# %%
CORPUS_ARXIU = "test_docs_anotat.conllu"

# Importem la llibreria CONLLU
import conllu, pickle, csv
from itertools import zip_longest
from conllu import parse
from io import open

from utils import EntitatNomenada

# %%
# Llegim les variables resultants d'executar les regex.
with open('entitats_nomenades.corpus_raw.pickle', 'rb') as file:
    entitats_nomenades_res = pickle.load(file)

with open('tokens.corpus_raw.pickle', 'rb') as file:
    tokens_res = pickle.load(file)

# %%
# Guardem el corpus de test anotat manualment a la variable dades
with open(CORPUS_ARXIU, "r", encoding="utf-8") as dades:

    # Llegeix els continguts del fitxer CONLLU i els guarda a la variable anotacions 
    anotacions = dades.read()

# Segmentem en frases tot el corpus i les guardem a la variable frases
frases = conllu.parse(anotacions)

# %%
# Obtenim els tokens a partir de l'arxiu de test.
tokens_test = []
for frase in frases:
    for token in frase:
        tokens_test.append((token))

# %%
# Comparem els dos conjunts de tokens per garantir que les dades son consistents.
if tokens_res == list(map(str, tokens_test)):
    print("Tot perfecte.")
# Out:
# Tot perfecte.

# %%
# Retorna l'etiqueta de la EN i el tipus ('B', 'I', 'O').
def obtenir_tipus_entitat(token):

    # Si no té dades, retornem buit.
    if token['misc'] is None:
        return 'O', None

    # Iterem per les claus del diccionari de dades.
    for clau in token['misc']:

        if clau[0:2] == 'B-':
            return 'B', clau[2:]
        
        if clau[0:2] == 'I-':
            return 'I', clau[2:]

    return 'O', None

# %%
# Iterem per tots els tokens cercant EN.
i = 0
entitats_nomenades_test = []
while i < len(tokens_test):

    # Obtenim el token corresponent.
    token_i = tokens_test[i]
    estat, etiqueta = obtenir_tipus_entitat(token_i)
    inici = i

    # Ja hem accedit al token, passem al següent ja en cas d'entrar
    # al bloc condicional.
    i += 1
    
    # Si marca l'inici d'una EN, entrem al bloc.
    if estat == 'B':

        # Obtenim el token corresponent.
        token_i = tokens_test[i]
        estat, _ = obtenir_tipus_entitat(token_i)
        final = i

        # Mentre la EN continuï o no s'hagi acabat el document.
        while estat == 'I' and i < len(tokens_test):

            # Saltem al següent token.
            i += 1

            # Actualitzem la informació.
            token_i = tokens_test[i]
            estat, _ = obtenir_tipus_entitat(token_i)
            final = i

        # Creem la instància d'EntitatNomenada i l'afegim a l'estructura.
        entitats_nomenades_test.append(EntitatNomenada(etiqueta, inici, final - inici, tokens_res[inici:final]))

# %%
# Ordenem les llistes pel seu index de token.
entitats_nomenades_res.sort(key=lambda x: x.inici)
entitats_nomenades_test.sort(key=lambda x: x.inici)

# %%
for en1, en2 in zip_longest(entitats_nomenades_res, entitats_nomenades_test):

    print("RES:", end=" ")
    if en1 is None:
        print("-")
    else:
        en1.print()

    print("TEST:", end=" ")
    if en2 is None:
        print("-")
    else:
        en2.print()
# Out:
# RES: PER (29-30) = ['Kerman']
# TEST: LOC (29-30) = ['Kerman']
# RES: PER (31-34) = ['Mohammad', 'Ali', 'Karimi']
# TEST: PER (31-34) = ['Mohammad', 'Ali', 'Karimi']
# RES: PER (42-43) = ['Kerman']
# TEST: LOC (42-43) = ['Kerman']
# RES: TIME (64-65) = ['després']
# TEST: TIME (64-65) = ['després']
# RES: PER (95-97) = ['Shah', 'Bajsh']
# TEST: ORG (95-97) = ['Shah', 'Bajsh']
# RES: TIME (125-126) = ['ahir']
# TEST: TIME (125-126) = ['ahir']
# RES: TIME (127-129) = ['un', 'dia']
# TEST: TIME (127-129) = ['un', 'dia']
# RES: TIME (129-130) = ['després']
# TEST: TIME (129-130) = ['després']
# RES: ORG (138-141) = ['Ministeri', "d'", 'Informació']
# TEST: ORG (138-141) = ['Ministeri', "d'", 'Informació']
# RES: ORG (148-149) = ['Govern']
# TEST: ORG (148-149) = ['Govern']
# RES: ORG (184-186) = ['France', 'Presse']
# TEST: ORG (184-186) = ['France', 'Presse']
# RES: LOC (211-212) = ['Iran']
# TEST: LOC (211-212) = ['Iran']
# RES: PER (213-215) = ['Ali', 'Khamenei']
# TEST: PER (213-215) = ['Ali', 'Khamenei']
# RES: TIME (239-240) = ['diari']
# TEST: MISC (242-243) = ['Nechat']
# RES: MISC (242-243) = ['Nechat']
# TEST: ORDINAL (279-280) = ['primer']
# RES: ORDINAL (279-280) = ['primer']
# TEST: PER (301-305) = ['José', 'Luis', 'Rodríguez', 'Zapatero']
# RES: PER (301-305) = ['José', 'Luis', 'Rodríguez', 'Zapatero']
# TEST: ORG (320-321) = ['Corts']
# RES: ORG (320-321) = ['Corts']
# TEST: DATE (323-326) = ["l'", 'any', '1986']
# RES: DATE (323-326) = ["l'", 'any', '1986']
# TEST: TIME (333-334) = ['ara']
# RES: TIME (333-334) = ['ara']
# TEST: TIME (360-361) = ['ara']
# RES: TIME (360-361) = ['ara']
# TEST: PER (377-379) = ['Rodríguez', 'Zapatero']
# RES: PER (377-379) = ['Rodríguez', 'Zapatero']
# TEST: ORG (384-385) = ['Govern']
# RES: ORG (384-385) = ['Govern']
# TEST: PER (386-389) = ['José', 'María', 'Aznar']
# RES: PER (386-389) = ['José', 'María', 'Aznar']
# TEST: PER (405-407) = ['Josep', 'Borrell']
# RES: PER (405-407) = ['Josep', 'Borrell']
# TEST: PER (408-410) = ['Joaquín', 'Almunia']
# RES: PER (408-410) = ['Joaquín', 'Almunia']
# TEST: PER (417-418) = ['Aznar']
# RES: PER (417-418) = ['Aznar']
# TEST: PER (438-441) = ['Luis', 'Martínez', 'Noval']
# RES: PER (438-441) = ['Luis', 'Martínez', 'Noval']
# TEST: ORG (450-451) = ['PSOE']
# RES: ORG (450-451) = ['PSOE']
# TEST: ORG (456-457) = ['Govern']
# RES: ORG (456-457) = ['Govern']
# TEST: TIME (459-460) = ['sovint']
# RES: TIME (459-460) = ['sovint']
# TEST: PER (475-477) = ['Rodríguez', 'Zapatero']
# RES: PER (475-477) = ['Rodríguez', 'Zapatero']
# TEST: PER (478-480) = ['Jesús', 'Caldera']
# RES: PER (478-480) = ['Jesús', 'Caldera']
# TEST: PER (481-482) = ['Aznar']
# RES: PER (481-482) = ['Aznar']
# TEST: ORG (515-516) = ['Govern']
# RES: ORG (515-516) = ['Govern']
# TEST: ORG (520-521) = ['Estat']
# RES: ORG (520-521) = ['Estat']
# TEST: PER (537-539) = ['Rodríguez', 'Zapatero']
# RES: PER (537-539) = ['Rodríguez', 'Zapatero']
# TEST: ORG (551-552) = ['Govern']
# RES: ORG (551-552) = ['Govern']
# TEST: PER (572-574) = ['Rodrigo', 'Rato']
# RES: PER (572-574) = ['Rodrigo', 'Rato']
# TEST: ORG (610-611) = ['PSOE']
# RES: ORG (610-611) = ['PSOE']
# TEST: ORG (627-628) = ['PP']
# RES: ORG (627-628) = ['PP']
# TEST: PER (631-632) = ['Rato']
# RES: PER (631-632) = ['Rato']
# TEST: PER (636-637) = ['Aznar']
# RES: PER (636-637) = ['Aznar']
# TEST: PER (655-657) = ['Rodríguez', 'Zapatero']
# RES: PER (655-657) = ['Rodríguez', 'Zapatero']
# TEST: MISC (659-662) = ['Quan', 'ens', 'veiem']
# RES: LOC (674-675) = ['Bars']
# TEST: ORG (674-675) = ['Bars']
# RES: PER (678-680) = ['Montse', 'Llaràs']
# TEST: PER (678-680) = ['Montse', 'Llaràs']
# RES: PER (681-683) = ['Toni', 'Moya']
# TEST: PER (681-683) = ['Toni', 'Moya']
# RES: PER (684-686) = ['Marc', 'Grasas']
# TEST: PER (684-686) = ['Marc', 'Grasas']
# RES: PER (687-689) = ['Jordi', 'Mourelo']
# TEST: PER (687-689) = ['Jordi', 'Mourelo']
# RES: PER (690-693) = ['Josep', 'Maria', 'Vilà']
# TEST: PER (690-693) = ['Josep', 'Maria', 'Vilà']
# RES: TIME (735-736) = ['abans']
# TEST: PER (702-703) = ['Llaràs']
# RES: MISC (739-741) = ['Mentre', 'dormies']
# TEST: TIME (735-736) = ['abans']
# RES: DATE (743-744) = ['1999']
# TEST: MISC (739-741) = ['Mentre', 'dormies']
# RES: PER (750-752) = ['Jordi', 'Garrós']
# TEST: DATE (743-744) = ['1999']
# RES: TIME (788-789) = ['Ara']
# TEST: PER (750-752) = ['Jordi', 'Garrós']
# RES: MISC (793-804) = ['Llaràs', 'sempre', 'hi', 'posa', 'les', 'lletres', '-', 'i', ',', 'potser', ',']
# TEST: PER (762-763) = ['Llaràs']
# RES: PER (814-815) = ['Moya']
# TEST: TIME (788-789) = ['Ara']
# RES: TIME (832-833) = ['sempre']
# TEST: PER (793-794) = ['Llaràs']
# RES: TIME (882-883) = ['Ara']
# TEST: TIME (794-795) = ['sempre']
# RES: PER (890-891) = ['Moya']
# TEST: PER (814-815) = ['Moya']
# RES: LOC (900-901) = ['Bars']
# TEST: TIME (832-833) = ['sempre']
# RES: MISC (905-906) = ['Llaràs']
# TEST: TIME (882-883) = ['Ara']
# RES: TIME (909-910) = ['mai']
# TEST: PER (890-891) = ['Moya']
# RES: CARDINAL (917-919) = ['18', 'temes']
# TEST: ORG (900-901) = ['Bars']
# RES: MISC (929-930) = ['Bars']
# TEST: PER (905-906) = ['Llaràs']
# RES: DATE (932-933) = ['1989']
# TEST: TIME (909-910) = ['mai']
# RES: MISC (936-938) = ['Mala', 'idea']
# TEST: CARDINAL (917-919) = ['18', 'temes']
# RES: DATE (940-941) = ['1991']
# TEST: MISC (922-925) = ['Quan', 'ens', 'veiem']
# RES: MISC (944-949) = ["T'", 'ho', 'diré', 'mil', 'vegades']
# TEST: ORG (929-930) = ['Bars']
# RES: DATE (951-952) = ['1993']
# TEST: DATE (932-933) = ['1989']
# RES: MISC (955-957) = ['En', 'concert']
# TEST: MISC (936-938) = ['Mala', 'idea']
# RES: DATE (959-960) = ['1994']
# TEST: DATE (940-941) = ['1991']
# RES: MISC (963-965) = ['Dolces', 'mentides']
# TEST: MISC (944-949) = ["T'", 'ho', 'diré', 'mil', 'vegades']
# RES: DATE (967-968) = ['1996']
# TEST: DATE (951-952) = ['1993']
# RES: MISC (971-973) = ['Mentre', 'dormies']
# TEST: MISC (955-957) = ['En', 'concert']
# RES: DATE (975-976) = ['1999']
# TEST: DATE (959-960) = ['1994']
# RES: PER (1035-1036) = ['Moya']
# TEST: MISC (963-965) = ['Dolces', 'mentides']
# RES: TIME (1041-1043) = ['el', 'gener']
# TEST: DATE (967-968) = ['1996']
# RES: MISC (1066-1069) = ['Fòrum', 'Social', 'Mundial']
# TEST: MISC (971-973) = ['Mentre', 'dormies']
# RES: PER (1070-1072) = ['Porto', 'Alegre']
# TEST: DATE (975-976) = ['1999']
# RES: LOC (1112-1114) = ['Buenos', 'Aires']
# TEST: ORG (978-979) = ['Bars']
# RES: ORG (1139-1140) = ['Tobin']
# TEST: PER (1035-1036) = ['Moya']
# RES: PER (1146-1148) = ['Rudolf', 'Strahm']
# TEST: TIME (1041-1043) = ['el', 'gener']
# RES: ORG (1151-1154) = ['Comitè', 'de', 'Finances']
# TEST: MISC (1066-1069) = ['Fòrum', 'Social', 'Mundial']
# RES: PER (1190-1191) = ['Strahm']
# TEST: LOC (1070-1072) = ['Porto', 'Alegre']
# RES: ORG (1196-1197) = ['Tobin']
# TEST: LOC (1112-1114) = ['Buenos', 'Aires']
# RES: PER (1204-1206) = ['Dominique', 'Pilhn']
# TEST: PER (1139-1140) = ['Tobin']
# RES: ORG (1208-1209) = ['ATTAC']
# TEST: PER (1146-1148) = ['Rudolf', 'Strahm']
# RES: LOC (1210-1211) = ['França']
# TEST: ORG (1151-1154) = ['Comitè', 'de', 'Finances']
# RES: MISC (1293-1295) = ['Universitat', 'Pontifícia']
# TEST: ORG (1156-1159) = ['Parlament', 'Federal', 'Suís']
# RES: PER (1352-1354) = ['Eric', 'Toussaint']
# TEST: PER (1190-1191) = ['Strahm']
# RES: ORG (1357-1369) = ['Comitè', 'per', 'a', "l'", 'Anul·lació', 'd', 'el', 'Deute', 'd', 'el', 'Tercer', 'Món']
# TEST: PER (1196-1197) = ['Tobin']
# RES: TIME (1371-1372) = ['Ara']
# TEST: PER (1204-1206) = ['Dominique', 'Pilhn']
# RES: LOC (1382-1383) = ['Argentina']
# TEST: ORG (1208-1209) = ['ATTAC']
# RES: LOC (1408-1410) = ['Nova', 'York']
# TEST: LOC (1210-1211) = ['França']
# RES: PER (1413-1415) = ['George', 'Soros']
# TEST: LOC (1293-1295) = ['Universitat', 'Pontifícia']
# RES: PER (1423-1425) = ['Porto', 'Alegre']
# TEST: PER (1352-1354) = ['Eric', 'Toussaint']
# RES: LOC (1426-1429) = ['Hebe', 'de', 'Bonafini']
# TEST: ORG (1357-1369) = ['Comitè', 'per', 'a', "l'", 'Anul·lació', 'd', 'el', 'Deute', 'd', 'el', 'Tercer', 'Món']
# RES: LOC (1433-1439) = ['Madres', 'de', 'la', 'Plaza', 'de', 'Mayo']
# TEST: TIME (1371-1372) = ['Ara']
# RES: PER (1451-1452) = ['Soros']
# TEST: LOC (1382-1383) = ['Argentina']
# RES: PER (1486-1489) = ['Haidi', 'Gaggio', 'Giuliani']
# TEST: LOC (1408-1410) = ['Nova', 'York']
# RES: CARDINAL (1495-1496) = ['23']
# TEST: PER (1413-1415) = ['George', 'Soros']
# RES: PER (1502-1503) = ['Gènova']
# TEST: LOC (1423-1425) = ['Porto', 'Alegre']
# RES: PER (1522-1524) = ['Porto', 'Alegre']
# TEST: PER (1426-1429) = ['Hebe', 'de', 'Bonafini']
# RES: TIME (1627-1632) = ['una', 'vegada', 'a', 'l', 'dia']
# TEST: ORG (1433-1439) = ['Madres', 'de', 'la', 'Plaza', 'de', 'Mayo']
# RES: TIME (1751-1753) = ['a', 'vegades']
# TEST: PER (1451-1452) = ['Soros']
# RES: ORG (1790-1791) = ['Administració']
# TEST: PER (1486-1489) = ['Haidi', 'Gaggio', 'Giuliani']
# RES: CARDINAL (1833-1835) = ['19', 'anys']
# TEST: CARDINAL (1495-1497) = ['23', 'anys']
# RES: LOC (1838-1839) = ['Lima']
# TEST: LOC (1502-1503) = ['Gènova']
# RES: LOC (1840-1841) = ['Amsterdam']
# TEST: LOC (1522-1524) = ['Porto', 'Alegre']
# RES: CARDINAL (1846-1848) = ['19', 'anys']
# TEST: TIME (1627-1632) = ['una', 'vegada', 'a', 'l', 'dia']
# RES: LOC (1855-1856) = ['Lima']
# TEST: MISC (1645-1649) = ["S'", 'ha', 'fet', 'justícia']
# RES: LOC (1857-1858) = ['Amsterdam']
# TEST: MISC (1678-1682) = ['No', 'hi', 'ha', 'dret']
# RES: ORG (1861-1862) = ['KLM']
# TEST: TIME (1751-1753) = ['a', 'vegades']
# RES: TIME (1865-1866) = ['dijous']
# TEST: ORG (1790-1791) = ['Administració']
# RES: TIME (1866-1869) = ['a', 'la', 'nit']
# TEST: CARDINAL (1833-1835) = ['19', 'anys']
# RES: LOC (1870-1871) = ['Nantes']
# TEST: LOC (1838-1839) = ['Lima']
# RES: TIME (1898-1899) = ['ahir']
# TEST: LOC (1840-1841) = ['Amsterdam']
# RES: ORG (1905-1906) = ['KL-742']
# TEST: CARDINAL (1846-1848) = ['19', 'anys']
# RES: TIME (1908-1909) = ['dimecres']
# TEST: LOC (1855-1856) = ['Lima']
# RES: LOC (1914-1915) = ['Lima']
# TEST: LOC (1857-1858) = ['Amsterdam']
# RES: LOC (1917-1918) = ['Amsterdam']
# TEST: ORG (1861-1862) = ['KLM']
# RES: LOC (1923-1924) = ['Aruba']
# TEST: TIME (1865-1869) = ['dijous', 'a', 'la', 'nit']
# RES: LOC (1941-1942) = ['Europa']
# TEST: LOC (1870-1871) = ['Nantes']
# RES: LOC (1953-1954) = ['Nantes']
# TEST: TIME (1898-1899) = ['ahir']
# RES: QUANTITY (2002-2004) = ['500', 'grams']
# TEST: MISC (1905-1906) = ['KL-742']
# RES: ORG (2053-2056) = ['Divisió', 'Nacional', 'Antidroga']
# TEST: TIME (1908-1909) = ['dimecres']
# RES: LOC (2060-2061) = ['Lima']
# TEST: LOC (1914-1915) = ['Lima']
# RES: TIME (2063-2064) = ['ahir']
# TEST: LOC (1917-1918) = ['Amsterdam']
# RES: TIME (2078-2079) = ['diari']
# TEST: LOC (1923-1924) = ['Aruba']
# RES: TIME (2080-2082) = ['aquest', 'any']
# TEST: LOC (1941-1942) = ['Europa']
# RES: LOC (2103-2104) = ['Lima']
# TEST: LOC (1953-1954) = ['Nantes']
# RES: CARDINAL (2121-2122) = ['70']
# TEST: QUANTITY (2002-2004) = ['500', 'grams']
# RES: LOC (2150-2151) = ['Perú']
# TEST: ORG (2053-2056) = ['Divisió', 'Nacional', 'Antidroga']
# RES: PER (2217-2219) = ['Jesús', 'Alonso']
# TEST: LOC (2060-2061) = ['Lima']
# RES: CARDINAL (2234-2236) = ['63', 'vots']
# TEST: TIME (2063-2064) = ['ahir']
# RES: TIME (2247-2248) = ['ahir']
# TEST: TIME (2080-2082) = ['aquest', 'any']
# RES: LOC (2249-2250) = ['Barcelona']
# TEST: LOC (2103-2104) = ['Lima']
# RES: PER (2251-2252) = ['Alonso']
# TEST: CARDINAL (2121-2122) = ['70']
# RES: CARDINAL (2254-2256) = ['1.701', 'vots']
# TEST: LOC (2150-2151) = ['Perú']
# RES: PER (2265-2268) = ['Joan', 'B.', 'Mur']
# TEST: PER (2217-2219) = ['Jesús', 'Alonso']
# RES: CARDINAL (2271-2273) = ['7.302', 'arquitectes']
# TEST: CARDINAL (2234-2236) = ['63', 'vots']
# RES: PERCENT (2294-2295) = ['45,7%']
# TEST: TIME (2247-2248) = ['ahir']
# RES: DATE (2301-2302) = ['1998']
# TEST: LOC (2249-2250) = ['Barcelona']
# RES: CARDINAL (2307-2309) = ['1.052', 'arquitectes']
# TEST: PER (2251-2252) = ['Alonso']
# RES: MISC (2321-2322) = ['Kosovo']
# TEST: CARDINAL (2254-2256) = ['1.701', 'vots']
# RES: ORG (2331-2333) = ['Afers', 'Estrangers']
# TEST: CARDINAL (2259-2260) = ['1.638']
# RES: PER (2334-2336) = ['Joschka', 'Fischer']
# TEST: PER (2265-2268) = ['Joan', 'B.', 'Mur']
# RES: TIME (2339-2340) = ['ahir']
# TEST: CARDINAL (2271-2273) = ['7.302', 'arquitectes']
# RES: LOC (2349-2350) = ['Balcans']
# TEST: CARDINAL (2285-2286) = ['3.339']
# RES: PER (2365-2366) = ['Fischer']
# TEST: PERCENT (2294-2295) = ['45,7%']
# RES: ORG (2370-2371) = ['OTAN']
# TEST: DATE (2301-2302) = ['1998']
# RES: MISC (2384-2385) = ['Kosovo']
# TEST: CARDINAL (2307-2309) = ['1.052', 'arquitectes']
# RES: ORDINAL (2387-2388) = ['primer']
# TEST: MISC (2321-2322) = ['Kosovo']
# RES: PER (2396-2397) = ['Fischer']
# TEST: ORG (2331-2333) = ['Afers', 'Estrangers']
# RES: PER (2399-2400) = ['Milosevic']
# TEST: PER (2334-2336) = ['Joschka', 'Fischer']
# RES: MISC (2408-2409) = ['Kosovo']
# TEST: TIME (2339-2340) = ['ahir']
# RES: ORG (2414-2415) = ['Exèrcit']
# TEST: LOC (2349-2350) = ['Balcans']
# RES: ORG (2431-2432) = ['Fischer']
# TEST: PER (2365-2366) = ['Fischer']
# RES: LOC (2444-2445) = ['Europa']
# TEST: ORG (2370-2371) = ['OTAN']
# RES: PER (2486-2487) = ['Rambouillet']
# TEST: MISC (2384-2385) = ['Kosovo']
# RES: ORG (2496-2497) = ['Defensa']
# TEST: ORDINAL (2387-2388) = ['primer']
# RES: PER (2498-2500) = ['Rudolf', 'Scharping']
# TEST: PER (2396-2397) = ['Fischer']
# RES: PER (2513-2514) = ['Rambouillet']
# TEST: PER (2399-2400) = ['Milosevic']
# RES: MISC (2542-2543) = ['Kosovo']
# TEST: MISC (2408-2409) = ['Kosovo']
# RES: PER (2547-2548) = ['Fischer']
# TEST: ORG (2414-2415) = ['Exèrcit']
# RES: ORG (2583-2584) = ['OTAN']
# TEST: PER (2431-2432) = ['Fischer']
# RES: PER (2595-2597) = ['Jacques', 'Chirac']
# TEST: LOC (2444-2445) = ['Europa']
# RES: TIME (2600-2601) = ['ahir']
# TEST: LOC (2486-2487) = ['Rambouillet']
# RES: PER (2640-2641) = ['Chirac']
# TEST: ORG (2496-2497) = ['Defensa']
# RES: PER (2667-2669) = ['Catherine', 'Colonna']
# TEST: PER (2498-2500) = ['Rudolf', 'Scharping']
# RES: DATE (2670-2675) = ["L'", 'octubre', 'd', 'el', '1998']
# TEST: LOC (2513-2514) = ['Rambouillet']
# RES: CARDINAL (2676-2678) = ['67', 'adolescents']
# TEST: MISC (2542-2543) = ['Kosovo']
# RES: CARDINAL (2703-2705) = ['320', 'persones']
# TEST: PER (2547-2548) = ['Fischer']
# RES: DATE (2706-2709) = ['26', 'de', 'desembre']
# TEST: ORG (2583-2584) = ['OTAN']
# RES: LOC (2711-2712) = ['Xina']
# TEST: PER (2595-2597) = ['Jacques', 'Chirac']
# RES: CARDINAL (2720-2722) = ['35', 'morts']
# TEST: TIME (2600-2601) = ['ahir']
# RES: DATE (2731-2734) = ['24', 'de', 'maig']
# TEST: PER (2640-2641) = ['Chirac']
# RES: TIME (2741-2742) = ['ahir']
# TEST: PER (2667-2669) = ['Catherine', 'Colonna']
# RES: LOC (2749-2750) = ['França']
# TEST: DATE (2670-2675) = ["L'", 'octubre', 'd', 'el', '1998']
# RES: PER (2762-2765) = ['Jean-Marie', 'Le', 'Pen']
# TEST: CARDINAL (2676-2678) = ['67', 'adolescents']
# RES: ORDINAL (2768-2769) = ['segona']
# TEST: CARDINAL (2703-2705) = ['320', 'persones']
# RES: PER (2781-2783) = ['Jacques', 'Chirac']
# TEST: DATE (2706-2709) = ['26', 'de', 'desembre']
# RES: CARDINAL (2787-2789) = ['1.300.000', 'persones']
# TEST: LOC (2711-2712) = ['Xina']
# RES: MISC (2810-2813) = ['Primer', 'de', 'Maig']
# TEST: CARDINAL (2720-2722) = ['35', 'morts']
# RES: LOC (2815-2816) = ['França']
# TEST: DATE (2731-2734) = ['24', 'de', 'maig']
# RES: ORG (2848-2850) = ['anti-Le', 'Pen']
# TEST: TIME (2741-2742) = ['ahir']
# RES: CARDINAL (2858-2860) = ['400.000', 'persones']
# TEST: LOC (2749-2750) = ['França']
# RES: ORG (2875-2877) = ['Front', 'Nacional']
# TEST: PER (2762-2765) = ['Jean-Marie', 'Le', 'Pen']
# RES: TIME (2881-2882) = ['abans']
# TEST: ORDINAL (2768-2769) = ['segona']
# RES: PER (2891-2894) = ['Joana', "d'", 'Arc']
# TEST: PER (2781-2783) = ['Jacques', 'Chirac']
# RES: PER (2912-2915) = ['Jean-Marie', 'Le', 'Pen']
# TEST: CARDINAL (2787-2789) = ['1.300.000', 'persones']
# RES: CARDINAL (2957-2959) = ['100.000', 'assistents']
# TEST: CARDINAL (2797-2798) = ['2.000.000']
# RES: CARDINAL (2969-2971) = ['20.000', 'persones']
# TEST: MISC (2810-2813) = ['Primer', 'de', 'Maig']
# RES: LOC (2974-2975) = ['França']
# TEST: LOC (2815-2816) = ['França']
# RES: TIME (2985-2986) = ['després']
# TEST: CARDINAL (2858-2860) = ['400.000', 'persones']
# RES: MISC (2995-2997) = ['Le', 'Pen']
# TEST: ORG (2875-2877) = ['Front', 'Nacional']
# RES: PER (2998-3000) = ['Bruno', 'Mégret']
# TEST: TIME (2879-2882) = ['poques', 'hores', 'abans']
# RES: ORG (3006-3008) = ['Front', 'Nacional']
# TEST: PER (2891-2894) = ['Joana', "d'", 'Arc']
# RES: TIME (3014-3017) = ["l'", 'any', 'passat']
# TEST: PER (2912-2915) = ['Jean-Marie', 'Le', 'Pen']
# RES: MISC (3018-3019) = ['París']
# TEST: CARDINAL (2957-2959) = ['100.000', 'assistents']
# RES: CARDINAL (3019-3021) = ['3.000', 'persones']
# TEST: CARDINAL (2967-2968) = ['15.000']
# RES: MISC (3025-3027) = ['Le', 'Pen']
# TEST: CARDINAL (2969-2971) = ['20.000', 'persones']
# RES: PER (3102-3104) = ['Jacques', 'Chirac']
# TEST: LOC (2974-2975) = ['França']
# RES: CARDINAL (3145-3147) = ['2.000', 'persones']
# TEST: TIME (2985-2986) = ['després']
# RES: PER (3164-3166) = ['Brahim', 'Buraram']
# TEST: PER (2995-2997) = ['Le', 'Pen']
# RES: LOC (3173-3174) = ['Sena']
# TEST: PER (2998-3000) = ['Bruno', 'Mégret']
# RES: TIME (3174-3175) = ['després']
# TEST: ORG (3006-3008) = ['Front', 'Nacional']
# RES: ORG (3196-3203) = ['Front', 'Nacional', 'd', 'el', 'Primer', 'de', 'Maig']
# TEST: TIME (3014-3017) = ["l'", 'any', 'passat']
# RES: DATE (3205-3206) = ['1995']
# TEST: MISC (3018-3019) = ['París']
# RES: MISC (3222-3224) = ['Le', 'Pen']
# TEST: CARDINAL (3019-3021) = ['3.000', 'persones']
# RES: ORG (3230-3231) = ['FN']
# TEST: PER (3025-3027) = ['Le', 'Pen']
# RES: LOC (3238-3239) = ['França']
# TEST: PER (3102-3104) = ['Jacques', 'Chirac']
# RES: CARDINAL (3248-3249) = ['400']
# TEST: CARDINAL (3145-3147) = ['2.000', 'persones']
# RES: LOC (3256-3257) = ['Lió']
# TEST: PER (3164-3166) = ['Brahim', 'Buraram']
# RES: MISC (3264-3265) = ['Grenoble']
# TEST: LOC (3173-3174) = ['Sena']
# RES: PER (3318-3319) = ['Chirac']
# TEST: TIME (3174-3175) = ['després']
# RES: ORG (3333-3334) = ['Govern']
# TEST: MISC (3196-3203) = ['Front', 'Nacional', 'd', 'el', 'Primer', 'de', 'Maig']
# RES: PER (3336-3338) = ['Lionel', 'Jospin']
# TEST: DATE (3205-3206) = ['1995']
# RES: TIME (3507-3508) = ['Sempre']
# TEST: MISC (3212-3217) = ['no', 'a', "l'", 'extrema', 'dreta']
# RES: PER (3543-3544) = ['Aznar']
# TEST: MISC (3220-3224) = ['no', 'a', 'Le', 'Pen']
# RES: PER (3545-3546) = ['Ibarretxe']
# TEST: MISC (3227-3231) = ['no', 'a', "l'", 'FN']
# RES: TIME (3564-3565) = ['mai']
# TEST: LOC (3238-3239) = ['França']
# RES: PER (3609-3610) = ['Ibarretxe']
# TEST: CARDINAL (3248-3250) = ['400', 'ciutats']
# RES: PER (3616-3617) = ['Aznar']
# TEST: LOC (3256-3257) = ['Lió']
# RES: DATE (3624-3625) = ['13-M']
# TEST: CARDINAL (3258-3260) = ['50.000', 'persones']
# RES: PER (3641-3643) = ['Josep', 'Pujadas']
# TEST: LOC (3264-3265) = ['Grenoble']
# RES: ORG (3644-3645) = ['PSC']
# TEST: CARDINAL (3266-3268) = ['40.000', 'persones']
# RES: TIME (3649-3650) = ['ahir']
# TEST: CARDINAL (3277-3278) = ['400.000']
# RES: CARDINAL (3659-3661) = ['224', 'veïns']
# TEST: PER (3318-3319) = ['Chirac']
# RES: CARDINAL (3664-3666) = ['165', 'ferits']
# TEST: ORG (3333-3334) = ['Govern']
# RES: DATE (3675-3680) = ['31', 'de', 'maig', 'de', '1938']
# TEST: PER (3336-3338) = ['Lionel', 'Jospin']
# RES: CARDINAL (3687-3689) = ['80', 'edificis']
# TEST: TIME (3507-3508) = ['Sempre']
# RES: ORG (3698-3700) = ['Caixa', 'Tarragona']
# TEST: PER (3543-3544) = ['Aznar']
# RES: MISC (3712-3715) = ['AC', 'BIENESTAR', 'FIM']
# TEST: PER (3545-3546) = ['Ibarretxe']
# RES: ORDINAL (3761-3762) = ['primer']
# TEST: TIME (3564-3565) = ['mai']
# RES: ORG (3770-3772) = ['Caixa', 'Tarragona']
# TEST: PER (3609-3610) = ['Ibarretxe']
# RES: MISC (3826-3827) = ['TV']
# TEST: PER (3616-3617) = ['Aznar']
# RES: ORG (3851-3852) = ['Japó']
# TEST: DATE (3624-3625) = ['13-M']
# RES: LOC (3853-3854) = ['França']
# TEST: PER (3641-3643) = ['Josep', 'Pujadas']
# RES: LOC (3855-3856) = ['Itàlia']
# TEST: ORG (3644-3645) = ['PSC']
# RES: ORG (3857-3858) = ['Suïssa']
# TEST: TIME (3649-3650) = ['ahir']
# RES: LOC (3859-3860) = ['Alemanya']
# TEST: CARDINAL (3659-3661) = ['224', 'veïns']
# RES: LOC (3861-3862) = ['Holanda']
# TEST: CARDINAL (3664-3666) = ['165', 'ferits']
# RES: LOC (3863-3865) = ['Gran', 'Bretanya']
# TEST: DATE (3675-3680) = ['31', 'de', 'maig', 'de', '1938']
# RES: LOC (3868-3870) = ['Estats', 'Units']
# TEST: CARDINAL (3687-3689) = ['80', 'edificis']
# RES: ORG (3883-3885) = ['Caixa', 'Tarragona']
# TEST: ORG (3698-3700) = ['Caixa', 'Tarragona']
# RES: PER (3927-3929) = ['Goldman', 'Sach']
# TEST: MISC (3712-3715) = ['AC', 'BIENESTAR', 'FIM']
# RES: PER (3930-3932) = ['Morgan', 'Stanley']
# TEST: ORDINAL (3761-3762) = ['primer']
# RES: PER (3933-3938) = ['Merril', 'Lynch', 'Mercury', 'Asset', 'Management']
# TEST: ORG (3770-3772) = ['Caixa', 'Tarragona']
# RES: ORG (3939-3942) = ['Gesinca', 'Inversiones', 'SA']
# TEST: ORG (3851-3852) = ['Japó']
# RES: ORG (3943-3946) = ['GVC', 'Gestió', 'SA']
# TEST: LOC (3853-3854) = ['França']
# RES: ORG (3948-3952) = ['Caixa', 'Tarragona', 'Gestió', 'SA']
# TEST: LOC (3855-3856) = ['Itàlia']
# RES: ORG (3956-3960) = ['Caixa', 'Tarragona', 'Gestió', 'SA']
# TEST: ORG (3857-3858) = ['Suïssa']
# RES: PERCENT (3964-3965) = ['100%']
# TEST: LOC (3859-3860) = ['Alemanya']
# RES: PERCENT (3978-3979) = ['34%']
# TEST: LOC (3861-3862) = ['Holanda']
# RES: TIME (3981-3984) = ["l'", 'any', 'anterior']
# TEST: LOC (3863-3865) = ['Gran', 'Bretanya']
# RES: ORDINAL (3987-3988) = ['tercer']
# TEST: LOC (3868-3870) = ['Estats', 'Units']
# RES: MONEY (3996-4000) = ['180', 'milions', 'de', 'pessetes']
# TEST: ORG (3883-3885) = ['Caixa', 'Tarragona']
# RES: MISC (4016-4017) = ['Inversión']
# TEST: MISC (3908-3910) = ['unit', 'link']
# RES: CARDINAL (4028-4030) = ['25', 'millors']
# TEST: ORG (3927-3929) = ['Goldman', 'Sach']
# RES: DATE (4058-4059) = ['1999']
# TEST: ORG (3930-3932) = ['Morgan', 'Stanley']
# RES: MISC (4070-4074) = ['FIM', 'RV', 'Mixta', 'Internacional']
# TEST: ORG (3933-3938) = ['Merril', 'Lynch', 'Mercury', 'Asset', 'Management']
# RES: LOC (4077-4080) = ['TARRAGONAFONS', 'GLOBAL', 'FIM']
# TEST: ORG (3939-3942) = ['Gesinca', 'Inversiones', 'SA']
# RES: ORG (4089-4091) = ['FIM', 'Globals']
# TEST: ORG (3943-3946) = ['GVC', 'Gestió', 'SA']
# RES: ORG (4093-4096) = ['AC', 'DIVISA', 'FIM']
# TEST: ORG (3948-3952) = ['Caixa', 'Tarragona', 'Gestió', 'SA']
# RES: ORG (4100-4102) = ['Caixa', 'Tarragona']
# TEST: ORG (3956-3960) = ['Caixa', 'Tarragona', 'Gestió', 'SA']
# RES: TIME (4105-4107) = ['sis', 'anys']
# TEST: PERCENT (3964-3965) = ['100%']
# RES: PER (4110-4112) = ['Elías', 'Yanes']
# TEST: PERCENT (3978-3979) = ['34%']
# RES: PER (4164-4165) = ['Pinochet']
# TEST: TIME (3981-3984) = ["l'", 'any', 'anterior']
# RES: ORG (4167-4168) = ['Església']
# TEST: ORDINAL (3987-3988) = ['tercer']
# RES: ORG (4173-4174) = ['Govern']
# TEST: MONEY (3996-4000) = ['180', 'milions', 'de', 'pessetes']
# RES: MISC (4204-4205) = ['IRPF']
# TEST: MISC (4016-4017) = ['Inversión']
# RES: PERCENT (4218-4219) = ['0,5%']
# TEST: CARDINAL (4028-4030) = ['25', 'millors']
# RES: ORG (4259-4260) = ['Tómbola']
# TEST: DATE (4058-4059) = ['1999']
# RES: ORG (4269-4270) = ['PP']
# TEST: MISC (4070-4074) = ['FIM', 'RV', 'Mixta', 'Internacional']
# RES: ORG (4287-4294) = ['Comissió', 'Primera', 'd', 'el', 'Parlament', 'de', 'Catalunya']
# TEST: MISC (4077-4080) = ['TARRAGONAFONS', 'GLOBAL', 'FIM']
# RES: ORG (4306-4307) = ['PP']
# TEST: MISC (4089-4096) = ['FIM', 'Globals', 'a', 'l', 'AC', 'DIVISA', 'FIM']
# RES: ORG (4308-4309) = ['ERC']
# TEST: ORG (4100-4102) = ['Caixa', 'Tarragona']
# RES: ORG (4312-4313) = ['Govern']
# TEST: PER (4110-4112) = ['Elías', 'Yanes']
# RES: MISC (4318-4323) = ['Diari', 'Oficial', 'de', 'la', 'Generalitat']
# TEST: PER (4164-4165) = ['Pinochet']
# RES: ORG (4348-4349) = ['Govern']
# TEST: ORG (4167-4168) = ['Església']
# RES: ORG (4354-4355) = ['PP']
# TEST: ORG (4173-4174) = ['Govern']
# RES: PER (4355-4357) = ['Dolors', 'Nadal']
# TEST: MISC (4204-4205) = ['IRPF']
# RES: ORG (4371-4375) = ['Govern', 'de', 'la', 'Generalitat']
# TEST: PERCENT (4218-4219) = ['0,5%']
# RES: ORG (4386-4387) = ['Govern']
# TEST: MISC (4259-4260) = ['Tómbola']
# RES: ORG (4399-4400) = ['Generalitat']
# TEST: ORG (4269-4270) = ['PP']
# RES: TIME (4402-4405) = ['cada', 'tres', 'mesos']
# TEST: ORG (4287-4289) = ['Comissió', 'Primera']
# RES: MISC (4423-4424) = ['Nadal']
# TEST: ORG (4291-4294) = ['Parlament', 'de', 'Catalunya']
# RES: TIME (4433-4436) = ['fa', 'uns', 'mesos']
# TEST: ORG (4306-4307) = ['PP']
# RES: ORG (4437-4438) = ['ERC']
# TEST: ORG (4308-4309) = ['ERC']
# RES: ORG (4449-4450) = ['Governació']
# TEST: ORG (4312-4313) = ['Govern']
# RES: ORG (4467-4468) = ['Generalitat']
# TEST: MISC (4318-4323) = ['Diari', 'Oficial', 'de', 'la', 'Generalitat']
# RES: ORG (4496-4497) = ['PP']
# TEST: ORG (4348-4349) = ['Govern']
# RES: DATE (4499-4502) = ['4', "d'", 'abril']
# TEST: ORG (4354-4355) = ['PP']
# RES: ORG (4522-4523) = ['CiU']
# TEST: PER (4355-4357) = ['Dolors', 'Nadal']
# RES: ORG (4548-4549) = ['CiU']
# TEST: ORG (4371-4375) = ['Govern', 'de', 'la', 'Generalitat']
# RES: ORG (4550-4551) = ['PP']
# TEST: ORG (4386-4387) = ['Govern']
# RES: DATE (4557-4560) = ['29', 'de', 'març']
# TEST: ORG (4399-4400) = ['Generalitat']
# RES: ORG (4561-4562) = ['PP']
# TEST: TIME (4402-4405) = ['cada', 'tres', 'mesos']
# RES: ORG (4564-4565) = ['CiU']
# TEST: TIME (4420-4422) = ['cada', 'any']
# RES: TIME (4573-4575) = ['dos', 'dies']
# TEST: MISC (4423-4424) = ['Nadal']
# RES: TIME (4575-4576) = ['després']
# TEST: TIME (4433-4436) = ['fa', 'uns', 'mesos']
# RES: ORG (4580-4581) = ['PP']
# TEST: ORG (4437-4438) = ['ERC']
# RES: ORG (4592-4593) = ['CDC']
# TEST: ORG (4449-4450) = ['Governació']
# RES: ORG (4594-4595) = ['UDC']
# TEST: ORG (4467-4468) = ['Generalitat']
# RES: DATE (4599-4602) = ['4', "d'", 'abril']
# TEST: ORG (4496-4497) = ['PP']
# RES: ORG (4603-4604) = ['PP']
# TEST: DATE (4499-4502) = ['4', "d'", 'abril']
# RES: ORG (4607-4608) = ['CiU']
# TEST: ORG (4522-4523) = ['CiU']
# RES: ORG (4612-4619) = ['Comissió', 'de', 'Política', 'Social', 'd', 'el', 'Parlament']
# TEST: ORG (4548-4549) = ['CiU']
# RES: ORG (4623-4624) = ['ERC']
# TEST: ORG (4550-4551) = ['PP']
# RES: PER (4624-4626) = ['Joan', 'Ridao']
# TEST: DATE (4557-4560) = ['29', 'de', 'març']
# RES: ORG (4644-4645) = ['Generalitat']
# TEST: ORG (4561-4562) = ['PP']
# RES: PER (4668-4669) = ['Ridao']
# TEST: ORG (4564-4565) = ['CiU']
# RES: TIME (4679-4682) = ['fa', 'uns', 'mesos']
# TEST: TIME (4573-4575) = ['dos', 'dies']
# RES: PER (4724-4725) = ['Ridao']
# TEST: TIME (4575-4576) = ['després']
# RES: ORG (4730-4731) = ['CiU']
# TEST: ORG (4580-4581) = ['PP']
# RES: PER (4731-4733) = ['Rafael', 'Hinojosa']
# TEST: ORG (4592-4593) = ['CDC']
# RES: PER (4744-4745) = ['Hinojosa']
# TEST: ORG (4594-4595) = ['UDC']
# RES: ORG (4771-4772) = ['CiU']
# TEST: DATE (4599-4602) = ['4', "d'", 'abril']
# RES: ORDINAL (4784-4785) = ['segones']
# TEST: ORG (4603-4604) = ['PP']
# RES: MISC (4809-4812) = ['Ètica', '/', 'Religió']
# TEST: ORG (4607-4608) = ['CiU']
# RES: TIME (4869-4871) = ['tres', 'anys']
# TEST: ORG (4612-4616) = ['Comissió', 'de', 'Política', 'Social']
# RES: ORG (4934-4935) = ['Església']
# TEST: ORG (4618-4619) = ['Parlament']
# RES: ORG (4947-4948) = ['Estat']
# TEST: ORG (4623-4624) = ['ERC']
# RES: ORG (4991-4992) = ['Estat']
# TEST: PER (4624-4626) = ['Joan', 'Ridao']
# RES: ORG (5015-5019) = ['Universitats', 'de', 'la', 'Generalitat']
# TEST: ORG (4644-4645) = ['Generalitat']
# RES: PER (5020-5022) = ['Andreu', 'Mas-Colell']
# TEST: PER (4668-4669) = ['Ridao']
# RES: MISC (5029-5034) = ['Els', 'Matins', 'amb', 'Josep', 'Cuní']
# TEST: TIME (4679-4682) = ['fa', 'uns', 'mesos']
# RES: ORG (5037-5039) = ['Ona', 'Catalana']
# TEST: CARDINAL (4690-4691) = ['7']
# RES: LOC (5072-5073) = ['Mas-Collel']
# TEST: PER (4724-4725) = ['Ridao']
# RES: PER (5140-5141) = ['Mas-Colell']
# TEST: ORG (4730-4731) = ['CiU']
# RES: LOC (5239-5240) = ['Barajas']
# TEST: PER (4731-4733) = ['Rafael', 'Hinojosa']
# RES: ORDINAL (5246-5247) = ['vintena']
# TEST: PER (4744-4745) = ['Hinojosa']
# RES: TIME (5258-5260) = ['aquest', 'any']
# TEST: ORG (4771-4772) = ['CiU']
# RES: ORG (5267-5269) = ['Aerolíneas', 'Argentinas']
# TEST: ORDINAL (4784-4785) = ['segones']
# RES: TIME (5279-5280) = ['dilluns']
# TEST: MISC (4809-4812) = ['Ètica', '/', 'Religió']
# RES: TIME (5302-5303) = ['dijous']
# TEST: TIME (4869-4871) = ['tres', 'anys']
# RES: TIME (5323-5328) = ["d'", 'aquí', 'a', 'una', 'setmana']
# TEST: ORG (4934-4935) = ['Església']
# RES: LOC (5333-5334) = ['Barajas']
# TEST: ORG (4947-4948) = ['Estat']
# RES: TIME (5343-5344) = ['abans']
# TEST: ORG (4991-4992) = ['Estat']
# RES: PER (5369-5371) = ['Sala', 'Goya']
# TEST: ORG (5015-5016) = ['Universitats']
# RES: LOC (5375-5376) = ['VIP']
# TEST: ORG (5018-5019) = ['Generalitat']
# RES: TIME (5379-5380) = ['dilluns']
# TEST: PER (5020-5022) = ['Andreu', 'Mas-Colell']
# RES: ORG (5391-5392) = ['AENA']
# TEST: MISC (5029-5034) = ['Els', 'Matins', 'amb', 'Josep', 'Cuní']
# RES: TIME (5416-5417) = ['Ahir']
# TEST: MISC (5037-5039) = ['Ona', 'Catalana']
# RES: LOC (5444-5445) = ['Barajas']
# TEST: PER (5072-5073) = ['Mas-Collel']
# RES: ORG (5460-5461) = ['UE']
# TEST: PER (5140-5141) = ['Mas-Colell']
# RES: TIME (5467-5468) = ['ahir']
# TEST: LOC (5239-5240) = ['Barajas']
# RES: LOC (5469-5470) = ['Madrid']
# TEST: TIME (5242-5244) = ['cada', 'estiu']
# RES: ORG (5474-5475) = ['Defensa']
# TEST: TIME (5258-5260) = ['aquest', 'any']
# RES: PER (5476-5478) = ['Federico', 'Trillo']
# TEST: ORG (5267-5269) = ['Aerolíneas', 'Argentinas']
# RES: PER (5507-5508) = ['Ibarretxe']
# TEST: TIME (5279-5280) = ['dilluns']
# RES: LOC (5517-5518) = ['Aguirre']
# TEST: TIME (5302-5303) = ['dijous']
# RES: DATE (5518-5520) = ['el', '1936']
# TEST: TIME (5323-5328) = ["d'", 'aquí', 'a', 'una', 'setmana']
# RES: PER (5521-5524) = ['Juan', 'José', 'Ibarretxe']
# TEST: LOC (5333-5334) = ['Barajas']
# RES: ORDINAL (5540-5541) = ['primer']
# TEST: TIME (5343-5344) = ['abans']
# RES: PER (5544-5548) = ['José', 'Antonio', 'Aguirre', 'Lekube']
# TEST: LOC (5369-5371) = ['Sala', 'Goya']
# RES: DATE (5549-5551) = ['el', '1936']
# TEST: PER (5375-5376) = ['VIP']
# RES: PER (5554-5555) = ['Déu']
# TEST: TIME (5379-5380) = ['dilluns']
# RES: LOC (5572-5573) = ['Gernika']
# TEST: ORG (5391-5392) = ['AENA']
# RES: PER (5602-5605) = ['José', 'Antonio', 'Ardanza']
# TEST: TIME (5408-5410) = ['Cada', 'dia']
# RES: PER (5625-5626) = ['Ibarretxe']
# TEST: TIME (5416-5417) = ['Ahir']
# RES: ORG (5660-5662) = ['Euskal', 'Herritarrok']
# TEST: LOC (5444-5445) = ['Barajas']
# RES: ORG (5663-5664) = ['EH']
# TEST: ORG (5460-5461) = ['UE']
# RES: CARDINAL (5672-5674) = ['14', 'parlamentaris']
# TEST: TIME (5467-5468) = ['ahir']
# RES: PER (5684-5685) = ['Ibarretxe']
# TEST: LOC (5469-5470) = ['Madrid']
# RES: LOC (5700-5705) = ['Casa', 'de', 'Juntes', 'de', 'Gernika']
# TEST: ORG (5474-5475) = ['Defensa']
# RES: LOC (5714-5716) = ['País', 'Basc']
# TEST: PER (5476-5478) = ['Federico', 'Trillo']
# RES: ORG (5724-5725) = ['Cambra']
# TEST: PER (5507-5508) = ['Ibarretxe']
# RES: CARDINAL (5730-5732) = ['300', 'convidats']
# TEST: PER (5517-5518) = ['Aguirre']
# RES: ORG (5745-5747) = ['Administracions', 'Públiques']
# TEST: DATE (5518-5520) = ['el', '1936']
# RES: PER (5748-5750) = ['Mariano', 'Rajoy']
# TEST: PER (5521-5524) = ['Juan', 'José', 'Ibarretxe']
# RES: LOC (5770-5771) = ['Gernika']
# TEST: PER (5544-5548) = ['José', 'Antonio', 'Aguirre', 'Lekube']
# RES: MISC (5773-5774) = ['Bíblia']
# TEST: DATE (5549-5551) = ['el', '1936']
# RES: DATE (5776-5777) = ['1859']
# TEST: PER (5554-5555) = ['Déu']
# RES: LOC (5800-5802) = ['País', 'Basc']
# TEST: LOC (5572-5573) = ['Gernika']
# RES: ORG (5825-5826) = ['Ertzaintza']
# TEST: PER (5602-5605) = ['José', 'Antonio', 'Ardanza']
# RES: ORG (5843-5844) = ['Ardanza']
# TEST: PER (5625-5626) = ['Ibarretxe']
# RES: PER (5845-5846) = ['Ibarretxe']
# TEST: ORG (5660-5662) = ['Euskal', 'Herritarrok']
# RES: TIME (5847-5850) = ['A', 'la', 'tarda']
# TEST: ORG (5663-5664) = ['EH']
# RES: MISC (5865-5867) = ['Ajuria', 'Enea']
# TEST: CARDINAL (5672-5674) = ['14', 'parlamentaris']
# RES: ORG (5896-5897) = ['Donington']
# TEST: PER (5684-5685) = ['Ibarretxe']
# RES: MISC (5906-5909) = ['Mundial', 'de', 'Motociclisme']
# TEST: LOC (5700-5703) = ['Casa', 'de', 'Juntes']
# RES: PER (5914-5916) = ['Sergio', 'Marqués']
# TEST: LOC (5704-5705) = ['Gernika']
# RES: TIME (5919-5920) = ['ahir']
# TEST: LOC (5714-5716) = ['País', 'Basc']
# RES: ORG (5932-5934) = ['Partit', 'Popular']
# TEST: ORG (5724-5725) = ['Cambra']
# RES: CARDINAL (5948-5949) = ['100']
# TEST: CARDINAL (5730-5732) = ['300', 'convidats']
# RES: ORG (5995-5996) = ['PP']
# TEST: ORG (5745-5747) = ['Administracions', 'Públiques']
# RES: TIME (5998-5999) = ['ara']
# TEST: PER (5748-5750) = ['Mariano', 'Rajoy']
# RES: LOC (6002-6003) = ['Astúries']
# TEST: LOC (5770-5771) = ['Gernika']
# RES: LOC (6008-6009) = ['Marqués']
# TEST: MISC (5773-5774) = ['Bíblia']
# RES: PER (6019-6022) = ['José', 'María', 'Aznar']
# TEST: DATE (5776-5777) = ['1859']
# RES: TIME (6024-6025) = ['ahir']
# TEST: LOC (5800-5802) = ['País', 'Basc']
# RES: LOC (6035-6036) = ['Principat']
# TEST: ORG (5825-5826) = ['Ertzaintza']
# RES: TIME (6044-6045) = ['demà']
# TEST: PER (5843-5844) = ['Ardanza']
# RES: ORG (6051-6052) = ['Parlament']
# TEST: PER (5845-5846) = ['Ibarretxe']
# RES: TIME (6061-6062) = ['dimarts']
# TEST: PER (5865-5867) = ['Ajuria', 'Enea']
# RES: TIME (6063-6064) = ['dimecres']
# TEST: LOC (5896-5897) = ['Donington']
# RES: TIME (6065-6069) = ['la', 'setmana', 'que', 've']
# TEST: MISC (5906-5909) = ['Mundial', 'de', 'Motociclisme']
# RES: ORG (6074-6075) = ['PP']
# TEST: PER (5914-5916) = ['Sergio', 'Marqués']
# RES: LOC (6080-6081) = ['Principat']
# TEST: TIME (5919-5920) = ['ahir']
# RES: ORG (6086-6087) = ['Parlament']
# TEST: ORG (5932-5934) = ['Partit', 'Popular']
# RES: PER (6089-6091) = ['Ovidio', 'Sánchez']
# TEST: CARDINAL (5948-5950) = ['100', 'dies']
# RES: LOC (6115-6116) = ['Astúries']
# TEST: ORG (5995-5996) = ['PP']
# RES: PER (6136-6137) = ['Marqués']
# TEST: TIME (5998-5999) = ['ara']
# RES: TIME (6140-6141) = ['dissabte']
# TEST: LOC (6002-6003) = ['Astúries']
# RES: ORG (6147-6150) = ['Unió', 'Renovadora', 'Asturiana']
# TEST: PER (6008-6009) = ['Marqués']
# RES: PER (6151-6152) = ['Uras']
# TEST: PER (6019-6022) = ['José', 'María', 'Aznar']
# RES: LOC (6157-6158) = ['Oviedo']
# TEST: TIME (6024-6025) = ['ahir']
# RES: PER (6159-6162) = ['Gabino', 'de', 'Lorenzo']
# TEST: LOC (6035-6036) = ['Principat']
# RES: ORG (6166-6167) = ['PP']
# TEST: TIME (6044-6045) = ['demà']
# RES: ORG (6171-6172) = ['avinentesa']
# TEST: ORG (6051-6052) = ['Parlament']
# RES: PER (6175-6176) = ['Marqués']
# TEST: TIME (6061-6062) = ['dimarts']
# RES: ORG (6203-6204) = ['PP']
# TEST: TIME (6063-6064) = ['dimecres']
# RES: PER (6205-6207) = ['Javier', 'Arenas']
# TEST: TIME (6065-6069) = ['la', 'setmana', 'que', 've']
# RES: LOC (6212-6215) = ['Palma', 'de', 'Mallorca']
# TEST: ORG (6074-6075) = ['PP']
# RES: LOC (6222-6223) = ['Astúries']
# TEST: LOC (6080-6081) = ['Principat']
# RES: PER (6226-6228) = ['Josep', 'Borrell']
# TEST: ORG (6086-6087) = ['Parlament']
# RES: PER (6253-6255) = ['Julio', 'Anguita']
# TEST: PER (6089-6091) = ['Ovidio', 'Sánchez']
# RES: ORG (6269-6270) = ['PP']
# TEST: LOC (6115-6116) = ['Astúries']
# RES: LOC (6271-6272) = ['Marqués']
# TEST: PER (6136-6137) = ['Marqués']
# RES: ORG (6281-6285) = ['Universitat', 'Rovira', 'i', 'Virgili']
# TEST: TIME (6140-6141) = ['dissabte']
# RES: ORG (6286-6287) = ['URV']
# TEST: ORG (6147-6150) = ['Unió', 'Renovadora', 'Asturiana']
# RES: PER (6289-6291) = ['Lluís', 'Arola']
# TEST: ORG (6151-6152) = ['Uras']
# RES: PER (6299-6301) = ['Joan', 'Igual']
# TEST: LOC (6157-6158) = ['Oviedo']
# RES: PER (6308-6310) = ['Josefina', 'Albert']
# TEST: PER (6159-6162) = ['Gabino', 'de', 'Lorenzo']
# RES: PER (6311-6314) = ['José', 'M.', 'Fernández']
# TEST: ORG (6166-6167) = ['PP']
# RES: CARDINAL (6334-6336) = ['8', 'anys']
# TEST: PER (6175-6176) = ['Marqués']
# RES: TIME (6343-6344) = ['avui']
# TEST: ORG (6203-6204) = ['PP']
# RES: PER (6352-6355) = ['Arola', 'i', 'Igual']
# TEST: PER (6205-6207) = ['Javier', 'Arenas']
# RES: ORG (6357-6359) = ['Ministeri', 'Públic']
# TEST: LOC (6212-6215) = ['Palma', 'de', 'Mallorca']
# RES: PER (6398-6400) = ['Josefina', 'Albert']
# TEST: LOC (6222-6223) = ['Astúries']
# RES: ORG (6404-6407) = ['Convivencia', 'Cívica', 'Catalana']
# TEST: PER (6226-6228) = ['Josep', 'Borrell']
# RES: ORG (6408-6409) = ['CCC']
# TEST: PER (6253-6255) = ['Julio', 'Anguita']
# RES: PER (6431-6433) = ['Ignacio', 'Monreal']
# TEST: ORG (6269-6270) = ['PP']
# RES: ORG (6446-6448) = ['Jutjat', 'Penal']
# TEST: PER (6271-6272) = ['Marqués']
# RES: LOC (6451-6452) = ['Tarragona']
# TEST: ORG (6281-6285) = ['Universitat', 'Rovira', 'i', 'Virgili']
# RES: DATE (6456-6459) = ['24', 'de', 'juliol']
# TEST: ORG (6286-6287) = ['URV']
# RES: ORG (6469-6470) = ['URV']
# TEST: PER (6289-6291) = ['Lluís', 'Arola']
# RES: ORG (6475-6476) = ['PAAU']
# TEST: PER (6299-6301) = ['Joan', 'Igual']
# RES: LOC (6537-6538) = ['Monreal']
# TEST: PER (6308-6310) = ['Josefina', 'Albert']
# RES: PER (6581-6582) = ['Albert']
# TEST: PER (6311-6314) = ['José', 'M.', 'Fernández']
# RES: PER (6600-6601) = ['Albert']
# TEST: CARDINAL (6334-6336) = ['8', 'anys']
# RES: ORG (6606-6607) = ['PAAU']
# TEST: TIME (6343-6344) = ['avui']
# RES: ORG (6641-6642) = ['PAAU']
# TEST: PER (6352-6353) = ['Arola']
# RES: PER (6676-6677) = ['Albert']
# TEST: PER (6354-6355) = ['Igual']
# RES: PER (6686-6688) = ['Ignacio', 'Monreal']
# TEST: ORG (6357-6359) = ['Ministeri', 'Públic']
# RES: PER (6725-6729) = ['Defensor', 'd', 'el', 'Pueblo']
# TEST: PER (6398-6400) = ['Josefina', 'Albert']
# RES: LOC (6756-6757) = ['Universitat']
# TEST: ORG (6404-6407) = ['Convivencia', 'Cívica', 'Catalana']
# RES: PER (6758-6760) = ['Antoni', 'Huber']
# TEST: ORG (6408-6409) = ['CCC']
# RES: PER (6784-6787) = ['Juan', 'Carlos', 'Zayas']
# TEST: PER (6431-6433) = ['Ignacio', 'Monreal']
# RES: ORG (6812-6814) = ['Tribunal', 'Constitucional']
# TEST: ORG (6446-6448) = ['Jutjat', 'Penal']
# RES: ORG (6831-6832) = ['Constitucional']
# TEST: CARDINAL (6449-6450) = ['2']
# RES: PER (6871-6873) = ['Josefina', 'Albert']
# TEST: LOC (6451-6452) = ['Tarragona']
# RES: PER (6881-6882) = ['Arola']
# TEST: DATE (6456-6459) = ['24', 'de', 'juliol']
# RES: ORG (6897-6900) = ['Convivencia', 'Cívica', 'Catalana']
# TEST: ORG (6469-6470) = ['URV']
# RES: ORG (6901-6902) = ['CCC']
# TEST: MISC (6475-6476) = ['PAAU']
# RES: PER (6904-6906) = ['Francisco', 'Caja']
# TEST: PER (6537-6538) = ['Monreal']
# RES: PER (6914-6915) = ['Albert']
# TEST: PER (6581-6582) = ['Albert']
# RES: ORG (6965-6966) = ['URV']
# TEST: PER (6600-6601) = ['Albert']
# RES: PER (6970-6972) = ['Josefina', 'Albert']
# TEST: MISC (6606-6607) = ['PAAU']
# RES: PER (6976-6979) = ['José', 'María', 'Fernández']
# TEST: MISC (6641-6642) = ['PAAU']
# RES: ORG (7035-7039) = ['Universitat', 'Rovira', 'i', 'Virgili']
# TEST: PER (6676-6677) = ['Albert']
# RES: ORG (7040-7041) = ['URV']
# TEST: PER (6686-6688) = ['Ignacio', 'Monreal']
# RES: PER (7043-7045) = ['Lluís', 'Arola']
# TEST: PER (6725-6729) = ['Defensor', 'd', 'el', 'Pueblo']
# RES: ORG (7058-7059) = ['PAAU']
# TEST: LOC (6756-6757) = ['Universitat']
# RES: PER (7061-7063) = ['Joan', 'Igual']
# TEST: PER (6758-6760) = ['Antoni', 'Huber']
# RES: PER (7085-7087) = ['Josefina', 'Albert']
# TEST: PER (6784-6787) = ['Juan', 'Carlos', 'Zayas']
# RES: DATE (7089-7092) = ["l'", 'any', '1998']
# TEST: ORG (6812-6814) = ['Tribunal', 'Constitucional']
# RES: ORG (7110-7111) = ['URV']
# TEST: ORG (6831-6832) = ['Constitucional']
# RES: TIME (7137-7140) = ["l'", 'any', 'següent']
# TEST: PER (6871-6873) = ['Josefina', 'Albert']
# RES: PER (7141-7142) = ['Albert']
# TEST: PER (6881-6882) = ['Arola']
# RES: ORG (7145-7146) = ['URV']
# TEST: PER (6883-6884) = ['Igual']
# RES: PER (7168-7172) = ['Defensor', 'd', 'el', 'Pueblo']
# TEST: ORG (6897-6900) = ['Convivencia', 'Cívica', 'Catalana']
# RES: ORG (7186-7189) = ['Departament', "d'", 'Estat']
# TEST: ORG (6901-6902) = ['CCC']
# RES: LOC (7191-7192) = ['EUA']
# TEST: PER (6904-6906) = ['Francisco', 'Caja']
# RES: DATE (7194-7197) = ["l'", 'any', '2000']
# TEST: PER (6914-6915) = ['Albert']
# RES: ORG (7208-7209) = ['ETA']
# TEST: ORG (6965-6966) = ['URV']
# RES: TIME (7209-7210) = ['després']
# TEST: PER (6970-6972) = ['Josefina', 'Albert']
# RES: ORG (7240-7241) = ['Europraxis']
# TEST: PER (6976-6979) = ['José', 'María', 'Fernández']
# RES: PER (7245-7246) = ['Indra']
# TEST: ORG (7035-7039) = ['Universitat', 'Rovira', 'i', 'Virgili']
# RES: DATE (7255-7260) = ["l'", 'abril', 'd', 'el', '2001']
# TEST: ORG (7040-7041) = ['URV']
# RES: PER (7261-7262) = ['Indra']
# TEST: PER (7043-7045) = ['Lluís', 'Arola']
# RES: MONEY (7264-7268) = ['42', 'milions', "d'", 'euros']
# TEST: MISC (7058-7059) = ['PAAU']
# RES: MONEY (7269-7273) = ['7.000', 'milions', 'de', 'pessetes']
# TEST: PER (7061-7063) = ['Joan', 'Igual']
# RES: PER (7277-7278) = ['Indra']
# TEST: TIME (7068-7071) = ['començaments', 'de', 'juliol']
# RES: TIME (7280-7281) = ['ahir']
# TEST: PER (7085-7087) = ['Josefina', 'Albert']
# RES: ORG (7298-7299) = ['Lear']
# TEST: DATE (7089-7092) = ["l'", 'any', '1998']
# RES: ORG (7301-7302) = ['Europraxis']
# TEST: ORG (7110-7111) = ['URV']
# RES: LOC (7310-7311) = ['Cervera']
# TEST: TIME (7137-7140) = ["l'", 'any', 'següent']
# RES: ORG (7319-7321) = ['Partners', 'Consulting']
# TEST: PER (7141-7142) = ['Albert']
# RES: PER (7334-7336) = ['Tinkle', 'Consultants']
# TEST: ORG (7145-7146) = ['URV']
# RES: PER (7346-7347) = ['Tinkle']
# TEST: PER (7168-7172) = ['Defensor', 'd', 'el', 'Pueblo']
# RES: ORG (7360-7361) = ['Lear']
# TEST: ORG (7186-7189) = ['Departament', "d'", 'Estat']
# RES: LOC (7370-7371) = ['Madrid']
# TEST: LOC (7191-7192) = ['EUA']
# RES: TIME (7375-7376) = ['ahir']
# TEST: DATE (7194-7197) = ["l'", 'any', '2000']
# RES: PER (7376-7378) = ['Joaquim', 'Triadú']
# TEST: ORG (7208-7209) = ['ETA']
# RES: ORG (7381-7382) = ['Presidència']
# TEST: TIME (7209-7210) = ['després']
# RES: ORG (7409-7410) = ['Generalitat']
# TEST: ORG (7240-7241) = ['Europraxis']
# RES: PER (7411-7413) = ['Jordi', 'Pujol']
# TEST: ORG (7245-7246) = ['Indra']
# RES: TIME (7416-7418) = ['aquest', 'divendres']
# TEST: DATE (7255-7260) = ["l'", 'abril', 'd', 'el', '2001']
# RES: MISC (7423-7425) = ['Any', 'Verdaguer']
# TEST: ORG (7261-7262) = ['Indra']
# RES: LOC (7437-7438) = ['Catalunya']
# TEST: MONEY (7264-7268) = ['42', 'milions', "d'", 'euros']
# RES: PER (7485-7486) = ['Pujol']
# TEST: MONEY (7269-7273) = ['7.000', 'milions', 'de', 'pessetes']
# RES: PER (7516-7518) = ['Jacint', 'Verdaguer']
# TEST: ORG (7277-7278) = ['Indra']
# RES: DATE (7519-7520) = ['1845']
# TEST: TIME (7280-7281) = ['ahir']
# RES: DATE (7521-7522) = ['1902']
# TEST: ORG (7298-7299) = ['Lear']
# RES: DATE (7533-7535) = ['segle', 'XIX']
# TEST: ORG (7301-7302) = ['Europraxis']
# RES: ORG (7627-7630) = ['Departament', "d'", 'Ensenyament']
# TEST: LOC (7310-7311) = ['Cervera']
# RES: ORG (7632-7633) = ['Generalitat']
# TEST: ORG (7319-7321) = ['Partners', 'Consulting']
# RES: TIME (7651-7652) = ['ara']
# TEST: ORG (7334-7336) = ['Tinkle', 'Consultants']
# RES: ORG (7653-7657) = ['Consell', 'Comarcal', "d'", 'Osona']
# TEST: ORG (7346-7347) = ['Tinkle']
# RES: ORG (7659-7662) = ['Universitat', 'de', 'Vic']
# TEST: ORG (7352-7353) = ['Andersen']
# RES: ORG (7663-7666) = ['Televisió', 'de', 'Catalunya']
# TEST: ORG (7360-7361) = ['Lear']
# RES: ORG (7678-7682) = ['Turisme', 'de', 'la', 'Generalitat']
# TEST: LOC (7370-7371) = ['Madrid']
# RES: LOC (7710-7711) = ['Catalunya']
# TEST: TIME (7375-7376) = ['ahir']
# RES: LOC (7717-7718) = ['Vic']
# TEST: PER (7376-7378) = ['Joaquim', 'Triadú']
# RES: LOC (7719-7720) = ['Folgueroles']
# TEST: ORG (7381-7382) = ['Presidència']
# RES: PER (7730-7732) = ['Mossèn', 'Cinto']
# TEST: ORG (7409-7410) = ['Generalitat']
# RES: PER (7768-7770) = ['Testimoni', 'Verdaguer']
# TEST: PER (7411-7413) = ['Jordi', 'Pujol']
# RES: ORG (7774-7778) = ['Teatre', 'Nacional', 'de', 'Catalunya']
# TEST: TIME (7416-7418) = ['aquest', 'divendres']
# RES: DATE (7781-7784) = ['29', 'de', 'juny']
# TEST: MISC (7423-7425) = ['Any', 'Verdaguer']
# RES: ORG (7806-7809) = ['Biblioteca', 'de', 'Catalunya']
# TEST: LOC (7437-7438) = ['Catalunya']
# RES: ORDINAL (7811-7812) = ['primera']
# TEST: PER (7485-7486) = ['Pujol']
# RES: LOC (7818-7819) = ['Vic']
# TEST: PER (7516-7518) = ['Jacint', 'Verdaguer']
# RES: DATE (7820-7823) = ['7', 'de', 'juny']
# TEST: DATE (7519-7520) = ['1845']
# RES: MISC (7828-7830) = ['Festa', 'Tipogràfica']
# TEST: DATE (7521-7522) = ['1902']
# RES: MISC (7835-7844) = ['Festa', 'd', 'els', 'Súpers', 'd', 'el', 'Club', 'Super', '3']
# TEST: DATE (7533-7535) = ['segle', 'XIX']
# RES: MISC (7845-7846) = ['TV3']
# TEST: ORG (7627-7633) = ['Departament', "d'", 'Ensenyament', 'de', 'la', 'Generalitat']
# RES: PER (7851-7852) = ['Verdaguer']
# TEST: ORG (7653-7657) = ['Consell', 'Comarcal', "d'", 'Osona']
# RES: PER (7872-7873) = ['Verdaguer']
# TEST: ORG (7659-7662) = ['Universitat', 'de', 'Vic']
# RES: LOC (7877-7878) = ['Berga']
# TEST: ORG (7663-7666) = ['Televisió', 'de', 'Catalunya']
# RES: DATE (7879-7882) = ['11', 'de', 'setembre']
# TEST: ORG (7678-7682) = ['Turisme', 'de', 'la', 'Generalitat']
# RES: LOC (7900-7901) = ['Atlàntida']
# TEST: CARDINAL (7703-7705) = ['quatre-centes', 'activitats']
# RES: TIME (7919-7922) = ['a', 'l', 'novembre']
# TEST: LOC (7710-7711) = ['Catalunya']
# RES: LOC (7924-7928) = ['Palau', 'de', 'la', 'Música']
# TEST: LOC (7717-7718) = ['Vic']
# RES: PER (7929-7931) = ['Jacint', 'Verdaguer']
# TEST: LOC (7719-7720) = ['Folgueroles']
# RES: LOC (7932-7933) = ['Folgueroles']
# TEST: PER (7730-7732) = ['Mossèn', 'Cinto']
# RES: LOC (7934-7935) = ['Osona']
# TEST: MISC (7768-7770) = ['Testimoni', 'Verdaguer']
# RES: DATE (7935-7936) = ['1845']
# TEST: ORG (7774-7778) = ['Teatre', 'Nacional', 'de', 'Catalunya']
# RES: LOC (7937-7938) = ['Vallvidrera']
# TEST: DATE (7781-7784) = ['29', 'de', 'juny']
# RES: LOC (7939-7940) = ['Barcelona']
# TEST: ORG (7806-7809) = ['Biblioteca', 'de', 'Catalunya']
# RES: DATE (7941-7942) = ['1902']
# TEST: ORDINAL (7811-7812) = ['primera']
# RES: LOC (7949-7950) = ['Vic']
# TEST: LOC (7818-7819) = ['Vic']
# RES: DATE (7950-7953) = ["l'", 'any', '1855']
# TEST: DATE (7820-7823) = ['7', 'de', 'juny']
# RES: CARDINAL (7956-7958) = ['20', 'anys']
# TEST: MISC (7828-7830) = ['Festa', 'Tipogràfica']
# RES: ORDINAL (7961-7962) = ['primers']
# TEST: MISC (7835-7839) = ['Festa', 'd', 'els', 'Súpers']
# RES: ORG (7962-7964) = ['Jocs', 'Florals']
# TEST: ORG (7841-7844) = ['Club', 'Super', '3']
# RES: LOC (7965-7966) = ['Barcelona']
# TEST: MISC (7845-7846) = ['TV3']
# RES: LOC (7981-7982) = ['Renaixença']
# TEST: MISC (7851-7856) = ['Verdaguer', 'i', 'les', 'llengües', 'europees']
# RES: DATE (7983-7985) = ['El', '1870']
# TEST: PER (7872-7873) = ['Verdaguer']
# RES: ORDINAL (7992-7993) = ['primera']
# TEST: LOC (7877-7878) = ['Berga']
# RES: LOC (7998-7999) = ['Vinyoles']
# TEST: DATE (7879-7882) = ['11', 'de', 'setembre']
# RES: LOC (8000-8001) = ['Orís']
# TEST: MISC (7900-7901) = ['Atlàntida']
# RES: LOC (8003-8004) = ['Osona']
# TEST: TIME (7919-7922) = ['a', 'l', 'novembre']
# RES: LOC (8034-8035) = ['Atlàntida']
# TEST: LOC (7924-7928) = ['Palau', 'de', 'la', 'Música']
# RES: DATE (8036-8037) = ['1977']
# TEST: PER (7929-7931) = ['Jacint', 'Verdaguer']
# RES: PER (8039-8041) = ['Mossèn', 'Cinto']
# TEST: LOC (7932-7933) = ['Folgueroles']
# RES: ORG (8053-8055) = ['Companyia', 'Transatlàntica']
# TEST: LOC (7934-7935) = ['Osona']
# RES: ORG (8061-8062) = ['Comillas']
# TEST: DATE (7935-7936) = ['1845']
# RES: DATE (8062-8065) = ["l'", 'any', '1874']
# TEST: LOC (7937-7938) = ['Vallvidrera']
# RES: LOC (8068-8069) = ['Barcelona']
# TEST: LOC (7939-7940) = ['Barcelona']
# RES: TIME (8081-8082) = ['Després']
# TEST: DATE (7941-7942) = ['1902']
# RES: TIME (8083-8085) = ['dos', 'anys']
# TEST: LOC (7949-7950) = ['Vic']
# RES: LOC (8093-8094) = ['Palau']
# TEST: DATE (7950-7953) = ["l'", 'any', '1855']
# RES: LOC (8098-8099) = ['Comillas']
# TEST: CARDINAL (7956-7958) = ['20', 'anys']
# RES: PER (8100-8102) = ['Palau', 'Moja']
# TEST: ORDINAL (7961-7962) = ['primers']
# RES: DATE (8113-8114) = ['1877']
# TEST: MISC (7962-7966) = ['Jocs', 'Florals', 'de', 'Barcelona']
# RES: DATE (8115-8116) = ['1893']
# TEST: MISC (7981-7982) = ['Renaixença']
# RES: LOC (8131-8132) = ['Atlàntida']
# TEST: DATE (7983-7985) = ['El', '1870']
# RES: MISC (8134-8135) = ['Canigó']
# TEST: ORDINAL (7992-7993) = ['primera']
# RES: DATE (8136-8137) = ['1886']
# TEST: LOC (7998-8001) = ['Vinyoles', "d'", 'Orís']
# RES: PER (8139-8140) = ['Verdaguer']
# TEST: LOC (8003-8004) = ['Osona']
# RES: ORG (8160-8163) = ['Manteniment', 'i', 'Obres']
# TEST: MISC (8034-8035) = ['Atlàntida']
# RES: ORG (8165-8168) = ['Ajuntament', 'de', 'Lleida']
# TEST: DATE (8036-8037) = ['1977']
# RES: PER (8169-8171) = ['Josep', 'Montserrat']
# TEST: PER (8039-8041) = ['Mossèn', 'Cinto']
# RES: LOC (8201-8202) = ['Montserrat']
# TEST: ORG (8053-8055) = ['Companyia', 'Transatlàntica']
# RES: TIME (8215-8216) = ['ahir']
# TEST: LOC (8061-8062) = ['Comillas']
# RES: PER (8224-8226) = ['Jacinto', 'Pernia']
# TEST: DATE (8062-8065) = ["l'", 'any', '1874']
# RES: LOC (8254-8255) = ['Montserrat']
# TEST: LOC (8068-8069) = ['Barcelona']
# RES: TIME (8264-8267) = ['fa', 'uns', 'dies']
# TEST: TIME (8081-8082) = ['Després']
# RES: ORG (8278-8279) = ['Escorxador']
# ...
# TEST: LOC (18301-18302) = ['València']
# RES: DATE (18394-18397) = ['18', 'de', 'juny']
# TEST: LOC (18304-18305) = ['Principat']
# RES: CARDINAL (18399-18400) = ['20h']
# TEST: LOC (18307-18308) = ['Catalunya']
# RES: LOC (18402-18410) = ['Auditori', 'Josep', 'Viader', 'de', 'la', 'Casa', 'de', 'Cultura']
# TEST: DATE (18321-18324) = ['21', 'de', 'juny']
# RES: LOC (18420-18423) = ['Selva', 'Big', 'Band']
# TEST: LOC (18327-18331) = ['Nummunit', 'de', 'la', 'Devesa']
# RES: TIME (18425-18426) = ['divendres']
# TEST: ORG (18342-18344) = ['Quartet', 'Anònim']
# RES: DATE (18426-18429) = ['20', 'de', 'juny']
# TEST: PER (18355-18357) = ['Josep', 'Puigbó']
# RES: CARDINAL (18431-18432) = ['20h']
# TEST: MISC (18364-18365) = ['Premis']
# RES: MISC (18434-18439) = ['Plaça', 'Jordi', 'de', 'Sant', 'Jordi']
# TEST: MISC (18372-18381) = ['Joaquim', 'Ruyra', ',', 'el', 'patriarca', 'de', 'la', 'prosa', 'catalana']
# RES: PER (18447-18449) = ['Esteve', 'Vilanova']
# TEST: PER (18385-18387) = ['Jaume', 'Reixach']
# RES: LOC (18454-18455) = ['Girona']
# TEST: TIME (18393-18394) = ['dimecres']
# RES: TIME (18455-18457) = ['una', 'setmana']
# TEST: DATE (18394-18397) = ['18', 'de', 'juny']
# RES: ORG (18488-18490) = ['Catalunya', 'Ràdio']
# TEST: DATE (18399-18400) = ['20h']
# RES: LOC (18493-18496) = ['Platja', 'de', 'llum']
# TEST: LOC (18402-18410) = ['Auditori', 'Josep', 'Viader', 'de', 'la', 'Casa', 'de', 'Cultura']
# RES: PER (18497-18499) = ['Rafa', 'Xambó']
# TEST: ORG (18420-18423) = ['Selva', 'Big', 'Band']
# RES: PER (18505-18506) = ['Gossos']
# TEST: TIME (18425-18426) = ['divendres']
# RES: MISC (18508-18510) = ['Sense', 'terra']
# TEST: DATE (18426-18429) = ['20', 'de', 'juny']
# RES: LOC (18511-18512) = ['Obrint']
# TEST: DATE (18431-18432) = ['20h']
# RES: PER (18520-18522) = ['Adrià', 'Puntí']
# TEST: LOC (18434-18439) = ['Plaça', 'Jordi', 'de', 'Sant', 'Jordi']
# RES: ORG (18524-18525) = ['Somiatruites']
# TEST: PER (18447-18449) = ['Esteve', 'Vilanova']
# RES: PER (18526-18528) = ['Albert', 'Pla']
# TEST: LOC (18454-18455) = ['Girona']
# RES: LOC (18530-18532) = ['Caos', 'n.13']
# TEST: MISC (18459-18460) = ['Lletres']
# RES: LOC (18533-18534) = ['Falsterbo-Marí']
# TEST: ORG (18488-18490) = ['Catalunya', 'Ràdio']
# RES: MISC (18536-18539) = ['Ens', 'veiem', 'a']
# TEST: MISC (18493-18496) = ['Platja', 'de', 'llum']
# RES: LOC (18539-18540) = ['Folegandres']
# TEST: PER (18497-18499) = ['Rafa', 'Xambó']
# RES: PER (18541-18543) = ['Lluís', 'Llach']
# TEST: MISC (18501-18504) = ['Com', 'si', 'res']
# RES: PER (18545-18547) = ['Merry', 'Christmes']
# TEST: ORG (18505-18506) = ['Gossos']
# RES: PER (18548-18550) = ['Eduard', 'Canimas']
# TEST: MISC (18508-18510) = ['Sense', 'terra']
# RES: PER (18556-18558) = ['Antònia', 'Font']
# TEST: ORG (18511-18513) = ['Obrint', 'pas']
# RES: PER (18560-18561) = ['Remigi']
# TEST: MISC (18515-18519) = ['De', 'muda', 'en', 'muda']
# RES: PER (18562-18564) = ['Òscar', 'Briz']
# TEST: PER (18520-18522) = ['Adrià', 'Puntí']
# RES: LOC (18569-18570) = ['Escala']
# TEST: MISC (18524-18525) = ['Somiatruites']
# RES: PER (18571-18573) = ['Josep', 'Tero']
# TEST: PER (18526-18528) = ['Albert', 'Pla']
# RES: MISC (18575-18578) = ['En', 'la', 'rebequeria']
# TEST: MISC (18530-18532) = ['Caos', 'n.13']
# RES: PER (18579-18581) = ['Roger', 'Mas']
# TEST: ORG (18533-18534) = ['Falsterbo-Marí']
# RES: PER (18600-18601) = ['cerverí@catradio.com']
# TEST: MISC (18536-18540) = ['Ens', 'veiem', 'a', 'Folegandres']
# RES: ORG (18603-18604) = ['Executiu']
# TEST: PER (18541-18543) = ['Lluís', 'Llach']
# RES: TIME (18606-18608) = ['un', 'any']
# TEST: MISC (18545-18547) = ['Merry', 'Christmes']
# RES: PER (18613-18614) = ['Sánchez']
# TEST: PER (18548-18550) = ['Eduard', 'Canimas']
# RES: CARDINAL (18616-18618) = ['31', 'anys']
# TEST: MISC (18552-18555) = ['Dins', 'aquest', 'iglú']
# RES: DATE (18621-18626) = ['el', 'maig', 'd', 'el', '1998']
# TEST: PER (18556-18558) = ['Antònia', 'Font']
# RES: ORG (18627-18629) = ['Secció', 'Cinquena']
# TEST: PER (18560-18561) = ['Remigi']
# RES: ORG (18631-18634) = ['Audiència', 'de', 'Barcelona']
# TEST: PER (18562-18564) = ['Òscar', 'Briz']
# RES: PER (18641-18643) = ['Carlos', 'Sánchez']
# TEST: MISC (18566-18570) = ['Quan', 'dic', "l'", 'Escala']
# RES: PER (18648-18649) = ['Model']
# TEST: PER (18571-18573) = ['Josep', 'Tero']
# RES: LOC (18650-18651) = ['Barcelona']
# TEST: MISC (18575-18578) = ['En', 'la', 'rebequeria']
# RES: DATE (18652-18657) = ['4', 'de', 'març', 'de', '1998']
# TEST: PER (18579-18581) = ['Roger', 'Mas']
# RES: TIME (18662-18664) = ['quatre', 'anys']
# TEST: ORG (18603-18604) = ['Executiu']
# RES: CARDINAL (18665-18667) = ['10', 'mesos']
# TEST: TIME (18606-18608) = ['un', 'any']
# RES: DATE (18674-18676) = ['el', '1988']
# TEST: PER (18613-18614) = ['Sánchez']
# RES: TIME (18679-18681) = ['un', 'any']
# TEST: CARDINAL (18616-18618) = ['31', 'anys']
# RES: TIME (18681-18682) = ['abans']
# TEST: DATE (18621-18626) = ['el', 'maig', 'd', 'el', '1998']
# RES: MONEY (18685-18687) = ['3.500', 'pessetes']
# TEST: ORG (18627-18629) = ['Secció', 'Cinquena']
# RES: ORG (18707-18709) = ['Tribunal', 'Suprem']
# TEST: ORG (18631-18634) = ['Audiència', 'de', 'Barcelona']
# RES: DATE (18709-18711) = ['el', '1991']
# TEST: PER (18641-18643) = ['Carlos', 'Sánchez']
# RES: DATE (18734-18738) = ['març', 'd', 'el', '1998']
# TEST: LOC (18648-18649) = ['Model']
# RES: MISC (18755-18756) = ['DNI']
# TEST: LOC (18650-18651) = ['Barcelona']
# RES: PER (18771-18773) = ['Carlos', 'Sánchez']
# TEST: DATE (18652-18657) = ['4', 'de', 'març', 'de', '1998']
# RES: DATE (18779-18784) = ['19', 'de', 'març', 'de', '1998']
# TEST: CARDINAL (18665-18667) = ['10', 'mesos']
# RES: ORG (18789-18791) = ['Secció', 'Cinquena']
# TEST: DATE (18674-18676) = ['el', '1988']
# RES: ORG (18793-18796) = ['Audiència', 'de', 'Barcelona']
# TEST: TIME (18681-18682) = ['abans']
# RES: ORG (18826-18827) = ['Policia']
# TEST: MONEY (18685-18687) = ['3.500', 'pessetes']
# RES: TIME (18835-18836) = ['mai']
# TEST: ORG (18707-18709) = ['Tribunal', 'Suprem']
# RES: DATE (18845-18848) = ['19', 'de', 'març']
# TEST: DATE (18709-18711) = ['el', '1991']
# RES: ORG (18850-18851) = ['Generalitat']
# TEST: DATE (18734-18738) = ['març', 'd', 'el', '1998']
# RES: PER (18856-18857) = ['Sánchez']
# TEST: TIME (18743-18744) = ['sempre']
# RES: ORG (18864-18866) = ['Benestar', 'Social']
# TEST: MISC (18755-18756) = ['DNI']
# RES: PER (18867-18869) = ['Antoni', 'Comas']
# TEST: PER (18771-18773) = ['Carlos', 'Sánchez']
# RES: DATE (18894-18896) = ['el', '1987']
# TEST: DATE (18779-18784) = ['19', 'de', 'març', 'de', '1998']
# RES: PER (18897-18899) = ['Carlos', 'Sánchez']
# TEST: ORG (18789-18791) = ['Secció', 'Cinquena']
# RES: TIME (18903-18905) = ['sis', 'mesos']
# TEST: ORG (18793-18796) = ['Audiència', 'de', 'Barcelona']
# RES: MONEY (18912-18914) = ['3.500', 'pessetes']
# TEST: ORG (18826-18827) = ['Policia']
# RES: CARDINAL (18933-18935) = ['19', 'anys']
# TEST: TIME (18835-18836) = ['mai']
# RES: PER (18936-18937) = ['Sánchez']
# TEST: DATE (18845-18848) = ['19', 'de', 'març']
# RES: ORG (18999-19000) = ['Generalitat']
# TEST: ORG (18850-18851) = ['Generalitat']
# RES: CARDINAL (19005-19007) = ['1.500', 'places']
# TEST: PER (18856-18857) = ['Sánchez']
# RES: LOC (19011-19013) = ['Can', 'Margarit']
# TEST: ORG (18864-18866) = ['Benestar', 'Social']
# RES: ORG (19021-19022) = ['Brians']
# TEST: PER (18867-18869) = ['Antoni', 'Comas']
# RES: LOC (19024-19027) = ['Sant', 'Esteve', 'Sesrovires']
# TEST: DATE (18894-18896) = ['el', '1987']
# RES: TIME (19033-19034) = ['ahir']
# TEST: PER (18897-18899) = ['Carlos', 'Sánchez']
# RES: ORDINAL (19041-19042) = ['primera']
# TEST: MONEY (18912-18914) = ['3.500', 'pessetes']
# RES: TIME (19053-19054) = ['abans']
# TEST: CARDINAL (18933-18935) = ['19', 'anys']
# RES: DATE (19059-19060) = ['2003']
# TEST: PER (18936-18937) = ['Sánchez']
# RES: TIME (19064-19067) = ["l'", 'any', 'següent']
# TEST: ORG (18999-19000) = ['Generalitat']
# RES: CARDINAL (19090-19092) = ['250', 'places']
# TEST: CARDINAL (19005-19007) = ['1.500', 'places']
# RES: ORG (19093-19096) = ['Aigües', 'de', 'Barcelona']
# TEST: LOC (19011-19013) = ['Can', 'Margarit']
# RES: CARDINAL (19098-19100) = ['16.828', 'milions']
# TEST: ORG (19021-19022) = ['Brians']
# RES: DATE (19100-19102) = ['el', '1999']
# TEST: LOC (19024-19027) = ['Sant', 'Esteve', 'Sesrovires']
# RES: PERCENT (19112-19113) = ['25,2%']
# TEST: TIME (19033-19034) = ['ahir']
# RES: DATE (19116-19117) = ['1998']
# TEST: ORDINAL (19041-19042) = ['primera']
# RES: DATE (19118-19121) = ["L'", 'any', '1999']
# TEST: TIME (19053-19054) = ['abans']
# RES: MONEY (19144-19148) = ['88.522', 'milions', 'de', 'pessetes']
# TEST: DATE (19059-19060) = ['2003']
# RES: ORG (19149-19150) = ['EMOS']
# TEST: TIME (19064-19067) = ["l'", 'any', 'següent']
# RES: CARDINAL (19166-19168) = ['283.297', 'milions']
# TEST: CARDINAL (19090-19092) = ['250', 'places']
# RES: PERCENT (19174-19175) = ['18,7%']
# TEST: ORG (19093-19096) = ['Aigües', 'de', 'Barcelona']
# RES: CARDINAL (19180-19182) = ['97.455', 'milions']
# TEST: CARDINAL (19098-19100) = ['16.828', 'milions']
# RES: LOC (19196-19197) = ['Eixample']
# TEST: DATE (19100-19102) = ['el', '1999']
# RES: CARDINAL (19295-19297) = ['83.600', 'milions']
# TEST: PERCENT (19112-19113) = ['25,2%']
# RES: CARDINAL (19310-19312) = ['300.000', 'milions']
# TEST: DATE (19116-19117) = ['1998']
# RES: ORG (19326-19327) = ['Iberdrola']
# TEST: DATE (19118-19121) = ["L'", 'any', '1999']
# RES: PERCENT (19330-19331) = ['3,5%']
# TEST: MONEY (19144-19148) = ['88.522', 'milions', 'de', 'pessetes']
# RES: ORG (19332-19333) = ['Repsol']
# TEST: ORG (19149-19150) = ['EMOS']
# RES: MONEY (19334-19338) = ['83.668', 'milions', 'de', 'pessetes']
# TEST: CARDINAL (19166-19168) = ['283.297', 'milions']
# RES: DATE (19353-19358) = ['el', 'gener', 'd', 'el', '1997']
# TEST: PERCENT (19174-19175) = ['18,7%']
# RES: TIME (19364-19365) = ['ahir']
# TEST: CARDINAL (19180-19182) = ['97.455', 'milions']
# RES: ORG (19367-19374) = ['Comissió', 'Nacional', 'd', 'el', 'Mercat', 'de', 'Valors']
# TEST: LOC (19196-19197) = ['Eixample']
# RES: CARDINAL (19380-19382) = ['300.000', 'milions']
# TEST: TIME (19290-19291) = ['mai']
# RES: ORG (19407-19408) = ['Iberdrola']
# TEST: CARDINAL (19295-19297) = ['83.600', 'milions']
# RES: QUANTITY (19452-19454) = ['3.000', 'megawatts']
# TEST: CARDINAL (19310-19312) = ['300.000', 'milions']
# RES: ORG (19467-19468) = ['Iberoamèrica']
# TEST: ORG (19326-19327) = ['Iberdrola']
# RES: ORG (19489-19490) = ['Iberdrola']
# TEST: PERCENT (19330-19331) = ['3,5%']
# RES: ORG (19491-19492) = ['Repsol']
# TEST: ORG (19332-19333) = ['Repsol']
# RES: DATE (19494-19500) = ['28', 'de', 'gener', 'd', 'el', '1997']
# TEST: MONEY (19334-19338) = ['83.668', 'milions', 'de', 'pessetes']
# RES: ORG (19520-19521) = ['Endesa']
# TEST: DATE (19353-19358) = ['el', 'gener', 'd', 'el', '1997']
# RES: LOC (19532-19533) = ['Llatinoamèrica']
# TEST: TIME (19364-19365) = ['ahir']
# RES: ORG (19537-19538) = ['Iberdrola']
# TEST: ORG (19367-19374) = ['Comissió', 'Nacional', 'd', 'el', 'Mercat', 'de', 'Valors']
# RES: ORG (19539-19540) = ['Repsol']
# TEST: CARDINAL (19380-19382) = ['300.000', 'milions']
# RES: ORG (19552-19553) = ['Endesa']
# TEST: ORG (19407-19408) = ['Iberdrola']
# RES: TIME (19555-19557) = ['el', 'gener']
# TEST: QUANTITY (19452-19454) = ['3.000', 'megawatts']
# RES: PERCENT (19561-19562) = ['3,64%']
# TEST: LOC (19467-19468) = ['Iberoamèrica']
# RES: CARDINAL (19566-19568) = ['82.000', 'milions']
# TEST: ORG (19489-19490) = ['Iberdrola']
# RES: ORG (19578-19579) = ['Repsol']
# TEST: ORG (19491-19492) = ['Repsol']
# RES: PERCENT (19602-19603) = ['85%']
# TEST: DATE (19494-19500) = ['28', 'de', 'gener', 'd', 'el', '1997']
# RES: ORG (19606-19607) = ['YPF']
# TEST: ORG (19520-19521) = ['Endesa']
# RES: ORG (19608-19609) = ['Iberdrola']
# TEST: LOC (19532-19533) = ['Llatinoamèrica']
# RES: ORG (19611-19612) = ['Repsol']
# TEST: ORG (19537-19538) = ['Iberdrola']
# RES: LOC (19623-19624) = ['Espanya']
# TEST: ORG (19539-19540) = ['Repsol']
# RES: LOC (19632-19633) = ['BP-Amoco']
# TEST: ORG (19552-19553) = ['Endesa']
# RES: MISC (19640-19641) = ['Trinitat']
# TEST: PERCENT (19561-19562) = ['3,64%']
# RES: ORG (19642-19643) = ['Tobago']
# TEST: CARDINAL (19566-19568) = ['82.000', 'milions']
# RES: ORG (19644-19645) = ['Iberdrola']
# TEST: ORG (19578-19579) = ['Repsol']
# RES: ORG (19653-19654) = ['Repsol']
# TEST: MISC (19596-19597) = ['OPA']
# RES: ORG (19667-19668) = ['Iberdrola']
# TEST: PERCENT (19602-19603) = ['85%']
# RES: ORG (19678-19679) = ['Repsol']
# TEST: ORG (19606-19607) = ['YPF']
# RES: ORG (19683-19685) = ['Gas', 'Natural']
# TEST: ORG (19608-19609) = ['Iberdrola']
# RES: PERCENT (19687-19688) = ['45,3%']
# TEST: ORG (19611-19612) = ['Repsol']
# RES: ORG (19690-19691) = ['BBV']
# TEST: LOC (19623-19624) = ['Espanya']
# RES: ORG (19697-19698) = ['Repsol']
# TEST: ORG (19632-19633) = ['BP-Amoco']
# RES: PERCENT (19703-19704) = ['9,5%']
# TEST: LOC (19640-19643) = ['Trinitat', 'i', 'Tobago']
# RES: ORG (19710-19711) = ['Iberdrola']
# TEST: ORG (19644-19645) = ['Iberdrola']
# RES: PERCENT (19721-19722) = ['7%']
# TEST: ORG (19653-19654) = ['Repsol']
# RES: ORG (19724-19725) = ['Caixa']
# TEST: ORG (19667-19668) = ['Iberdrola']
# RES: ORG (19731-19732) = ['Repsol']
# TEST: ORG (19678-19679) = ['Repsol']
# RES: ORG (19741-19742) = ['BBV']
# TEST: ORG (19683-19685) = ['Gas', 'Natural']
# RES: PERCENT (19745-19746) = ['7,6%']
# TEST: PERCENT (19687-19688) = ['45,3%']
# RES: PERCENT (19753-19754) = ['1,9%']
# TEST: ORG (19690-19691) = ['BBV']
# RES: LOC (19761-19762) = ['Repinves']
# TEST: ORG (19697-19698) = ['Repsol']
# RES: ORG (19767-19769) = ['La', 'Caixa']
# TEST: PERCENT (19703-19704) = ['9,5%']
# RES: LOC (19770-19772) = ['La', 'Kutxa']
# TEST: ORG (19710-19711) = ['Iberdrola']
# RES: ORG (19773-19775) = ['Caixa', 'Catalunya']
# TEST: PERCENT (19721-19722) = ['7%']
# RES: PERCENT (19779-19780) = ['6,1%']
# TEST: ORG (19723-19725) = ['La', 'Caixa']
# RES: PER (19785-19786) = ['Pemex']
# TEST: ORG (19731-19732) = ['Repsol']
# RES: PERCENT (19789-19790) = ['5%']
# TEST: ORG (19741-19742) = ['BBV']
# RES: ORG (19791-19792) = ['Endesa']
# TEST: PERCENT (19745-19746) = ['7,6%']
# RES: PERCENT (19795-19796) = ['3,6%']
# TEST: PERCENT (19753-19754) = ['1,9%']
# RES: TIME (19798-19799) = ['ara']
# TEST: ORG (19761-19762) = ['Repinves']
# RES: ORG (19799-19800) = ['Iberdrola']
# TEST: ORG (19767-19769) = ['La', 'Caixa']
# RES: PERCENT (19803-19804) = ['3,5%']
# TEST: ORG (19770-19772) = ['La', 'Kutxa']
# RES: ORG (19813-19814) = ['EDP']
# TEST: ORG (19773-19775) = ['Caixa', 'Catalunya']
# RES: ORG (19823-19824) = ['Estat']
# TEST: PERCENT (19779-19780) = ['6,1%']
# RES: PERCENT (19830-19831) = ['5%']
# TEST: ORG (19785-19786) = ['Pemex']
# RES: ORG (19835-19836) = ['Iberdrola']
# TEST: PERCENT (19789-19790) = ['5%']
# RES: ORG (19856-19857) = ['Iberdrola']
# TEST: ORG (19791-19792) = ['Endesa']
# RES: PERCENT (19860-19861) = ['3%']
# TEST: PERCENT (19795-19796) = ['3,6%']
# RES: CARDINAL (19883-19884) = ['00']
# TEST: TIME (19798-19799) = ['ara']
# RES: CARDINAL (19886-19887) = ['95']
# TEST: ORG (19799-19800) = ['Iberdrola']
# RES: CARDINAL (19889-19890) = ['99']
# TEST: PERCENT (19803-19804) = ['3,5%']
# RES: LOC (19921-19923) = ['Estats', 'Units']
# TEST: ORG (19813-19814) = ['EDP']
# RES: CARDINAL (19934-19935) = ['2,99']
# TEST: ORG (19823-19824) = ['Estat']
# RES: CARDINAL (19936-19937) = ['8,95']
# TEST: PERCENT (19830-19831) = ['5%']
# RES: MONEY (19965-19967) = ['2,73', 'euros']
# TEST: ORG (19835-19836) = ['Iberdrola']
# RES: MONEY (19974-19976) = ['2,99', 'euros']
# TEST: ORG (19856-19857) = ['Iberdrola']
# RES: PERCENT (19987-19988) = ['9%']
# TEST: PERCENT (19860-19861) = ['3%']
# RES: TIME (20010-20011) = ['ara']
# TEST: CARDINAL (19883-19884) = ['00']
# RES: MONEY (20029-20031) = ['20', 'cèntims']
# TEST: CARDINAL (19886-19887) = ['95']
# RES: PER (20039-20040) = ['refresc']
# TEST: CARDINAL (19889-19890) = ['99']
# RES: PERCENT (20054-20055) = ['66%']
# TEST: LOC (19921-19923) = ['Estats', 'Units']
# RES: PERCENT (20057-20058) = ['11%']
# TEST: CARDINAL (19934-19935) = ['2,99']
# RES: -
# TEST: CARDINAL (19936-19937) = ['8,95']
# RES: -
# TEST: MONEY (19965-19967) = ['2,73', 'euros']
# RES: -
# TEST: MONEY (19974-19976) = ['2,99', 'euros']
# RES: -
# TEST: PERCENT (19987-19988) = ['9%']
# RES: -
# TEST: TIME (20010-20011) = ['ara']
# RES: -
# TEST: MONEY (20029-20031) = ['20', 'cèntims']
# RES: -
# TEST: PERCENT (20054-20055) = ['66%']
# RES: -
# TEST: PERCENT (20057-20058) = ['11%']

# %%
# Transformem les instàncies d'EntitatNomenada a tuples per poder operar-hi fàcilment.
entitats_nomenades_res_tuples = set(map(lambda x: x.a_tupla(), entitats_nomenades_res))
entitats_nomenades_test_tuples = set(map(lambda x: x.a_tupla(), entitats_nomenades_test))

# Operem amb els conjunts per obtenir la intersecció i subtraccions.
true_positives = entitats_nomenades_res_tuples & entitats_nomenades_test_tuples
false_positives = entitats_nomenades_res_tuples - entitats_nomenades_test_tuples
false_negatives = entitats_nomenades_test_tuples - entitats_nomenades_res_tuples

# Obtenim les mètriques de cada categoria.
metrica_tp = len(true_positives)
metrica_fp = len(false_positives)
metrica_fn = len(false_negatives)

# Obtenim les mètriques complexes.
precisio = metrica_tp / (metrica_tp + metrica_fp)
reclam = metrica_tp / (metrica_tp + metrica_fn)
f1 = 2 * precisio * reclam / (precisio + reclam)

print("Autèntics positius:", metrica_tp)
print("Falsos positius:", metrica_fp)
print("Falsos negatius:", metrica_fn)
print("=========")
print("Precisió: {}%".format(int(precisio * 10000) / 100))
print("Reclam: {}%".format(int(reclam * 10000) / 100))
print("Mesura F: {}%".format(int(f1 * 10000) / 100))
# Out:
# Autèntics positius: 1333
# Falsos positius: 288
# Falsos negatius: 296
# =========
# Precisió: 82.23%
# Reclam: 81.82%
# Mesura F: 82.03%

# %%
for en in false_negatives:
    print(en)
# Out:
# ('CARDINAL', 5948, 2, ('100', 'dies'))
# ('PER', 5843, 1, ('Ardanza',))
# ('PER', 5375, 1, ('VIP',))
# ('TIME', 11341, 1, ('desembre',))
# ('LOC', 10731, 1, ('Brest',))
# ('PER', 702, 1, ('Llaràs',))
# ('PER', 11168, 1, ('Belot',))
# ('LOC', 18648, 1, ('Model',))
# ('LOC', 14610, 1, ('Carnota',))
# ('ORG', 19723, 2, ('La', 'Caixa'))
# ('ORG', 13378, 1, ('Pimecsefes',))
# ('ORG', 19770, 2, ('La', 'Kutxa'))
# ('LOC', 16648, 1, ('Barcelona',))
# ('MISC', 10551, 7, ('Encesa', 'd', 'el', 'signe', 'd', 'el', 'zodíac-Cranc'))
# ('CARDINAL', 3277, 1, ('400.000',))
# ('CARDINAL', 2797, 1, ('2.000.000',))
# ('ORG', 18200, 5, ('Fundació', 'Prudenci', 'Bertrana', 'de', 'Girona'))
# ('MISC', 6606, 1, ('PAAU',))
# ('MISC', 5037, 2, ('Ona', 'Catalana'))
# ('LOC', 5896, 1, ('Donington',))
# ('ORG', 13996, 1, ('Xfera',))
# ('LOC', 1293, 2, ('Universitat', 'Pontifícia'))
# ('MISC', 6641, 1, ('PAAU',))
# ('ORG', 14745, 5, ('Agrupació', 'de', 'Voluntaris', 'de', 'Reus'))
# ('LOC', 9463, 3, ('Hospital', 'do', 'Meixoeiro'))
# ('ORG', 12040, 1, ('Cedel',))
# ('MISC', 10611, 10, ('Castell', 'blanc', 'de', 'la', 'raó', 'i', 'vermell', 'de', 'la', 'follia'))
# ('LOC', 8061, 1, ('Comillas',))
# ('MISC', 11498, 1, ('Lipobay',))
# ('PER', 17995, 4, ('President', 'de', 'la', 'Fundació'))
# ('ORG', 4618, 1, ('Parlament',))
# ('LOC', 11311, 2, ('Saint', 'Louis'))
# ('ORG', 4291, 3, ('Parlament', 'de', 'Catalunya'))
# ('ORG', 13610, 4, ('Delegació', 'd', 'el', 'Govern'))
# ('MISC', 12023, 3, ('Borsa', 'de', 'Frankfurt'))
# ('ORG', 18511, 2, ('Obrint', 'pas'))
# ('ORG', 4287, 2, ('Comissió', 'Primera'))
# ('ORG', 6151, 1, ('Uras',))
# ('TIME', 1865, 4, ('dijous', 'a', 'la', 'nit'))
# ('ORG', 11240, 1, ('DaimlerChrysler',))
# ('MISC', 13160, 5, ('Nit', 'de', 'llum', 'i', 'foc'))
# ('MISC', 15102, 1, ('Conys',))
# ('CARDINAL', 11889, 2, ('248.489', 'unitats'))
# ('MISC', 10527, 2, ('Tres', 'pets'))
# ('PER', 17185, 1, ('Gunilla',))
# ('ORG', 12030, 1, ('Clearstream',))
# ('LOC', 14612, 2, ('A', 'Coruña'))
# ('ORG', 14916, 1, ('Amfiteatre',))
# ('MISC', 1678, 4, ('No', 'hi', 'ha', 'dret'))
# ('LOC', 19467, 1, ('Iberoamèrica',))
# ('MISC', 18135, 3, ('Premi', 'Prudenci', 'Bertrana'))
# ('PER', 3025, 2, ('Le', 'Pen'))
# ('PER', 17170, 1, ('Gunilla',))
# ('PER', 6008, 1, ('Marqués',))
# ('CARDINAL', 8542, 1, ('132.100',))
# ('MISC', 11606, 1, ('Lipobay',))
# ('MISC', 12735, 2, ('Polar', 'Lander'))
# ('PER', 6354, 1, ('Igual',))
# ('ORG', 11905, 1, ('Toyota',))
# ('MISC', 18566, 4, ('Quan', 'dic', "l'", 'Escala'))
# ('MISC', 17963, 4, ('Premis', 'Literaris', 'de', 'Girona'))
# ('LOC', 10773, 1, ('Brest',))
# ('LOC', 29, 1, ('Kerman',))
# ('LOC', 2486, 1, ('Rambouillet',))
# ('MISC', 19596, 1, ('OPA',))
# ('TIME', 9836, 1, ('juliol',))
# ('MISC', 12892, 2, ('Mars', 'Pathfinder'))
# ('LOC', 17620, 3, ('Morera', 'de', 'Montsant'))
# ('CARDINAL', 11711, 1, ('12',))
# ('LOC', 15335, 1, ('Gavà',))
# ('PER', 9032, 1, ('Navío',))
# ('CARDINAL', 3266, 2, ('40.000', 'persones'))
# ('LOC', 15511, 6, ('Universitat', 'Protestant', 'de', 'Teologia', 'de', 'Roma'))
# ('ORG', 13418, 1, ('Pimecsefes',))
# ('CARDINAL', 7703, 2, ('quatre-centes', 'activitats'))
# ('LOC', 11309, 1, ('Newark',))
# ('MISC', 18372, 9, ('Joaquim', 'Ruyra', ',', 'el', 'patriarca', 'de', 'la', 'prosa', 'catalana'))
# ('ORG', 19785, 1, ('Pemex',))
# ('MISC', 16938, 2, ('Lasius', 'neglectus'))
# ('ORG', 14216, 2, ('Cambra', 'Alta'))
# ('TIME', 16972, 1, ('juliol',))
# ('MISC', 18459, 1, ('Lletres',))
# ('ORG', 1433, 6, ('Madres', 'de', 'la', 'Plaza', 'de', 'Mayo'))
# ('LOC', 14811, 1, ('Finisterre',))
# ('CARDINAL', 1495, 2, ('23', 'anys'))
# ('MISC', 7835, 4, ('Festa', 'd', 'els', 'Súpers'))
# ('TIME', 9838, 1, ('setembre',))
# ('ORG', 3933, 5, ('Merril', 'Lynch', 'Mercury', 'Asset', 'Management'))
# ('PER', 2995, 2, ('Le', 'Pen'))
# ('PER', 6883, 1, ('Igual',))
# ('ORG', 18505, 1, ('Gossos',))
# ('DATE', 18431, 1, ('20h',))
# ('PER', 1196, 1, ('Tobin',))
# ('MISC', 9477, 1, ('Aspergillus',))
# ('LOC', 5369, 2, ('Sala', 'Goya'))
# ('PER', 5517, 1, ('Aguirre',))
# ('DATE', 12194, 5, ('a', 'principis', 'd', 'els', '90'))
# ('CARDINAL', 2259, 1, ('1.638',))
# ('CARDINAL', 9089, 1, ('3',))
# ('CARDINAL', 10229, 2, ('col·laboradors', "d'"))
# ('MISC', 1905, 1, ('KL-742',))
# ('MISC', 13030, 2, ('Colònia', 'Güell'))
# ('ORG', 15391, 1, ('Acerinox',))
# ('DATE', 18399, 1, ('20h',))
# ('PER', 9254, 1, ('Arnó',))
# ('LOC', 8100, 2, ('Palau', 'Moja'))
# ('MISC', 18072, 5, ('Ramon', 'Muntaner', 'de', 'Literatura', 'Juvenil'))
# ('CARDINAL', 3258, 2, ('50.000', 'persones'))
# ('CARDINAL', 15947, 1, ('6',))
# ('LOC', 16433, 1, ('Seva',))
# ('MISC', 13053, 2, ('Park', 'Güell'))
# ('PER', 6271, 1, ('Marqués',))
# ('ORG', 13914, 1, ('Aucat',))
# ('MISC', 659, 3, ('Quan', 'ens', 'veiem'))
# ('MISC', 14943, 1, ('Conys',))
# ('MISC', 15491, 6, ('Assemblea', 'd', 'el', 'Poble', 'de', 'Déu'))
# ('ORG', 7627, 6, ('Departament', "d'", 'Ensenyament', 'de', 'la', 'Generalitat'))
# ('MISC', 12740, 3, ('Deep', 'Space', '2'))
# ('TIME', 11332, 1, ('15',))
# ('MISC', 6475, 1, ('PAAU',))
# ('LOC', 19640, 3, ('Trinitat', 'i', 'Tobago'))
# ('ORG', 13341, 1, ('Generalitat',))
# ('ORG', 5015, 1, ('Universitats',))
# ('TIME', 8348, 4, ('dilluns', 'a', 'la', 'nit'))
# ('ORG', 7261, 1, ('Indra',))
# ('ORG', 17889, 1, ('Miniwatt',))
# ('MISC', 15251, 1, ('Conys',))
# ('LOC', 1070, 2, ('Porto', 'Alegre'))
# ('ORG', 14145, 2, ('Coalició', 'Canària'))
# ('MISC', 16745, 1, ('Lasius',))
# ('TIME', 5408, 2, ('Cada', 'dia'))
# ('CARDINAL', 6449, 1, ('2',))
# ('MISC', 12708, 2, ('Mars', 'Pathfinder'))
# ('ORG', 13464, 1, ('Ensenyament',))
# ('MISC', 18545, 2, ('Merry', 'Christmes'))
# ('MISC', 4259, 1, ('Tómbola',))
# ('PER', 10950, 1, ('Belot',))
# ('MISC', 14900, 1, ('Conys',))
# ('CARDINAL', 2285, 1, ('3.339',))
# ('ORG', 4612, 4, ('Comissió', 'de', 'Política', 'Social'))
# ('MISC', 7058, 1, ('PAAU',))
# ('MISC', 4089, 7, ('FIM', 'Globals', 'a', 'l', 'AC', 'DIVISA', 'FIM'))
# ('MISC', 18493, 3, ('Platja', 'de', 'llum'))
# ('PER', 10112, 4, ('Antoni', 'Gaudí', 'i', 'Cornet'))
# ('MISC', 7900, 1, ('Atlàntida',))
# ('ORG', 15452, 1, ('Acerinox',))
# ('MISC', 13038, 2, ('Finca', 'Güell'))
# ('LOC', 18129, 1, ('Nummunit',))
# ('LOC', 18132, 1, ('Devesa',))
# ('TIME', 18743, 1, ('sempre',))
# ('PER', 6537, 1, ('Monreal',))
# ('LOC', 18434, 5, ('Plaça', 'Jordi', 'de', 'Sant', 'Jordi'))
# ('ORG', 900, 1, ('Bars',))
# ('CARDINAL', 9495, 2, ('tres', 'morts'))
# ('ORG', 18420, 3, ('Selva', 'Big', 'Band'))
# ('PER', 793, 1, ('Llaràs',))
# ('PER', 6352, 1, ('Arola',))
# ('ORG', 15887, 9, ('Iniciativa', 'per', 'Catalunya', 'Verds', '-', 'Esquerra', 'Unida', 'i', 'Alternativa'))
# ('ORG', 3930, 2, ('Morgan', 'Stanley'))
# ('MISC', 7768, 2, ('Testimoni', 'Verdaguer'))
# ('MISC', 922, 3, ('Quan', 'ens', 'veiem'))
# ('ORG', 15329, 5, ('Associació', 'de', 'Veïns', 'Ausiàs', 'March'))
# ('MISC', 18552, 3, ('Dins', 'aquest', 'iglú'))
# ('CARDINAL', 10482, 2, ('una', 'cinquantena'))
# ('LOC', 14928, 2, ('Teatre', 'Laboratori'))
# ('ORG', 14632, 5, ('Agrupació', 'de', 'Voluntaris', 'de', 'Reus'))
# ('PER', 8976, 1, ('Navío',))
# ('MISC', 18530, 2, ('Caos', 'n.13'))
# ('LOC', 1423, 2, ('Porto', 'Alegre'))
# ('MISC', 3908, 2, ('unit', 'link'))
# ('PER', 10989, 1, ('Belot',))
# ('CARDINAL', 17954, 2, ('159', 'originals'))
# ('ORG', 674, 1, ('Bars',))
# ('QUANTITY', 10873, 2, ('tres', 'hores'))
# ('MISC', 7981, 1, ('Renaixença',))
# ('ORG', 18342, 2, ('Quartet', 'Anònim'))
# ('MISC', 18515, 4, ('De', 'muda', 'en', 'muda'))
# ('CARDINAL', 12545, 2, ('4.500', 'milions'))
# ('TIME', 794, 1, ('sempre',))
# ('DATE', 10516, 6, ('2/4', "d'", 'onze', 'de', 'la', 'nit'))
# ('ORG', 7334, 2, ('Tinkle', 'Consultants'))
# ('TIME', 9813, 2, ('vuit', 'anys'))
# ('LOC', 12600, 3, ('Centre', 'Espacial', 'Kennedy'))
# ('TIME', 10127, 2, ('aquesta', 'nit'))
# ('ORG', 14520, 2, ("L'", 'Economiste'))
# ('LOC', 17764, 1, ('Cornudella',))
# ('PER', 1426, 3, ('Hebe', 'de', 'Bonafini'))
# ('LOC', 3264, 1, ('Grenoble',))
# ('MISC', 7851, 5, ('Verdaguer', 'i', 'les', 'llengües', 'europees'))
# ('ORG', 7346, 1, ('Tinkle',))
# ('MISC', 3227, 4, ('no', 'a', "l'", 'FN'))
# ('MISC', 18501, 3, ('Com', 'si', 'res'))
# ('TIME', 9539, 3, ('el', 'setembre', 'passat'))
# ('ORG', 13466, 1, ('Treball',))
# ('TIME', 2879, 3, ('poques', 'hores', 'abans'))
# ('ORG', 18533, 1, ('Falsterbo-Marí',))
# ('PER', 17248, 1, ('Gunilla',))
# ('MISC', 9680, 1, ('Aspergillus',))
# ('ORG', 5018, 1, ('Generalitat',))
# ('PER', 17322, 1, ('Gunilla',))
# ('MISC', 11452, 1, ('Bayer',))
# ('LOC', 16356, 2, ('Àsia', 'Menor'))
# ('LOC', 2513, 1, ('Rambouillet',))
# ('DATE', 15503, 1, ('4',))
# ('LOC', 17624, 1, ('Poboleda',))
# ('MISC', 11706, 1, ('Lipobay',))
# ('TIME', 11969, 3, ('un', 'any', 'després'))
# ('PER', 5865, 2, ('Ajuria', 'Enea'))
# ('MISC', 13042, 2, ('Palau', 'Güell'))
# ('CARDINAL', 18078, 1, ('8',))
# ('CARDINAL', 13811, 2, ('49.202', 'milions'))
# ('ORG', 11431, 4, ('Defensor', 'd', 'el', 'Pacient'))
# ('MISC', 11447, 1, ('Lipobay',))
# ('ORG', 7245, 1, ('Indra',))
# ('ORG', 12422, 1, ('AGT',))
# ('ORG', 7352, 1, ('Andersen',))
# ('CARDINAL', 8845, 2, ('12,1', 'milions'))
# ('TIME', 14698, 5, ('les', '5', 'de', 'la', 'matinada'))
# ('LOC', 14799, 1, ('Carnota',))
# ('LOC', 9467, 1, ('Vigo',))
# ('ORG', 3927, 2, ('Goldman', 'Sach'))
# ('LOC', 14932, 3, ('Centre', "d'", 'Osona'))
# ('TIME', 4420, 2, ('cada', 'any'))
# ('PER', 17101, 3, ('Gunilla', 'von', 'Bismarck'))
# ('MISC', 15022, 1, ('Conys',))
# ('MISC', 3220, 4, ('no', 'a', 'Le', 'Pen'))
# ('LOC', 16435, 1, ('Matadepera',))
# ('PER', 17365, 1, ('Gunilla',))
# ('ORG', 13961, 1, ('Saba',))
# ('ORG', 15182, 1, ('Amfiteatre',))
# ('LOC', 5704, 1, ('Gernika',))
# ('PER', 1139, 1, ('Tobin',))
# ('ORG', 19632, 1, ('BP-Amoco',))
# ('ORG', 95, 2, ('Shah', 'Bajsh'))
# ('ORG', 13444, 1, ('Pimecsefes',))
# ('TIME', 11284, 3, ('a', "l'", 'octubre'))
# ('LOC', 11223, 4, ('Amèrica', 'd', 'el', 'nord'))
# ('ORG', 1156, 3, ('Parlament', 'Federal', 'Suís'))
# ('MISC', 8034, 1, ('Atlàntida',))
# ('TIME', 8206, 3, ('a', "l'", 'agost'))
# ('MISC', 16347, 2, ('Lasius', 'neglectus'))
# ('PER', 17465, 1, ('Gunilla',))
# ('CARDINAL', 4690, 1, ('7',))
# ('MISC', 12033, 2, ('Deutsche', 'Boerse'))
# ('LOC', 7998, 3, ('Vinyoles', "d'", 'Orís'))
# ('MISC', 18536, 4, ('Ens', 'veiem', 'a', 'Folegandres'))
# ('MISC', 18524, 1, ('Somiatruites',))
# ('TIME', 19290, 1, ('mai',))
# ('MISC', 16891, 2, ('Linepithema', 'humile'))
# ('MISC', 8131, 1, ('Atlàntida',))
# ('LOC', 15897, 1, ('Reus',))
# ('ORG', 978, 1, ('Bars',))
# ('LOC', 12693, 1, ('Mart',))
# ('ORG', 19761, 1, ('Repinves',))
# ('CARDINAL', 10499, 2, ('deu', 'punts'))
# ('PER', 762, 1, ('Llaràs',))
# ('LOC', 5700, 3, ('Casa', 'de', 'Juntes'))
# ('MISC', 7962, 4, ('Jocs', 'Florals', 'de', 'Barcelona'))
# ('ORG', 13994, 1, ('Tradia',))
# ('ORG', 7277, 1, ('Indra',))
# ('ORG', 15290, 1, ('Amfiteatre',))
# ('CARDINAL', 8854, 2, ('dos', 'milions'))
# ('MISC', 10371, 5, ('Festa', 'Major', 'de', 'Sant', 'Pere'))
# ('MISC', 10591, 4, ('Pluja', "d'", 'espurnes', 'blanques'))
# ('ORG', 17808, 2, ('Best', 'Hotels'))
# ('TIME', 17229, 4, ('sis', 'mesos', "l'", 'any'))
# ('ORG', 17937, 1, ('LG',))
# ('MISC', 3212, 5, ('no', 'a', "l'", 'extrema', 'dreta'))
# ('PER', 2431, 1, ('Fischer',))
# ('LOC', 1502, 1, ('Gènova',))
# ('MISC', 9553, 1, ('Aspergillus',))
# ('CARDINAL', 3248, 2, ('400', 'ciutats'))
# ('LOC', 9559, 3, ('Hospital', 'do', 'Meixoeiro'))
# ('LOC', 42, 1, ('Kerman',))
# ('MISC', 16308, 2, ('Lasius', 'neglectus'))
# ('ORG', 11816, 2, ('Ascat', 'Vida'))
# ('MISC', 4077, 3, ('TARRAGONAFONS', 'GLOBAL', 'FIM'))
# ('CARDINAL', 13501, 1, ('10',))
# ('MISC', 16813, 2, ('Lasius', 'neglectus'))
# ('TIME', 14712, 5, ('les', '8', 'd', 'el', 'matí'))
# ('MISC', 12593, 3, ('Mars', 'Polar', 'Lander'))
# ('MISC', 3196, 7, ('Front', 'Nacional', 'd', 'el', 'Primer', 'de', 'Maig'))
# ('PER', 5072, 1, ('Mas-Collel',))
# ('LOC', 16644, 3, ('Palau', 'de', 'Pedralbes'))
# ('ORG', 929, 1, ('Bars',))
# ('ORG', 11211, 1, ('DaimlerChrysler',))
# ('TIME', 11329, 1, ('11',))
# ('LOC', 1522, 2, ('Porto', 'Alegre'))
# ('MISC', 1645, 4, ("S'", 'ha', 'fet', 'justícia'))
# ('TIME', 7068, 3, ('començaments', 'de', 'juliol'))
# ('ORG', 7841, 3, ('Club', 'Super', '3'))
# ('LOC', 15652, 1, ('Ribeira',))
# ('CARDINAL', 2967, 1, ('15.000',))
# ('LOC', 17861, 1, ('Salobreña',))
# ('TIME', 5242, 2, ('cada', 'estiu'))
# ('PER', 905, 1, ('Llaràs',))

# %%
for en in false_positives:
    print(en)
# Out:
# ('ORG', 11309, 1, ('Newark',))
# ('ORG', 19642, 1, ('Tobago',))
# ('ORG', 4612, 7, ('Comissió', 'de', 'Política', 'Social', 'd', 'el', 'Parlament'))
# ('PER', 7851, 1, ('Verdaguer',))
# ('MISC', 16433, 3, ('Seva', ',', 'Matadepera'))
# ('PER', 13961, 1, ('Saba',))
# ('MISC', 14610, 1, ('Carnota',))
# ('MISC', 3222, 2, ('Le', 'Pen'))
# ('PER', 3933, 5, ('Merril', 'Lynch', 'Mercury', 'Asset', 'Management'))
# ('LOC', 1426, 3, ('Hebe', 'de', 'Bonafini'))
# ('ORG', 11452, 1, ('Bayer',))
# ('ORG', 15511, 4, ('Universitat', 'Protestant', 'de', 'Teologia'))
# ('ORG', 16356, 2, ('Àsia', 'Menor'))
# ('LOC', 8034, 1, ('Atlàntida',))
# ('LOC', 11498, 1, ('Lipobay',))
# ('PER', 18600, 1, ('cerverí@catradio.com',))
# ('MISC', 18342, 2, ('Quartet', 'Anònim'))
# ('TIME', 2881, 1, ('abans',))
# ('PER', 16891, 1, ('Linepithema',))
# ('PER', 3930, 2, ('Morgan', 'Stanley'))
# ('TIME', 12933, 2, ('un', 'dia'))
# ('PER', 29, 1, ('Kerman',))
# ('ORG', 8061, 1, ('Comillas',))
# ('LOC', 13610, 4, ('Delegació', 'd', 'el', 'Govern'))
# ('PER', 42, 1, ('Kerman',))
# ('TIME', 9539, 2, ('el', 'setembre'))
# ('PER', 18201, 2, ('Prudenci', 'Bertrana'))
# ('LOC', 14749, 1, ('Reus',))
# ('LOC', 18420, 3, ('Selva', 'Big', 'Band'))
# ('LOC', 17101, 1, ('Gunilla',))
# ('MISC', 19640, 1, ('Trinitat',))
# ('MISC', 13160, 3, ('Nit', 'de', 'llum'))
# ('TIME', 2078, 1, ('diari',))
# ('PER', 12693, 1, ('Mart',))
# ('MISC', 10591, 1, ('Pluja',))
# ('PER', 7346, 1, ('Tinkle',))
# ('ORG', 2431, 1, ('Fischer',))
# ('ORDINAL', 14907, 1, ('quart',))
# ('LOC', 10950, 1, ('Belot',))
# ('ORG', 6641, 1, ('PAAU',))
# ('CARDINAL', 1495, 1, ('23',))
# ('LOC', 18511, 1, ('Obrint',))
# ('TIME', 8349, 3, ('a', 'la', 'nit'))
# ('PER', 11211, 1, ('DaimlerChrysler',))
# ('LOC', 10611, 1, ('Castell',))
# ('PER', 3927, 2, ('Goldman', 'Sach'))
# ('ORDINAL', 9808, 1, ('primer',))
# ('LOC', 674, 1, ('Bars',))
# ('PER', 7334, 2, ('Tinkle', 'Consultants'))
# ('TIME', 11969, 2, ('un', 'any'))
# ('LOC', 17365, 1, ('Gunilla',))
# ('ORG', 5896, 1, ('Donington',))
# ('ORG', 12033, 2, ('Deutsche', 'Boerse'))
# ('MISC', 17963, 2, ('Premis', 'Literaris'))
# ('PER', 11431, 4, ('Defensor', 'd', 'el', 'Pacient'))
# ('ORG', 15251, 1, ('Conys',))
# ('LOC', 9553, 1, ('Aspergillus',))
# ('PER', 5369, 2, ('Sala', 'Goya'))
# ('ORG', 19724, 1, ('Caixa',))
# ('LOC', 13418, 1, ('Pimecsefes',))
# ('LOC', 7998, 1, ('Vinyoles',))
# ('PER', 18545, 2, ('Merry', 'Christmes'))
# ('LOC', 14216, 2, ('Cambra', 'Alta'))
# ('TIME', 8712, 1, ('anual',))
# ('LOC', 15182, 1, ('Amfiteatre',))
# ('ORG', 5843, 1, ('Ardanza',))
# ('PER', 10112, 2, ('Antoni', 'Gaudí'))
# ('DATE', 10516, 1, ('2/4',))
# ('LOC', 1433, 6, ('Madres', 'de', 'la', 'Plaza', 'de', 'Mayo'))
# ('LOC', 18533, 1, ('Falsterbo-Marí',))
# ('ORG', 3230, 1, ('FN',))
# ('TIME', 16966, 2, ('un', 'dia'))
# ('MISC', 9878, 3, ('producte', 'interior', 'brut'))
# ('ORDINAL', 5246, 1, ('vintena',))
# ('LOC', 6008, 1, ('Marqués',))
# ('ORG', 15102, 1, ('Conys',))
# ('MISC', 1293, 2, ('Universitat', 'Pontifícia'))
# ('LOC', 19770, 2, ('La', 'Kutxa'))
# ('LOC', 9477, 1, ('Aspergillus',))
# ('LOC', 17966, 1, ('Girona',))
# ('ORG', 8281, 1, ('Iniciativa',))
# ('LOC', 17620, 5, ('Morera', 'de', 'Montsant', 'i', 'Poboleda'))
# ('TIME', 18662, 2, ('quatre', 'anys'))
# ('LOC', 10989, 1, ('Belot',))
# ('TIME', 18679, 2, ('un', 'any'))
# ('PER', 12735, 2, ('Polar', 'Lander'))
# ('TIME', 18043, 2, ('sis', 'anys'))
# ('LOC', 9032, 1, ('Navío',))
# ('PER', 11240, 1, ('DaimlerChrysler',))
# ('PER', 1070, 2, ('Porto', 'Alegre'))
# ('PER', 17861, 1, ('Salobreña',))
# ('PER', 7277, 1, ('Indra',))
# ('ORG', 15329, 7, ('Associació', 'de', 'Veïns', 'Ausiàs', 'March', 'de', 'Gavà'))
# ('MISC', 18100, 1, ('internet',))
# ('CARDINAL', 5948, 1, ('100',))
# ('ORG', 6171, 1, ('avinentesa',))
# ('LOC', 8000, 1, ('Orís',))
# ('TIME', 14716, 1, ('matí',))
# ('ORG', 2848, 2, ('anti-Le', 'Pen'))
# ('ORG', 1139, 1, ('Tobin',))
# ('PER', 18648, 1, ('Model',))
# ('LOC', 9463, 5, ('Hospital', 'do', 'Meixoeiro', 'de', 'Vigo'))
# ('PER', 12593, 3, ('Mars', 'Polar', 'Lander'))
# ('LOC', 17248, 1, ('Gunilla',))
# ('TIME', 18903, 2, ('sis', 'mesos'))
# ('LOC', 13053, 2, ('Park', 'Güell'))
# ('ORG', 5037, 2, ('Ona', 'Catalana'))
# ('TIME', 4105, 2, ('sis', 'anys'))
# ('ORG', 1905, 1, ('KL-742',))
# ('MISC', 905, 1, ('Llaràs',))
# ('ORG', 3196, 7, ('Front', 'Nacional', 'd', 'el', 'Primer', 'de', 'Maig'))
# ('CARDINAL', 3248, 1, ('400',))
# ('LOC', 14636, 1, ('Reus',))
# ('TIME', 239, 1, ('diari',))
# ('ORG', 1196, 1, ('Tobin',))
# ('ORG', 14632, 3, ('Agrupació', 'de', 'Voluntaris'))
# ('LOC', 16644, 5, ('Palau', 'de', 'Pedralbes', 'de', 'Barcelona'))
# ('MISC', 16308, 1, ('Lasius',))
# ('ORG', 12023, 3, ('Borsa', 'de', 'Frankfurt'))
# ('MISC', 5865, 2, ('Ajuria', 'Enea'))
# ('TIME', 17229, 2, ('sis', 'mesos'))
# ('PER', 15516, 1, ('Roma',))
# ('CARDINAL', 18399, 1, ('20h',))
# ('LOC', 5375, 1, ('VIP',))
# ('LOC', 18539, 1, ('Folegandres',))
# ('LOC', 11706, 1, ('Lipobay',))
# ('TIME', 10520, 2, ('la', 'nit'))
# ('LOC', 14145, 2, ('Coalició', 'Canària'))
# ('ORG', 18524, 1, ('Somiatruites',))
# ('LOC', 10551, 1, ('Encesa',))
# ('CARDINAL', 11329, 1, ('11',))
# ('LOC', 900, 1, ('Bars',))
# ('ORG', 4093, 3, ('AC', 'DIVISA', 'FIM'))
# ('ORG', 10731, 1, ('Brest',))
# ('LOC', 5517, 1, ('Aguirre',))
# ('LOC', 13996, 1, ('Xfera',))
# ('LOC', 6271, 1, ('Marqués',))
# ('TIME', 8348, 1, ('dilluns',))
# ('LOC', 19761, 1, ('Repinves',))
# ('CARDINAL', 11332, 1, ('15',))
# ('TIME', 14701, 2, ('la', 'matinada'))
# ('PER', 10115, 1, ('Cornet',))
# ('LOC', 11606, 1, ('Lipobay',))
# ('ORG', 7058, 1, ('PAAU',))
# ('ORDINAL', 5540, 1, ('primer',))
# ('MISC', 10371, 2, ('Festa', 'Major'))
# ('CARDINAL', 13501, 2, ('10', 'correspondran'))
# ('LOC', 15290, 1, ('Amfiteatre',))
# ('LOC', 7900, 1, ('Atlàntida',))
# ('LOC', 11168, 1, ('Belot',))
# ('ORG', 15895, 3, ('Alternativa', 'de', 'Reus'))
# ('LOC', 10557, 1, ('zodíac-Cranc',))
# ('PER', 12892, 2, ('Mars', 'Pathfinder'))
# ('PER', 18075, 2, ('Literatura', 'Juvenil'))
# ('LOC', 10374, 2, ('Sant', 'Pere'))
# ('PER', 1423, 2, ('Porto', 'Alegre'))
# ('PER', 2486, 1, ('Rambouillet',))
# ('TIME', 1865, 1, ('dijous',))
# ('TIME', 10840, 2, ('la', 'nit'))
# ('MISC', 10673, 2, ('El', 'arlequín'))
# ('LOC', 18129, 4, ('Nummunit', 'de', 'la', 'Devesa'))
# ('ORG', 14900, 1, ('Conys',))
# ('PER', 17995, 1, ('President',))
# ('MISC', 16347, 1, ('Lasius',))
# ('CARDINAL', 11711, 2, ('12', 'van'))
# ('PER', 17764, 1, ('Cornudella',))
# ('TIME', 10128, 1, ('nit',))
# ('TIME', 13458, 2, ('un', 'any'))
# ('ORG', 19467, 1, ('Iberoamèrica',))
# ('PER', 15452, 1, ('Acerinox',))
# ('PER', 95, 2, ('Shah', 'Bajsh'))
# ('ORG', 7962, 2, ('Jocs', 'Florals'))
# ('LOC', 18530, 2, ('Caos', 'n.13'))
# ('PER', 1522, 2, ('Porto', 'Alegre'))
# ('CARDINAL', 12545, 3, ('4.500', 'milions', '"'))
# ('CARDINAL', 10228, 2, ('50', 'col·laboradors'))
# ('ORG', 4259, 1, ('Tómbola',))
# ('MISC', 929, 1, ('Bars',))
# ('PER', 2513, 1, ('Rambouillet',))
# ('ORG', 14943, 1, ('Conys',))
# ('ORG', 6475, 1, ('PAAU',))
# ('MISC', 3025, 2, ('Le', 'Pen'))
# ('PER', 13030, 2, ('Colònia', 'Güell'))
# ('ORG', 10773, 1, ('Brest',))
# ('LOC', 7981, 1, ('Renaixença',))
# ('LOC', 7965, 1, ('Barcelona',))
# ('ORG', 12600, 3, ('Centre', 'Espacial', 'Kennedy'))
# ('TIME', 11971, 1, ('després',))
# ('PER', 6151, 1, ('Uras',))
# ('PER', 8100, 2, ('Palau', 'Moja'))
# ('TIME', 17545, 2, ('la', 'nit'))
# ('MISC', 3826, 1, ('TV',))
# ('ORG', 14928, 7, ('Teatre', 'Laboratori', 'd', 'el', 'Centre', "d'", 'Osona'))
# ('TIME', 15722, 2, ('un', 'any'))
# ('MISC', 18434, 5, ('Plaça', 'Jordi', 'de', 'Sant', 'Jordi'))
# ('PER', 12040, 1, ('Cedel',))
# ('PER', 18505, 1, ('Gossos',))
# ('LOC', 13378, 1, ('Pimecsefes',))
# ('ORG', 15887, 4, ('Iniciativa', 'per', 'Catalunya', 'Verds'))
# ('ORG', 18200, 1, ('Fundació',))
# ('LOC', 13444, 1, ('Pimecsefes',))
# ('ORG', 7627, 3, ('Departament', "d'", 'Ensenyament'))
# ('PER', 11311, 2, ('Saint', 'Louis'))
# ('MISC', 18135, 1, ('Premi',))
# ('LOC', 5072, 1, ('Mas-Collel',))
# ('MISC', 16813, 1, ('Lasius',))
# ('MISC', 2995, 2, ('Le', 'Pen'))
# ('LOC', 5700, 5, ('Casa', 'de', 'Juntes', 'de', 'Gernika'))
# ('PER', 11905, 1, ('Toyota',))
# ('LOC', 8131, 1, ('Atlàntida',))
# ('LOC', 11447, 1, ('Lipobay',))
# ('ORG', 6606, 1, ('PAAU',))
# ('PER', 7768, 2, ('Testimoni', 'Verdaguer'))
# ('LOC', 8976, 1, ('Navío',))
# ('ORG', 4287, 7, ('Comissió', 'Primera', 'd', 'el', 'Parlament', 'de', 'Catalunya'))
# ('PER', 11816, 2, ('Ascat', 'Vida'))
# ('MISC', 7835, 9, ('Festa', 'd', 'els', 'Súpers', 'd', 'el', 'Club', 'Super', '3'))
# ('LOC', 11223, 1, ('Amèrica',))
# ('ORDINAL', 16474, 1, ('primer',))
# ('MISC', 14799, 1, ('Carnota',))
# ('PER', 20039, 1, ('refresc',))
# ('PER', 12708, 2, ('Mars', 'Pathfinder'))
# ('LOC', 18204, 1, ('Girona',))
# ('PER', 14613, 1, ('Coruña',))
# ('PER', 19785, 1, ('Pemex',))
# ('LOC', 14916, 1, ('Amfiteatre',))
# ('TIME', 7651, 1, ('ara',))
# ('LOC', 17322, 1, ('Gunilla',))
# ('PER', 15391, 1, ('Acerinox',))
# ('CARDINAL', 18431, 1, ('20h',))
# ('LOC', 13038, 2, ('Finca', 'Güell'))
# ('ORG', 15491, 6, ('Assemblea', 'd', 'el', 'Poble', 'de', 'Déu'))
# ('ORG', 12740, 3, ('Deep', 'Space', '2'))
# ('MISC', 793, 11, ('Llaràs', 'sempre', 'hi', 'posa', 'les', 'lletres', '-', 'i', ',', 'potser', ','))
# ('LOC', 19632, 1, ('BP-Amoco',))
# ('LOC', 6537, 1, ('Monreal',))
# ('LOC', 18493, 3, ('Platja', 'de', 'llum'))
# ('TIME', 11414, 3, ('a', 'l', 'novembre'))
# ('PER', 7245, 1, ('Indra',))
# ('LOC', 18569, 1, ('Escala',))
# ('ORG', 13464, 3, ('Ensenyament', 'i', 'Treball'))
# ('ORG', 15022, 1, ('Conys',))
# ('TIME', 13594, 2, ('tres', 'dies'))
# ('LOC', 12030, 1, ('Clearstream',))
# ('ORG', 9254, 1, ('Arnó',))
# ('PER', 18136, 2, ('Prudenci', 'Bertrana'))
# ('TIME', 12909, 1, ('nit',))
# ('MISC', 17937, 1, ('LG',))
# ('PER', 1502, 1, ('Gènova',))
# ('TIME', 1866, 3, ('a', 'la', 'nit'))
# ('ORDINAL', 10518, 1, ('onze',))
# ('MISC', 14520, 2, ("L'", 'Economiste'))
# ('ORG', 14745, 3, ('Agrupació', 'de', 'Voluntaris'))
# ('LOC', 17185, 1, ('Gunilla',))
# ('ORG', 5015, 4, ('Universitats', 'de', 'la', 'Generalitat'))
# ('LOC', 9680, 1, ('Aspergillus',))
# ('PER', 17808, 2, ('Best', 'Hotels'))
# ('LOC', 13994, 1, ('Tradia',))
# ('ORG', 9559, 3, ('Hospital', 'do', 'Meixoeiro'))
# ('MISC', 15652, 1, ('Ribeira',))
# ('TIME', 11910, 3, ('a', 'l', 'gener'))
# ('ORG', 4089, 2, ('FIM', 'Globals'))
# ('ORG', 7632, 1, ('Generalitat',))
# ('LOC', 17560, 1, ('Hola',))
# ('LOC', 17889, 1, ('Miniwatt',))
# ('LOC', 17170, 1, ('Gunilla',))
# ('PER', 18072, 2, ('Ramon', 'Muntaner'))
# ('TIME', 18455, 2, ('una', 'setmana'))
# ('MISC', 3264, 1, ('Grenoble',))
# ('TIME', 19555, 2, ('el', 'gener'))
# ('PER', 18372, 2, ('Joaquim', 'Ruyra'))
# ('LOC', 17565, 1, ('Marbella',))
# ('LOC', 17465, 1, ('Gunilla',))
# ('PER', 16745, 1, ('Lasius',))
# ('PER', 7261, 1, ('Indra',))
# ('CARDINAL', 12198, 1, ('90',))
# ('ORG', 9037, 4, ('convergència', 'europea', 'de', 'taxes'))
# ('PER', 6352, 3, ('Arola', 'i', 'Igual'))
# ('PER', 14811, 1, ('Finisterre',))
# ('LOC', 4077, 3, ('TARRAGONAFONS', 'GLOBAL', 'FIM'))
# ('ORG', 17998, 1, ('Fundació',))
# ('PER', 16938, 1, ('Lasius',))
# ('ORG', 15892, 2, ('Esquerra', 'Unida'))
# ('LOC', 13042, 2, ('Palau', 'Güell'))
# ('LOC', 17592, 1, ('principat',))
# ('TIME', 18161, 2, ('sis', 'anys'))
# ('TIME', 5847, 3, ('A', 'la', 'tarda'))
# ('MISC', 18536, 3, ('Ens', 'veiem', 'a'))

# %%
# Obtenim la llista d'etiquetes.
etiquetes_disponibles = set(map(lambda e: e[0], entitats_nomenades_test_tuples))
etiquetes_spacy_org = {'LOC', 'MISC', 'ORG', 'PER'}
etiquetes_propies = set(e for e in etiquetes_disponibles if e not in etiquetes_spacy_org)

# %%
# Obtenim les mètriques pel sistema original de spacy.
en_resultat_spacy = set(filter(lambda e: e[0] in etiquetes_spacy_org, entitats_nomenades_res_tuples))
en_test_spacy = set(filter(lambda e: e[0] in etiquetes_spacy_org, entitats_nomenades_test_tuples))

# Operem amb els conjunts per obtenir la intersecció i subtraccions.
true_positives_spacy = en_resultat_spacy & en_test_spacy
false_positives_spacy = en_resultat_spacy - en_test_spacy
false_negatives_spacy = en_test_spacy - en_resultat_spacy

# Obtenim les mètriques de cada categoria.
metrica_tp = len(true_positives_spacy)
metrica_fp = len(false_positives_spacy)
metrica_fn = len(false_negatives_spacy)

# Obtenim les mètriques complexes.
precisio = metrica_tp / (metrica_tp + metrica_fp)
reclam = metrica_tp / (metrica_tp + metrica_fn)
f1 = 2 * precisio * reclam / (precisio + reclam)

print("DETECTADES PER SPACY EN COMPARACIÓ A L'ETIQUETAT ORIGINAL DE SPACY")
print("Autèntics positius:", metrica_tp)
print("Falsos positius:", metrica_fp)
print("Falsos negatius:", metrica_fn)
print("=========")
print("Precisió: {}%".format(int(precisio * 10000) / 100))
print("Reclam: {}%".format(int(reclam * 10000) / 100))
print("Mesura F: {}%".format(int(f1 * 10000) / 100))
# Out:
# DETECTADES PER SPACY EN COMPARACIÓ A L'ETIQUETAT ORIGINAL DE SPACY
# Autèntics positius: 829
# Falsos positius: 233
# Falsos negatius: 236
# =========
# Precisió: 78.06%
# Reclam: 77.84%
# Mesura F: 77.95%

# %%
# Obtenim les mètriques pel sistema original de spacy.
en_resultat_spacy = set(filter(lambda e: e[0] in etiquetes_spacy_org, entitats_nomenades_res_tuples))
en_test_spacy = entitats_nomenades_test_tuples

# Operem amb els conjunts per obtenir la intersecció i subtraccions.
true_positives_spacy = en_resultat_spacy & en_test_spacy
false_positives_spacy = en_resultat_spacy - en_test_spacy
false_negatives_spacy = en_test_spacy - en_resultat_spacy

# Obtenim les mètriques de cada categoria.
metrica_tp = len(true_positives_spacy)
metrica_fp = len(false_positives_spacy)
metrica_fn = len(false_negatives_spacy)

# Obtenim les mètriques complexes.
precisio = metrica_tp / (metrica_tp + metrica_fp)
reclam = metrica_tp / (metrica_tp + metrica_fn)
f1 = 2 * precisio * reclam / (precisio + reclam)

print("DETECTADES PER SPACY EN COMPARACIÓ A L'ETIQUETAT COMPLET")
print("Autèntics positius:", metrica_tp)
print("Falsos positius:", metrica_fp)
print("Falsos negatius:", metrica_fn)
print("=========")
print("Precisió: {}%".format(int(precisio * 10000) / 100))
print("Reclam: {}%".format(int(reclam * 10000) / 100))
print("Mesura F: {}%".format(int(f1 * 10000) / 100))
# Out:
# DETECTADES PER SPACY EN COMPARACIÓ A L'ETIQUETAT COMPLET
# Autèntics positius: 829
# Falsos positius: 233
# Falsos negatius: 800
# =========
# Precisió: 78.06%
# Reclam: 50.89%
# Mesura F: 61.61%

# %%
# Iterem per les etiquetes propies per obtenir les mètriques per etiqueta.
for etiqueta in etiquetes_propies:

    # Obtenim les mètriques pel sistema original de spacy.
    en_resultat_etiqueta = set(filter(lambda e: e[0] == etiqueta, entitats_nomenades_res_tuples))
    en_test_etiqueta = set(filter(lambda e: e[0] == etiqueta, entitats_nomenades_test_tuples))

    # Operem amb els conjunts per obtenir la intersecció i subtraccions.
    true_positives_etiqueta = en_resultat_etiqueta & en_test_etiqueta
    false_positives_etiqueta = en_resultat_etiqueta - en_test_etiqueta
    false_negatives_etiqueta = en_test_etiqueta - en_resultat_etiqueta

    # Obtenim les mètriques de cada categoria.
    metrica_tp = len(true_positives_etiqueta)
    metrica_fp = len(false_positives_etiqueta)
    metrica_fn = len(false_negatives_etiqueta)

    # Obtenim les mètriques complexes.
    precisio = metrica_tp / (metrica_tp + metrica_fp)
    reclam = metrica_tp / (metrica_tp + metrica_fn)
    f1 = 2 * precisio * reclam / (precisio + reclam)

    print("= ETIQUETA", etiqueta, "===")
    print("Autèntics positius:", metrica_tp)
    print("Falsos positius:", metrica_fp)
    print("Falsos negatius:", metrica_fn)
    print("=========")
    print("Precisió: {}%".format(int(precisio * 10000) / 100))
    print("Reclam: {}%".format(int(reclam * 10000) / 100))
    print("Mesura F: {}%".format(int(f1 * 10000) / 100))
    print("")
# Out:
# = ETIQUETA PERCENT ===
# Autèntics positius: 58
# Falsos positius: 0
# Falsos negatius: 0
# =========
# Precisió: 100.0%
# Reclam: 100.0%
# Mesura F: 100.0%
#
# = ETIQUETA MONEY ===
# Autèntics positius: 38
# Falsos positius: 0
# Falsos negatius: 0
# =========
# Precisió: 100.0%
# Reclam: 100.0%
# Mesura F: 100.0%
#
# = ETIQUETA TIME ===
# Autèntics positius: 162
# Falsos positius: 36
# Falsos negatius: 25
# =========
# Precisió: 81.81%
# Reclam: 86.63%
# Mesura F: 84.15%
#
# = ETIQUETA CARDINAL ===
# Autèntics positius: 101
# Falsos positius: 12
# Falsos negatius: 29
# =========
# Precisió: 89.38%
# Reclam: 77.69%
# Mesura F: 83.12%
#
# = ETIQUETA DATE ===
# Autèntics positius: 109
# Falsos positius: 1
# Falsos negatius: 5
# =========
# Precisió: 99.09%
# Reclam: 95.61%
# Mesura F: 97.32%
#
# = ETIQUETA ORDINAL ===
# Autèntics positius: 28
# Falsos positius: 6
# Falsos negatius: 0
# =========
# Precisió: 82.35%
# Reclam: 100.0%
# Mesura F: 90.32%
#
# = ETIQUETA QUANTITY ===
# Autèntics positius: 8
# Falsos positius: 0
# Falsos negatius: 1
# =========
# Precisió: 100.0%
# Reclam: 88.88%
# Mesura F: 94.11%
