# %%
SAVE_IMAGES = False
TEXT_ARXIU = 'corpus_raw.txt'

import re, spacy, pickle

from utils import EntitatNomenada, obtenir_totes_les_coincidencies, convertir_fragments_a_referencies, afegir_entitat_nomenada, comprova_si_solapa, entitats_nomenades_cmp
from spacy import displacy
from pathlib import Path

# %%
# Inicialitzem spacy en català.
nlp = spacy.load("ca_core_news_sm")

# %%
# Text on buscarem entitats nomenades.

with open(TEXT_ARXIU, 'rb') as file:
    text_sencer = file.read().decode('utf-8')

# %%
# Tokenitza el text.
doc_spacy = nlp(text_sencer)

# Obté els tokens com strings.
tokens = [token.text for token in doc_spacy]

# %%
# Inicialitzem una llista buida on anirem guardant les entitats
# nomenades resultants.
entitats_nomenades = []

# %%
# Definim l'expressió regular per trobar dates senceres i hores
regex_dates_hores = (r'\b(?:0?[1-9]|[12][0-9]|3[01])[-/](?:0?[1-9]|1[0-2])([-/](\d{2}|\d{4}))?\b|' # 23/02/2024
    r'\b(?:0?[1-9]|[12][0-9]|3[01])\s(de\s|d\')?(?:gener|febrer|març|abril|maig|juny|juliol|agost|setembre|octubre|novembre|desembre)(\s(del?\s)?(\d{2,4}))?\b|' # 25 de novembre de 2015
    r'\b(([Ee]l\s)?gener|([Ee]l\s)?febrer|([Ee]l\s)?març|([Ll]\')?abril|([Ee]l\s)?maig|([Ee]l\s)?juny|([Ee]l\s)?juliol|([Ll]\')?agost|([Ee]l\s)?setembre|([Ll]\')?octubre|([Ee]l\s)?novembre|([Ee]l\s)?desembre)(\s(del?\s)(\d{2,4}))\b|' # El març del 2019
    r'\b([01]?\d|2[0-3])([:\.][0-5]\d\s?)(hores|h)?\b|' # 23.15 h
    r'\b(([Ee]l\s)|[Ll]\'any\s)?\d{4}\b|' # El 1995
    r'\b[Ss]egle\sM{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})\b|' # Segle XXI
    r'\d{1,2}\-[GFMAJSOND]') # 12-J

# Per obtenir les strings completes de cada data trobada
dates_senceres_hores = obtenir_totes_les_coincidencies(regex_dates_hores, text_sencer)

# Imprimim les dates trobades
print("Dates i hores trobades:", "\n".join(dates_senceres_hores), sep="\n\n")
# Out:
# Dates i hores trobades:
#
# l'any 1986
# 1999
# 1989
# 1991
# 1993
# 1994
# 1996
# 1999
# 1998
# L'octubre del 1998
# 26 de desembre
# 24 de maig
# 1995
# 13-M
# 31 de maig de 1938
# 1999
# 4 d'abril
# 29 de març
# 4 d'abril
# el 1936
# el 1936
# 1859
# 24 de juliol
# l'any 1998
# l'any 2000
# l'abril del 2001
# 1845
# 1902
# segle XIX
# 29 de juny
# 7 de juny
# 11 de setembre
# 1845
# 1902
# l'any 1855
# El 1870
# 1977
# l'any 1874
# 1877
# 1893
# 1886
# El 1945
# 2000
# 1999
# 2000
# 1998
# el 2000
# 1999
# el 1999
# 17 d'abril
# 1999
# 5 de setembre
# 11 de setembre
# 25 de juny de 1852
# 2/4
# 11-S
# 1999
# 8 d'agost
# l'any 1995
# l'any 2004
# 20 de setembre de 1999
# 1999
# 3 de desembre de 1999
# 15.21 hores
# 21.21
# 23.20 hores
# 22.00 hores
# febrer del 1999
# el 2000
# 1999
# l'any 2000
# el 1999
# el 2000
# el 1999
# El 2000
# 23 de febrer
# 28 de febrer
# 28 de febrer
# 28 de febrer
# 1 de març
# el 1999
# el 1998
# 7 d'octubre
# 1 de novembre
# El març del 1999
# el 1998
# 1870
# 1917
# 1914
# 1925
# juliol de 1995
# el 2005
# 21 de juny
# 21 de juny
# 18 de juny
# 20 de juny
# el maig del 1998
# 4 de març de 1998
# el 1988
# el 1991
# març del 1998
# 19 de març de 1998
# 19 de març
# el 1987
# 2003
# el 1999
# 1998
# L'any 1999
# el gener del 1997
# 28 de gener del 1997

# %%
# Tokenitza les troballes.
# Converteix aixó en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in dates_senceres_hores]

# Obtenir les referencies com a instancies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'DATE')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# Tot verificat!

# %%
# Definim l'expressió regular per trobar moments i dates relatius al dia actual
regex_dates_relatives = (r'\b((?:[Aa]quest\s)?([Dd]illuns|[Dd]imarts|[Dd]imecres|[Dd]ijous|[Dd]ivendres|[Dd]issabte|[Dd]iumenge)(?:\sque\sve|\spassat)?)\b|' # Aquest dilluns / Dimecres / diumenge que ve
    r'\b([Aa]questa\ssetmana|[Aa]quest\smes|[Aa]quest\sany)\b|' # Aquest mes
    r'\b(([Ll]a\ssetmana\s|[Ee]l\smes\s|[Ll]\'any\s)(que\sve|passa(t|da)|precedent|següent|anterior|posterior))\b|' # L'any que ve
    r'\b([Ff]a\s|[Dd]\'aquí\sa?\s?|[Cc]ada\s?)?([Gg]airebé\s|[Tt]ot\sjust\s|([Pp]oc\s)?més\s(d\'|de\s))?([Uu]na?e?s?\s|[Dd](o|ue)s\s|[Tt]res\s|[Qq]uatre\s|[Cc]inc\s|[Ss]is\s)(di(a|es)|setman(a|es)|meso?s?|anys?)\b|' # Fa gairebé dos anys
    r'\b([Aa]vui|[Dd]emà|([Aa]bans-d\')?[Aa]hir|[Dd]emà\spassat)\b|' # Abans-d'ahir
    r'\b(?:[Jj]ust\s)?[Aa]ra|(?:[Mm]olt\s|[Pp]oc\s|[Jj]ust\s)?[Aa]bans|(?:(?:[Pp]oc\s|[Jj]ust\s)?[Dd]esprés)\b|' # Poc abans
    r'\b[AaEe]\s?l\'?\s(mes\s(de\s|d\'))?(gener|febrer|març|abril|maig|juny|juliol|agost|setembre|octubre|novembre|desembre)\b|' # El mes de juny
    r'\b(((?:[Pp]rimera\s|[Úú]ltima\s)hora\s(?:del\s|de\sla\s))?|([Aa]quest\s|[AaEe]l\s|[Ll]a\s|[Aa]\sla\s)?)(matí|migdia|tarda|vespre|nit|matinada)|' # Aquesta matinada
    r'\b([Ll]a|[Ll]es)\s(una|dues|tres|quatre|cinc|sis|set|vuit|nou|deu|onze|dotze|d{1,2})(?:\s(del\smatí|del\smigdia|de\sla\starda|del\svespre|de\sla\snit|de\sla\smatinada))\b') # Les cinc de la tarda 

# Per obtenir les strings completes de cada data trobada
dates_relatives = obtenir_totes_les_coincidencies(regex_dates_relatives, text_sencer)

# Imprimim les EN trobades
print("Dates relatives trobades:", "\n".join(dates_relatives), sep="\n\n")
# Out:
# Dates relatives trobades:
#
# després
# ahir
# un dia
# després
# ara
# ara
# abans
# Ara
# Ara
# el gener
# Ara
# dijous
# a la nit
# ahir
# dimecres
# ahir
# aquest any
# ahir
# ahir
# ahir
# ahir
# abans
# després
# l'any passat
# després
# ahir
# l'any anterior
# sis anys
# cada tres mesos
# fa uns mesos
# dos dies
# després
# fa uns mesos
# tres anys
# aquest any
# dilluns
# dijous
# d'aquí a una setmana
# abans
# dilluns
# Ahir
# ahir
# A la tarda
# ahir
# ara
# ahir
# demà
# dimarts
# dimecres
# la setmana que ve
# dissabte
# avui
# l'any següent
# després
# ahir
# ahir
# aquest divendres
# ara
# al novembre
# Després
# dos anys
# ahir
# fa uns dies
# just abans
# dilluns
# a la nit
# després
# després
# demà
# l'any precedent
# ahir
# l'any passat
# ara
# Aquest any
# aquest mes
# ahir
# aquest matí
# aquest vespre
# cinc anys
# després
# el maig
# el juny
# el setembre
# dijous
# A l juny
# al juliol
# després
# el maig
# el juny
# ahir
# després
# ahir
# ara
# Avui
# nit
# la nit
# avui
# dilluns
# ahir
# les tres de la matinada
# després
# la nit
# després
# abans
# al novembre
# la setmana que ve
# aquest mes
# abans
# al novembre
# el maig
# ahir
# després
# després
# l'any passat
# el gener
# al gener
# un any
# després
# l'any passat
# abans
# abans
# un dia
# avui
# nit
# un dia
# Després
# Després
# un any
# tres dies
# demà
# dimarts
# ahir
# l'any passat
# avui
# avui
# ahir
# fa tres setmanes
# abans
# dimarts que ve
# l'any passat
# la matinada
# matí
# l'any anterior
# aquesta setmana
# després
# El març
# un any
# després
# quatre dies
# després
# Avui
# un dia
# ahir
# sis mesos
# després
# ahir
# fa més de tres anys
# la nit
# avui
# fa gairebé un mes
# aquest any
# l'any anterior
# sis anys
# aquest any
# sis anys
# L'any passat
# aquest any
# dimecres
# divendres
# una setmana
# un any
# el maig
# quatre anys
# un any
# abans
# sis mesos
# ahir
# abans
# l'any següent
# el gener
# ahir
# el gener
# ara
# ara

# %%
# Tokenitza les troballes.
# Converteix aixó en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in dates_relatives]

# Obtenir les referencies com a instancies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'TIME')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# Tot verificat!

# %%
# Definim l'expressió regular per trobar freqüències
regex_frequencies = (r'\b(([Cc]ada|([Uu]na?|[Dd]os|[Dd]ues|[Tt]res|[Qq]uatre|[Cc]inc|[Ss]is|[Ss]et|[Vv]uit|[Nn]ou|[Dd]eu)\s(cop|vegada)\s(al\s|a\sla\s|(a\s)?l\'|per\s))'
    r'(dia|setmana|mes|any|estiu|tardor|hivern|primavera|dilluns|dimarts|dimecres|dijous|divendres|dissabte|diumenge)\b|' # Un cop a l'any
    r'\b[Ee]ls\s(dilluns|dimarts|dimecres|dijous|divendres|dissabte|diumenge)\b|' # Els dilluns
    r'\b([Dd]i[aà]ria?|[Ss]etmanal|[Qq]uinzenal|[Pp]eriòdica?|[Ff]reqüent|[Oo]casional|([Bb]i|[Tt]ri|[Qq]uadri|[Ss]e)?([Mm]ensuals?|mestrals?|[Aa]nuals?|ennals?))(ment)?)\b|' #Setmanalment / trimestral / biennal
    r'\b[Ss]empre|[Mm]ai|[Ss]ovint|(([Aa]|[Dd]e)\svegades)|[Dd]e\stant\sen\stant\b') # Sovint

# Per obtenir les strings completes de cada data trobada
frequencies = obtenir_totes_les_coincidencies(regex_frequencies, text_sencer)

# Imprimim les EN trobades
print("Expressions de freqüència trobades:", "\n".join(frequencies), sep="\n\n")
# Out:
# Expressions de freqüència trobades:
#
# diari
# sovint
# sempre
# sempre
# mai
# una vegada al dia
# a vegades
# diari
# mai
# Mai
# Mai
# Sempre
# mai
# mai
# periòdicament
# Diari
# anual
# mai
# mai
# mai
# diari
# de vegades
# mai
# ocasionalment
# mai
# sempre
# anual
# mai
# sempre
# mai
# mai

# %%
# Tokenitza les troballes.
# Converteix aixó en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in frequencies]

# Obtenir les referencies com a instancies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'TIME')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# DESCARTAT: ['Mai']
# DESCARTAT: ['Mai']
# DESCARTAT: ['periòdicament']
# DESCARTAT: ['diari']
# DESCARTAT: ['sempre']
# Tot verificat!

# %%
# Definim l'expressió regular per detectar nombres ordinals
regex_ordinals = (r'\b([Pp]rimer(a|e?s)?|[Ss]egon(a|es)?|[Tt]ercer(a|e?s)?|[Qq]uart(a|e?s)?|[Cc]inqu[èe](ns|na|nes)?|[Ss]is[èe](ns|na|nes)?|([Dd]is)?[Ss]et[èe](ns|na|nes)?|'
    r'([Dd]i)?[Vv]uit[èe](ns|na|nes)?|([Dd]i)?[Nn]ov[èe](ns|na|nes)?|[Dd]es[èe](ns|na|nes)?|[Oo]nz[èe](ns|na|nes)?|[Dd]otz[èe](ns|na|nes)?|[Tt]retz[èe](ns|na|nes)?|'
    r'[Cc]atorz[èe](ns|na|nes)?|[Qq]uinz[èe](ns|na|nes)?|[Ss]etz[èe](ns|na|nes)|[Vv]int[èe](ns|na|nes)??)\b|' # Cinquè
    r'\b\d+(rs?|ts?|è|a|ns?|es)\.?\b|' # 4t
    r'\b(?=[MDCLXVI])M{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})\b(?=\s[A-Z])') # XXIII Jornades

# Per obtenir les strings completes de cada data trobada
ordinals = obtenir_totes_les_coincidencies(regex_ordinals, text_sencer)

# Imprimim les EN trobades
print("Ordinals trobats:", "\n".join(ordinals), sep="\n\n")
# Out:
# Ordinals trobats:
#
# primer
# Tercer
# primer
# segona
# Primer
# Primer
# primer
# tercer
# Primera
# segones
# vintena
# primer
# primera
# primers
# primera
# primera
# primera
# primera
# quarta
# primer
# Primer
# segon
# onze
# tercera
# cinquè
# primer
# primera
# segon
# primer
# desè
# primer
# primera
# quart
# quart
# quart
# primer
# XXXVI
# segon
# primera
# Cinquena
# Cinquena
# primera

# %%
# Tokenitza les troballes.
# Converteix aixó en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in ordinals]

# Obtenir les referencies com a instancies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'ORDINAL')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# Tot verificat!

# %%
# Definim l'expressió regular per detectar monedes
regex_monedes = (r'(\d{1,3}(?:,\d{1,3})?\s?(\.\d{3})*(?:,\d{1,3})?\s?)(mil(ers)?\s(de\s)?)?([bm]ilions\s(de\s)?)?((cèntims?|centaus?|¢|penics?)|(afganis?|AFN)|(ariarys?|MGA)|'
    r'(฿|bahts?|THB)|(balboas?|PAB)|(birrs?|ETB)|(bolívars?|VEF)|(bolivianos?|BOB)|(₵|cedis?|GHS)|(₡|colons?|CRC)|(córdob(a|es)|NIO)|(coron(a|es)|DKK|SKK|EEK|ISK|NOK|SEK|CZK)|'
    r'(dalasis?|GMD)|(denars?|MKD)|(dinars?|DZD|BHD|IQD|JOD|KWD|LYD|TND|RSD|IRR)|(dírhams?|AED|MAD)|(dobr(a|es)|STD)|'
    r'(\$|\$CAN|dòlars?|AUD|BSD|BBD|BZD|BMD|BND|KYD|CAD|XCD|USD|FJD|GYD|HKD|JMD|LRD|NAD|NZD|SBD|SGD|SRD|TWD|TTD|ZWL)|(₫|dongs?|VND)|(₯|DR|dracm(a|es))|(drams?|AMD)|(escuts?|CVE)|'
    r'(M?€|d?\'?euros?|M?EUR)|(ƒ|FL|flor(í|ins)|ANF|AWG)|(fòrints?|HUF)|(₣|FB|FLUX|FS|francs?|BIF|XAF|XOF|XPF|KMF|CDF|DJF|GNF|RWF|CHF)|(gourdes?|HTG)|(guaranís?|PYG)|(₴|hrívni(a|es)|UAH)|'
    r'(¥|iens?|iuans?|renminbis?|JPY|CNY)|(kin(a|es)|PGK)|(₭|kips?|LAK)|(kun(a|es)|HRK)|(kwach(a|es)|MWK|ZMK)|(kwanz(a|es)|AOA)|(kyats?|MMK)|(laris?|GEL)|(lats|LVL)|(leks?|ALL)|'
    r'(lempir(a|es)|HNL)|(leones?|SLL)|(leus?|MDL|RON)|(levs?|BGN)|(lilangenis?|SZL)|([£₤]|lir(a|es)|TRY)|(litas|LTL)|([£₤]|£EG|£IR|£LIB|£SYR|£TQ|'
    r'(lliur(a|es)(\sesterlin(a|es))?|EGP|GBP|GIP|GGP|JEP|LBP|FKP|IMP|SHP|SYP|SDG|SSP))|(lotis?|LSL)|(manats?|AZN|TMT)|(DM|MF|marcs?|BAM)|(meticals?|MZN)|(₦|nair(a|es)|NGN)|'
    r'(nafk(a|es)|ERN)|(ngultrums?|BTN)|(ouguiy(a|es)|MRO)|(pa\'ang(a|ues)|TOP)|(pata(ca|ques)|MOP)|(₱|$MEX|$CH|CU|pesos?|ARS|COP|CUC|CUP|DOP|PHP|MXN|UYU|CLP)|'
    r'(pesset(a|es)|pt(a|es)\.?|ESP|M?PTA)|(pul(a|es)|BWP)|(quetzals?|GTQ)|(rands?|ZAR)|(R$|reals?|BRL)|(rials?|YER|IRR|OMR)|(៛|riels?|KHR)|(ringgits?|MYR)|(riyals?|QAR|SAR)|'
    r'(rubles?|BYR|RUB)|(₨|rupi(a|es)|INR|IDR|MVR|MUR|NPR|PKR|SCR|LKR)|(sols?(?=\s)|PEN)|(soms?|KGS|UZS)|(somonis?|TJS)|(sucres?)|(tak(a|es)|BDT)|(tal(a|es)|WST)|(tengu?es?|KZT)|'
    r'(₮|tögrögs?|MNT)|(tolars?)|(vatus?|VUV)|(₩|wons?|KPW|KRW)|(₪|£IS|(nous?\s)?xéquels?|ILS)|(xílings?|KES|SOS|TZS|UGX)|(zaires?)|(ZL|z[łl]otys?|PLN)|¤)')

# Per obtenir les strings completes de cada data trobada
monedes = obtenir_totes_les_coincidencies(regex_monedes, text_sencer)

# Imprimim les EN trobades
print("Monedes trobades:", "\n".join(monedes), sep="\n\n")
# Out:
# Monedes trobades:
#
# 180 milions de pessetes
# 42 milions d'euros
# 7.000 milions de pessetes
# 135.400 pessetes
# 467.800 milions de pessetes
# 2.000 milions de pessetes
# 56 milions d'euros
# 90.000 milions de dòlars
# 300 milions de pessetes
# 1,8 milions d'euros
# 8,01 milions d'euros
# 1.332 milions de pessetes
# 992 milions d'euros
# 164.981 milions de pessetes
# 591 milions d'euros
# 98.334 milions de pessetes
# 1.600 milions d'euros
# 266.218 milions de pessetes
# 4.500 milions de pessetes
# 27.081 milions de pessetes
# 91.440 milions de pessetes
# 15.095 milions de pessetes
# 26.033 milions de pessetes
# 2.209 milions de pessetes
# 352.000 milions de pessetes
# 20.831 milions de pessetes
# 89 milions de pessetes
# 1.500.000 euros
# 1.200 euros
# 16.000 milions de pessetes
# 42.000 euros
# 3.500 pessetes
# 3.500 pessetes
# 88.522 milions de pessetes
# 83.668 milions de pessetes
# 2,73 euros
# 2,99 euros
# 20 cèntims

# %%
# Tokenitza les troballes.
# Converteix això en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in monedes]

# Obtenir les referències com a instàncies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'MONEY')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# Tot verificat!

# %%
# Expressió regular per detectar percentatges
regex_percentatges = (r'\-?(?:\d{1,3}(?:\.\d{3})*|\d+)(?:,\d+)?\s?(%|per\scent)|' # 23%
    r'\b(?:zero|u|dos|tres|quatre|cinc|sis|set|vuit|nou|deu|onze|dotze|tretze|catorze|quinze|setze|disset|divuit|dinou|vint|trenta|quaranta|cinquanta|seixanta|setanta|vuitanta|noranta|cent)\sper\scent\b') # tres per cent

# Per obtenir les strings completes de cada data trobada
percentatges = obtenir_totes_les_coincidencies(regex_percentatges, text_sencer)

# Imprimim les EN trobades
print("Mesures trobades:", "\n".join(percentatges), sep="\n\n")
# Out:
# Mesures trobades:
#
# 45,7%
# 100%
# 34%
# 0,5%
# 26%
# 23%
# 76%
# 73%
# 5,01%
# 7,53%
# 39,28%
# 0,4%
# 1,5%
# 5%
# 9%
# 18,7%
# 20,9%
# 2,6%
# 4,5%
# -3%
# 34,7%
# 50%
# 9,1%
# 16%
# 74,5%
# 9,4%
# 56%
# 9,3%
# 1,6%
# 34%
# 2,8%
# 16,6%
# 7%
# 125%
# 13%
# 85 per cent
# 85 per cent
# 15 per cent
# 12,5%
# 25,2%
# 18,7%
# 3,5%
# 3,64%
# 85%
# 45,3%
# 9,5%
# 7%
# 7,6%
# 1,9%
# 6,1%
# 5%
# 3,6%
# 3,5%
# 5%
# 3%
# 9%
# 66%
# 11%

# %%
# Tokenitza les troballes.
# Converteix això en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in percentatges]

# Obtenir les referències com a instàncies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'PERCENT')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# Tot verificat!

# %%
# Expressió regular per detectar unitats de mesura
regex_mesures = (r'((-?\d{1,3}(?:[.,]\d{3})*(?:,\d+)?\s*))\s?((([QRYZEPTGMKkhdcmµnpfzyrq]|da)?'
    r'((m|g|s|A|K|mol|cd|N|Pa|J|W|C|V|Ω|S|F|T|Wb|H|rad|sr|Hz|lm|lx|Bq|Gy|Sv|kat|B|b|L|l|cal|fg|mi|UA|ly|pc|t|HP|hp|ac|Ac|[°º]C|[°º]F|P|bar|atm)¯?[¹²³123]?([p\·\/]?([QRYZEPTGMKkhdcmµnpfazyrq]?(m|g|s|A|K|mol|cd|h)¯?[¹²³123]?))*))|'
    r'([Qq]uett[aà]|[Rr]onn[aà]|[Yy]ott[aà]|[Zz]ett[aà]|[Ee]x[aà]|[Pp]et[aà]|[Tt]er[aà]|[Gg]ig[aà]|[Mm]eg[aà]|[KkQq]u?il[oò]|[Hh]ect[oò]?|[Dd]ec[aà]|[Dd]ec[ií]|[Cc]ent[ií]|[Mm]il·l[ií]|[Mm]icr[oò]|[Nn]an[oò]|[Pp]ic[oò]|'
    r'[Ff]emt[oò]|[Aa]tt[oò]|[Zz]ept[oò]|[Yy]oct[oò]|[Rr]ont[oò]|[Qq]ect[oò])?(metres?|grams?|segons?|minuts?|hor(a|es)|amperes?|(graus?\s)kelvin|candel(a|es)|mols?|newtons?|pascals?|joules?|watts?|coulombs?|volts?|ohms?|siemens?|farads?|'
    r'tesl(a|es)|webers?|henrys?|radiant?s?|estereoradiant?s?|hertzs?|lumens?|luxs?|becquerels?|grays?|sieverts?|katals?|bels?|bytes?|bits?|litres?|gal[óo](ns)?|calori(a|es)|frigori(a|es)|mill(a|es)(\snàuti(ca|ques))?|'
    r'llegu(a|es)|iard(a|es)|peus?|polzad(a|es)|bra(ça|ces)|unitats?\sastronòmi(ca|ques)|anys?\sllum|pàrsecs?|ton(a|es)|tonelad(a|es)|un(ça|ces)|cavalls?|àre(a|es)|acres?|graus?|graus?\s(Celsius|centígrads?|Fahrenheits?)|poises?|'
    r'bars?|atmosfer(a|es)|psis?)(\sper)?\s?(metres?|grams?|segons?|amperes?|graus?\skelvin|candel(a|es)|mols?|hor(a|es))?((al)?\squadrats?|al\scub|cúbics?)?)\b')

# Per obtenir les strings completes de cada data trobada
mesures = obtenir_totes_les_coincidencies(regex_mesures, text_sencer)

# Imprimim les EN trobades
print("Mesures trobades:", "\n".join(mesures), sep="\n\n")
# Out:
# Mesures trobades:
#
# 500 grams
# 21 hores
# 200 metres per segon
# -3 s
# 20 hores
# 00 hores
# 10 minuts
# 12 hores
# 000 l
# 14 hectàrees
# 600 metres
# 200 hectàrees
# 3.000 megawatts

# %%
# Tokenitza les troballes.
# Converteix això en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in mesures]

# Obtenir les referències com a instàncies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'QUANTITY')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# DESCARTAT: ['21', 'hores']
# DESCARTAT: ['-', '3', 's']
# DESCARTAT: ['20', 'hores']
# DESCARTAT: ['00', 'hores']
# DESCARTAT: ['000', 'l']
# Tot verificat!

# %%
# Expressió regular per detectar quantitats
regex_quantitats = r'(\d+(?:[.,]\d{3})*(?:,\d+)?\s*)((?!(?:a|amb|en|entre|per|sense|sota|sobre|del?|pel|al|i|o|que)\s)[^\s,\.\)\%\;]+)(?=\s|,|\.|$)'

# Per obtenir les strings completes de cada data trobada
quantitats = obtenir_totes_les_coincidencies(regex_quantitats, text_sencer)

# Imprimim les EN trobades
print("Quantitats trobades:", "\n".join(quantitats), sep="\n\n")
# Out:
# Quantitats trobades:
#
# 1986
# 18 temes
# 23 anys
# 19 anys
# 19 anys
# 742 havia
# 500 grams
# 70
# 63 vots
# 1.701 vots
# 638
# 7.302 arquitectes
# 339
# 45
# 1998
# 1.052 arquitectes
# 1998
# 67 adolescents
# 320 persones
# 26
# 35 morts
# 24
# 1.300.000 persones
# 000
# 000
# 400.000 persones
# 100.000 assistents
# 15
# 000
# 20.000 persones
# 3.000 persones
# 2.000 persones
# 1995
# 400 ciutats
# 50
# 000
# 40
# 000
# 400
# 13-M
# 224 veïns
# 165 ferits
# 31
# 1938
# 80 edificis
# 180 milions
# 25 millors
# 1999
# 4 d'abril
# 29
# 4 d'abril
# 1936
# 1936:
# 14 parlamentaris
# 300 convidats
# 1859
# 100 dies
# 8 anys
# 24
# 1998 va
# 2000 destaca
# 2001
# 42 milions
# 7.000 milions
# 29
# 11
# 1845 -
# 1855
# 20 anys
# 1870 va
# 1874
# 1877-1893
# 89 anys
# 1945 va
# 2000
# 8,8 milions
# 1,19 bilions
# 135.400 pessetes
# 132
# 100
# 1999
# 2000
# 1998
# 2000
# 467.800 milions
# 1999
# 3,5 milions
# 1,2 milions
# 1,7 milions
# 1,9 milions
# 2,8 milions
# 1999
# 39
# 12,1 milions
# 17 d'abril
# 30.000 milions
# 46.000 milions
# 1999
# 30 dies
# 2.000 milions
# 56 milions
# 1.400 socis
# 247 llocs
# 1.400 socis
# 75 anys
# 127 pacients
# 11
# 90.000 milions
# 150 anys
# 28 persones
# 50 col·laboradors
# 25
# 1852
# 28 persones
# 2/4
# 245 passatgers
# 11-S
# 184.065 vehicles
# 1999
# 11
# 15 d'aquest
# 60
# 65 anys
# 8 d'agost
# 22
# 31 persones
# 12 van
# 300 milions
# 1,8 milions
# 1995
# 18
# 8,01 milions
# 1.332 milions
# 992 milions
# 164.981 milions
# 20
# 248.489 unitats
# 34
# 2004
# 591 milions
# 98.334 milions
# 1.600 milions
# 266.218 milions
# 15
# 4.500 milions
# 90
# 10 milions
# 23 empreses
# 20
# 1999 presentar
# 4.500 milions
# 4.500 milions
# 187
# 1999
# 2.836 milions
# 4.500 milions"
# 1999
# 15
# 21 hores
# 21
# 21
# 200 metres
# 3 s'ha
# 23
# 20 hores
# 22
# 00 hores
# 10 minuts
# 1999
# 10 representants
# 34
# 10 correspondran
# 10 més
# 31 vots
# 12 hores
# 2000 un
# 1999
# 27.081 milions
# 91.440 milions
# 115.000 milions
# 15.095 milions
# 49
# 202
# 74
# 26.033 milions
# 2000
# 1.615 milions
# 1999
# 2000 l'1
# 2.209 milions
# 1999
# 2000
# 16
# 352.000 milions
# 60 voluntaris
# 23
# 28
# 60 voluntaris
# 23
# 28
# 20
# 30 anys
# 28
# 28
# 1999 els
# 20.831 milions
# 1998
# 200 grups
# 7 d'octubre
# 1999
# 4 anys
# 17 anys
# 92
# 1998
# 14 hectàrees
# 600 metres
# 90.000 formigues
# 89 milions
# 1995
# 89 milions
# 200 hectàrees
# 300
# 1.500.000 euros
# 85
# 1.200 euros
# 85
# 15
# 8.000 milions
# 23 hotels
# 2005
# 16.000 milions
# 12
# 159 originals
# 181 originals
# 42.000 euros
# 39 originals
# 42 obres
# 31
# 27
# 21
# 21
# 18
# 20h
# 20
# 20h
# 13
# 93
# 414
# 37
# 04
# 31 anys
# 1998 la
# 1998
# 10 mesos
# 1988
# 3.500 pessetes
# 1991
# 1998
# 19
# 1998
# 19
# 1987
# 3.500 pessetes
# 19 anys
# 1.500 places
# 2003
# 250 places
# 16.828 milions
# 1999
# 25
# 1998
# 1999 es
# 88.522 milions
# 283.297 milions
# 18
# 97.455 milions
# 83.600 milions
# 300.000 milions
# 83.668 milions
# 1997"
# 300.000 milions
# 3.000 megawatts
# 28
# 1997
# 82.000 milions
# 45
# 00
# 95
# 99
# 2,99
# 8,95
# 2,73 euros
# 2,99 euros
# 20 cèntims

# %%
# Tokenitza les troballes.
# Converteix això en una llista de llistes de tokens en format string.
troballes_tokenitzades = [[t.text for t in nlp(trob)] for trob in quantitats]

# Obtenir les referències com a instàncies d'EntitatNomenada.
entitats_nomenades += convertir_fragments_a_referencies(tokens, troballes_tokenitzades, 'CARDINAL')

# Ara verifiquem si aquestes es corresponen correctament als tokens inicials.
for en in entitats_nomenades:
    en.verificar(tokens)
else:
    print('Tot verificat!')
# Out:
# DESCARTAT: ['742', 'havia']
# DESCARTAT: ['638']
# DESCARTAT: ['339']
# DESCARTAT: ['45']
# DESCARTAT: ['000']
# DESCARTAT: ['000']
# DESCARTAT: ['000']
# DESCARTAT: ['000']
# DESCARTAT: ['40']
# DESCARTAT: ['000']
# DESCARTAT: ['132']
# DESCARTAT: ['12,1', 'milions']
# DESCARTAT: ['8,01', 'milions']
# DESCARTAT: ['248.489', 'unitats']
# DESCARTAT: ['2004']
# DESCARTAT: ['21', 'hores']
# DESCARTAT: ['200', 'metres']
# DESCARTAT: ['3', "s'", 'ha']
# DESCARTAT: ['20', 'hores']
# DESCARTAT: ['00', 'hores']
# DESCARTAT: ['49']
# DESCARTAT: ['202']
# DESCARTAT: ['74']
# DESCARTAT: ['2000', "l'", '1']
# DESCARTAT: ['16']
# DESCARTAT: ['159', 'originals']
# DESCARTAT: ['13']
# DESCARTAT: ['93']
# DESCARTAT: ['414']
# DESCARTAT: ['37']
# DESCARTAT: ['04']
# DESCARTAT: ['25']
# DESCARTAT: ['18']
# DESCARTAT: ['45']
# Tot verificat!

# %%
# Ordenem les prioritats de cada etiqueta per sobreescriure les EN que apareixen en més d'una RegEx
prioritats = {
    'PERCENT' :     7,
    'MONEY' :       6,
    'DATE' :        5,
    'QUANTITY' :    4,
    'ORDINAL' :     3,
    'TIME' :        2,
    'CARDINAL' :    1,
    'ERROR' :       0,
    'PERCENT-ERROR' :     0,
    'ORDINAL-ERROR' :     0,
    'MONEY-ERROR' :       0,
    'DATE-ERROR' :        0,
    'QUANTITY-ERROR' :    0,
    'TIME-ERROR' :        0,
    'CARDINAL-ERROR' :    0,
    'ERROR-ERROR' :       0
}

# Bucle en què iterem per totes les combinacions d'etiquetes
for i, en1 in enumerate(entitats_nomenades):
    for j, en2 in enumerate(entitats_nomenades):
        
        # Condicional per evitar comparacions entre una mateixa etiqueta
        if i == j:
            continue

        # Condicional per evitar repetir comparacions que ja hem fet
        if i > j:
            continue
        
        # Condicional per assignar la categoria ERROR si etiquetes se solapen
        if comprova_si_solapa(en1, en2):
            if prioritats[en1.etiqueta] <= prioritats[en2.etiqueta]:
                if '-ERROR' not in en1.etiqueta:
                    en1.etiqueta += '-ERROR'
            else: 
                if '-ERROR' not in en2.etiqueta:
                    en2.etiqueta += '-ERROR'

# %%
# Iterem per les entitats en sentit contrari per eliminar els errors.
# Ho fem en sentit contrari per evitar errors pel desplaçament dels indexs.
for i in reversed(range(len(entitats_nomenades))):
    
    # Elimina els que han estat marcats com errors.
    if '-ERROR' in entitats_nomenades[i].etiqueta:
        del entitats_nomenades[i]

for en in entitats_nomenades:
    en.print()
# Out:
# DATE (323-326) = ["l'", 'any', '1986']
# DATE (743-744) = ['1999']
# DATE (932-933) = ['1989']
# DATE (940-941) = ['1991']
# DATE (951-952) = ['1993']
# DATE (959-960) = ['1994']
# DATE (967-968) = ['1996']
# DATE (975-976) = ['1999']
# DATE (2301-2302) = ['1998']
# DATE (2670-2675) = ["L'", 'octubre', 'd', 'el', '1998']
# DATE (2706-2709) = ['26', 'de', 'desembre']
# DATE (2731-2734) = ['24', 'de', 'maig']
# DATE (3205-3206) = ['1995']
# DATE (3624-3625) = ['13-M']
# DATE (3675-3680) = ['31', 'de', 'maig', 'de', '1938']
# DATE (4058-4059) = ['1999']
# DATE (4499-4502) = ['4', "d'", 'abril']
# DATE (4557-4560) = ['29', 'de', 'març']
# DATE (4599-4602) = ['4', "d'", 'abril']
# DATE (5518-5520) = ['el', '1936']
# DATE (5549-5551) = ['el', '1936']
# DATE (5776-5777) = ['1859']
# DATE (6456-6459) = ['24', 'de', 'juliol']
# DATE (7089-7092) = ["l'", 'any', '1998']
# DATE (7194-7197) = ["l'", 'any', '2000']
# DATE (7255-7260) = ["l'", 'abril', 'd', 'el', '2001']
# DATE (7519-7520) = ['1845']
# DATE (7521-7522) = ['1902']
# DATE (7533-7535) = ['segle', 'XIX']
# DATE (7781-7784) = ['29', 'de', 'juny']
# DATE (7820-7823) = ['7', 'de', 'juny']
# DATE (7879-7882) = ['11', 'de', 'setembre']
# DATE (7935-7936) = ['1845']
# DATE (7941-7942) = ['1902']
# DATE (7950-7953) = ["l'", 'any', '1855']
# DATE (7983-7985) = ['El', '1870']
# DATE (8036-8037) = ['1977']
# DATE (8062-8065) = ["l'", 'any', '1874']
# DATE (8113-8114) = ['1877']
# DATE (8115-8116) = ['1893']
# DATE (8136-8137) = ['1886']
# DATE (8381-8383) = ['El', '1945']
# DATE (8417-8418) = ['2000']
# DATE (8545-8546) = ['1999']
# DATE (8584-8585) = ['2000']
# DATE (8607-8608) = ['1998']
# DATE (8637-8639) = ['el', '2000']
# DATE (8682-8683) = ['1999']
# DATE (8763-8765) = ['el', '1999']
# DATE (8871-8874) = ['17', "d'", 'abril']
# DATE (8891-8892) = ['1999']
# DATE (9687-9690) = ['5', 'de', 'setembre']
# DATE (9847-9850) = ['11', 'de', 'setembre']
# DATE (10359-10364) = ['25', 'de', 'juny', 'de', '1852']
# DATE (10516-10517) = ['2/4']
# DATE (10901-10902) = ['11-S']
# DATE (11272-11273) = ['1999']
# DATE (11614-11617) = ['8', "d'", 'agost']
# DATE (11755-11758) = ["l'", 'any', '1995']
# DATE (11947-11950) = ["l'", 'any', '2004']
# DATE (12281-12286) = ['20', 'de', 'setembre', 'de', '1999']
# DATE (12515-12516) = ['1999']
# DATE (12665-12670) = ['3', 'de', 'desembre', 'de', '1999']
# DATE (12677-12679) = ['15.21', 'hores']
# DATE (12682-12683) = ['21.21']
# DATE (13148-13150) = ['23.20', 'hores']
# DATE (13258-13260) = ['22.00', 'hores']
# DATE (13329-13333) = ['febrer', 'd', 'el', '1999']
# DATE (13704-13706) = ['el', '2000']
# DATE (13717-13718) = ['1999']
# DATE (13889-13892) = ["l'", 'any', '2000']
# DATE (13911-13913) = ['el', '1999']
# DATE (13946-13948) = ['el', '2000']
# DATE (13979-13981) = ['el', '1999']
# DATE (14446-14448) = ['El', '2000']
# DATE (14694-14697) = ['23', 'de', 'febrer']
# DATE (14708-14711) = ['28', 'de', 'febrer']
# DATE (14923-14926) = ['28', 'de', 'febrer']
# DATE (15238-15241) = ['28', 'de', 'febrer']
# DATE (15259-15262) = ['1', 'de', 'març']
# DATE (15394-15396) = ['el', '1999']
# DATE (15419-15421) = ['el', '1998']
# DATE (15506-15509) = ['7', "d'", 'octubre']
# DATE (15615-15618) = ['1', 'de', 'novembre']
# DATE (15686-15691) = ['El', 'març', 'd', 'el', '1999']
# DATE (16484-16486) = ['el', '1998']
# DATE (17027-17028) = ['1870']
# DATE (17029-17030) = ['1917']
# DATE (17041-17042) = ['1914']
# DATE (17043-17044) = ['1925']
# DATE (17197-17200) = ['juliol', 'de', '1995']
# DATE (17843-17845) = ['el', '2005']
# DATE (18123-18126) = ['21', 'de', 'juny']
# DATE (18321-18324) = ['21', 'de', 'juny']
# DATE (18394-18397) = ['18', 'de', 'juny']
# DATE (18426-18429) = ['20', 'de', 'juny']
# DATE (18621-18626) = ['el', 'maig', 'd', 'el', '1998']
# DATE (18652-18657) = ['4', 'de', 'març', 'de', '1998']
# DATE (18674-18676) = ['el', '1988']
# DATE (18709-18711) = ['el', '1991']
# DATE (18734-18738) = ['març', 'd', 'el', '1998']
# DATE (18779-18784) = ['19', 'de', 'març', 'de', '1998']
# DATE (18845-18848) = ['19', 'de', 'març']
# DATE (18894-18896) = ['el', '1987']
# DATE (19059-19060) = ['2003']
# DATE (19100-19102) = ['el', '1999']
# DATE (19116-19117) = ['1998']
# DATE (19118-19121) = ["L'", 'any', '1999']
# DATE (19353-19358) = ['el', 'gener', 'd', 'el', '1997']
# DATE (19494-19500) = ['28', 'de', 'gener', 'd', 'el', '1997']
# TIME (64-65) = ['després']
# TIME (125-126) = ['ahir']
# TIME (127-129) = ['un', 'dia']
# TIME (129-130) = ['després']
# TIME (333-334) = ['ara']
# TIME (360-361) = ['ara']
# TIME (735-736) = ['abans']
# TIME (788-789) = ['Ara']
# TIME (882-883) = ['Ara']
# TIME (1041-1043) = ['el', 'gener']
# TIME (1371-1372) = ['Ara']
# TIME (1865-1866) = ['dijous']
# TIME (1866-1869) = ['a', 'la', 'nit']
# TIME (1898-1899) = ['ahir']
# TIME (1908-1909) = ['dimecres']
# TIME (2063-2064) = ['ahir']
# TIME (2080-2082) = ['aquest', 'any']
# TIME (2247-2248) = ['ahir']
# TIME (2339-2340) = ['ahir']
# TIME (2600-2601) = ['ahir']
# TIME (2741-2742) = ['ahir']
# TIME (2881-2882) = ['abans']
# TIME (2985-2986) = ['després']
# TIME (3014-3017) = ["l'", 'any', 'passat']
# TIME (3174-3175) = ['després']
# TIME (3649-3650) = ['ahir']
# TIME (3981-3984) = ["l'", 'any', 'anterior']
# TIME (4105-4107) = ['sis', 'anys']
# TIME (4402-4405) = ['cada', 'tres', 'mesos']
# TIME (4433-4436) = ['fa', 'uns', 'mesos']
# TIME (4573-4575) = ['dos', 'dies']
# TIME (4575-4576) = ['després']
# TIME (4679-4682) = ['fa', 'uns', 'mesos']
# TIME (4869-4871) = ['tres', 'anys']
# TIME (5258-5260) = ['aquest', 'any']
# TIME (5279-5280) = ['dilluns']
# TIME (5302-5303) = ['dijous']
# TIME (5323-5328) = ["d'", 'aquí', 'a', 'una', 'setmana']
# TIME (5343-5344) = ['abans']
# TIME (5379-5380) = ['dilluns']
# TIME (5416-5417) = ['Ahir']
# TIME (5467-5468) = ['ahir']
# TIME (5847-5850) = ['A', 'la', 'tarda']
# TIME (5919-5920) = ['ahir']
# TIME (5998-5999) = ['ara']
# TIME (6024-6025) = ['ahir']
# TIME (6044-6045) = ['demà']
# TIME (6061-6062) = ['dimarts']
# TIME (6063-6064) = ['dimecres']
# TIME (6065-6069) = ['la', 'setmana', 'que', 've']
# TIME (6140-6141) = ['dissabte']
# TIME (6343-6344) = ['avui']
# TIME (7137-7140) = ["l'", 'any', 'següent']
# TIME (7209-7210) = ['després']
# TIME (7280-7281) = ['ahir']
# TIME (7375-7376) = ['ahir']
# TIME (7416-7418) = ['aquest', 'divendres']
# TIME (7651-7652) = ['ara']
# TIME (7919-7922) = ['a', 'l', 'novembre']
# TIME (8081-8082) = ['Després']
# TIME (8083-8085) = ['dos', 'anys']
# TIME (8215-8216) = ['ahir']
# TIME (8264-8267) = ['fa', 'uns', 'dies']
# TIME (8289-8291) = ['just', 'abans']
# TIME (8348-8349) = ['dilluns']
# TIME (8349-8352) = ['a', 'la', 'nit']
# TIME (8356-8357) = ['després']
# TIME (8372-8373) = ['després']
# TIME (8421-8422) = ['demà']
# TIME (8469-8472) = ["l'", 'any', 'precedent']
# TIME (8573-8574) = ['ahir']
# TIME (8736-8739) = ["l'", 'any', 'passat']
# TIME (8839-8840) = ['ara']
# TIME (8875-8877) = ['Aquest', 'any']
# TIME (8896-8898) = ['aquest', 'mes']
# TIME (8949-8950) = ['ahir']
# TIME (9076-9078) = ['aquest', 'matí']
# TIME (9218-9220) = ['aquest', 'vespre']
# TIME (9266-9268) = ['cinc', 'anys']
# TIME (9500-9501) = ['després']
# TIME (9526-9528) = ['el', 'maig']
# TIME (9529-9531) = ['el', 'juny']
# TIME (9539-9541) = ['el', 'setembre']
# TIME (9564-9565) = ['dijous']
# TIME (9697-9700) = ['A', 'l', 'juny']
# TIME (9718-9721) = ['a', 'l', 'juliol']
# TIME (9739-9740) = ['després']
# TIME (9747-9749) = ['el', 'maig']
# TIME (9750-9752) = ['el', 'juny']
# TIME (9819-9820) = ['ahir']
# TIME (9891-9892) = ['després']
# TIME (9985-9986) = ['ahir']
# TIME (10020-10021) = ['ara']
# TIME (10101-10102) = ['Avui']
# TIME (10128-10129) = ['nit']
# TIME (10520-10522) = ['la', 'nit']
# TIME (10638-10639) = ['avui']
# TIME (10708-10709) = ['dilluns']
# TIME (10822-10823) = ['ahir']
# TIME (10824-10829) = ['les', 'tres', 'de', 'la', 'matinada']
# TIME (10830-10831) = ['després']
# TIME (10840-10842) = ['la', 'nit']
# TIME (10895-10896) = ['després']
# TIME (10958-10959) = ['abans']
# TIME (11243-11246) = ['a', 'l', 'novembre']
# TIME (11299-11303) = ['la', 'setmana', 'que', 've']
# TIME (11334-11336) = ['aquest', 'mes']
# TIME (11390-11391) = ['abans']
# TIME (11414-11417) = ['a', 'l', 'novembre']
# TIME (11528-11530) = ['el', 'maig']
# TIME (11693-11694) = ['ahir']
# TIME (11702-11703) = ['després']
# TIME (11778-11779) = ['després']
# TIME (11840-11843) = ["l'", 'any', 'passat']
# TIME (11884-11886) = ['el', 'gener']
# TIME (11910-11913) = ['a', 'l', 'gener']
# TIME (11969-11971) = ['un', 'any']
# TIME (11971-11972) = ['després']
# TIME (12000-12003) = ["l'", 'any', 'passat']
# TIME (12472-12473) = ['abans']
# TIME (12508-12509) = ['abans']
# TIME (12555-12557) = ['un', 'dia']
# TIME (12597-12598) = ['avui']
# TIME (12909-12910) = ['nit']
# TIME (12933-12935) = ['un', 'dia']
# TIME (13138-13139) = ['Després']
# TIME (13391-13392) = ['Després']
# TIME (13458-13460) = ['un', 'any']
# TIME (13594-13596) = ['tres', 'dies']
# TIME (13663-13664) = ['demà']
# TIME (13664-13665) = ['dimarts']
# TIME (13679-13680) = ['ahir']
# TIME (13765-13768) = ["l'", 'any', 'passat']
# TIME (14022-14023) = ['avui']
# TIME (14111-14112) = ['avui']
# TIME (14133-14134) = ['ahir']
# TIME (14150-14153) = ['fa', 'tres', 'setmanes']
# TIME (14188-14189) = ['abans']
# TIME (14190-14193) = ['dimarts', 'que', 've']
# TIME (14546-14549) = ["l'", 'any', 'passat']
# TIME (14701-14703) = ['la', 'matinada']
# TIME (14716-14717) = ['matí']
# TIME (15399-15402) = ["l'", 'any', 'anterior']
# TIME (15562-15564) = ['aquesta', 'setmana']
# TIME (15646-15647) = ['després']
# TIME (15722-15724) = ['un', 'any']
# TIME (16252-16253) = ['després']
# TIME (16256-16258) = ['quatre', 'dies']
# TIME (16488-16489) = ['després']
# TIME (16518-16519) = ['Avui']
# TIME (16966-16968) = ['un', 'dia']
# TIME (17016-17017) = ['ahir']
# TIME (17229-17231) = ['sis', 'mesos']
# TIME (17325-17326) = ['després']
# TIME (17372-17373) = ['ahir']
# TIME (17496-17501) = ['fa', 'més', 'de', 'tres', 'anys']
# TIME (17545-17547) = ['la', 'nit']
# TIME (17900-17901) = ['avui']
# TIME (17946-17950) = ['fa', 'gairebé', 'un', 'mes']
# TIME (17959-17961) = ['aquest', 'any']
# TIME (17983-17986) = ["l'", 'any', 'anterior']
# TIME (18043-18045) = ['sis', 'anys']
# TIME (18149-18151) = ['aquest', 'any']
# TIME (18161-18163) = ['sis', 'anys']
# TIME (18236-18239) = ["L'", 'any', 'passat']
# TIME (18278-18280) = ['aquest', 'any']
# TIME (18393-18394) = ['dimecres']
# TIME (18425-18426) = ['divendres']
# TIME (18455-18457) = ['una', 'setmana']
# TIME (18606-18608) = ['un', 'any']
# TIME (18662-18664) = ['quatre', 'anys']
# TIME (18679-18681) = ['un', 'any']
# TIME (18681-18682) = ['abans']
# TIME (18903-18905) = ['sis', 'mesos']
# TIME (19033-19034) = ['ahir']
# TIME (19053-19054) = ['abans']
# TIME (19064-19067) = ["l'", 'any', 'següent']
# TIME (19364-19365) = ['ahir']
# TIME (19555-19557) = ['el', 'gener']
# TIME (19798-19799) = ['ara']
# TIME (20010-20011) = ['ara']
# TIME (239-240) = ['diari']
# TIME (459-460) = ['sovint']
# TIME (794-795) = ['sempre']
# TIME (832-833) = ['sempre']
# TIME (1627-1632) = ['una', 'vegada', 'a', 'l', 'dia']
# TIME (1751-1753) = ['a', 'vegades']
# TIME (2078-2079) = ['diari']
# TIME (3507-3508) = ['Sempre']
# TIME (4318-4319) = ['Diari']
# TIME (8712-8713) = ['anual']
# TIME (15159-15161) = ['de', 'vegades']
# TIME (17225-17226) = ['mai']
# TIME (17315-17316) = ['ocasionalment']
# TIME (17397-17398) = ['mai']
# TIME (17577-17578) = ['sempre']
# TIME (17870-17871) = ['anual']
# TIME (18835-18836) = ['mai']
# TIME (909-910) = ['mai']
# TIME (3564-3565) = ['mai']
# ORDINAL (279-280) = ['primer']
# ORDINAL (1367-1368) = ['Tercer']
# ORDINAL (2387-2388) = ['primer']
# ORDINAL (2768-2769) = ['segona']
# ORDINAL (2810-2811) = ['Primer']
# ORDINAL (3200-3201) = ['Primer']
# ORDINAL (3761-3762) = ['primer']
# ORDINAL (3987-3988) = ['tercer']
# ORDINAL (4288-4289) = ['Primera']
# ORDINAL (4784-4785) = ['segones']
# ORDINAL (5246-5247) = ['vintena']
# ORDINAL (5540-5541) = ['primer']
# ORDINAL (7811-7812) = ['primera']
# ORDINAL (7961-7962) = ['primers']
# ORDINAL (7992-7993) = ['primera']
# ORDINAL (8397-8398) = ['primera']
# ORDINAL (8733-8734) = ['primera']
# ORDINAL (9345-9346) = ['primera']
# ORDINAL (9471-9472) = ['quarta']
# ORDINAL (9808-9809) = ['primer']
# ORDINAL (10257-10258) = ['Primer']
# ORDINAL (10348-10349) = ['segon']
# ORDINAL (10518-10519) = ['onze']
# ORDINAL (11338-11339) = ['tercera']
# ORDINAL (11901-11902) = ['cinquè']
# ORDINAL (11914-11915) = ['primer']
# ORDINAL (12725-12726) = ['primera']
# ORDINAL (12871-12872) = ['primer']
# ORDINAL (13426-13427) = ['desè']
# ORDINAL (13470-13471) = ['primer']
# ORDINAL (14438-14439) = ['primera']
# ORDINAL (14907-14908) = ['quart']
# ORDINAL (15135-15136) = ['quart']
# ORDINAL (15282-15283) = ['quart']
# ORDINAL (16474-16475) = ['primer']
# ORDINAL (18011-18012) = ['XXXVI']
# ORDINAL (18140-18141) = ['segon']
# ORDINAL (18244-18245) = ['primera']
# ORDINAL (18628-18629) = ['Cinquena']
# ORDINAL (18790-18791) = ['Cinquena']
# ORDINAL (19041-19042) = ['primera']
# MONEY (3996-4000) = ['180', 'milions', 'de', 'pessetes']
# MONEY (7264-7268) = ['42', 'milions', "d'", 'euros']
# MONEY (7269-7273) = ['7.000', 'milions', 'de', 'pessetes']
# MONEY (8536-8538) = ['135.400', 'pessetes']
# MONEY (8669-8673) = ['467.800', 'milions', 'de', 'pessetes']
# MONEY (9066-9070) = ['2.000', 'milions', 'de', 'pessetes']
# MONEY (9099-9103) = ['56', 'milions', "d'", 'euros']
# MONEY (10008-10012) = ['90.000', 'milions', 'de', 'dòlars']
# MONEY (11738-11742) = ['300', 'milions', 'de', 'pessetes']
# MONEY (11743-11747) = ['1,8', 'milions', "d'", 'euros']
# MONEY (11826-11830) = ['8,01', 'milions', "d'", 'euros']
# MONEY (11831-11835) = ['1.332', 'milions', 'de', 'pessetes']
# MONEY (11851-11855) = ['992', 'milions', "d'", 'euros']
# MONEY (11856-11860) = ['164.981', 'milions', 'de', 'pessetes']
# MONEY (12003-12007) = ['591', 'milions', "d'", 'euros']
# MONEY (12008-12012) = ['98.334', 'milions', 'de', 'pessetes']
# MONEY (12057-12061) = ['1.600', 'milions', "d'", 'euros']
# MONEY (12062-12066) = ['266.218', 'milions', 'de', 'pessetes']
# MONEY (12099-12103) = ['4.500', 'milions', 'de', 'pessetes']
# MONEY (13724-13728) = ['27.081', 'milions', 'de', 'pessetes']
# MONEY (13756-13760) = ['91.440', 'milions', 'de', 'pessetes']
# MONEY (13797-13801) = ['15.095', 'milions', 'de', 'pessetes']
# MONEY (13856-13860) = ['26.033', 'milions', 'de', 'pessetes']
# MONEY (13970-13974) = ['2.209', 'milions', 'de', 'pessetes']
# MONEY (14462-14466) = ['352.000', 'milions', 'de', 'pessetes']
# MONEY (15407-15411) = ['20.831', 'milions', 'de', 'pessetes']
# MONEY (17120-17124) = ['89', 'milions', 'de', 'pessetes']
# MONEY (17659-17661) = ['1.500.000', 'euros']
# MONEY (17689-17691) = ['1.200', 'euros']
# MONEY (17876-17880) = ['16.000', 'milions', 'de', 'pessetes']
# MONEY (18027-18029) = ['42.000', 'euros']
# MONEY (18685-18687) = ['3.500', 'pessetes']
# MONEY (18912-18914) = ['3.500', 'pessetes']
# MONEY (19144-19148) = ['88.522', 'milions', 'de', 'pessetes']
# MONEY (19334-19338) = ['83.668', 'milions', 'de', 'pessetes']
# MONEY (19965-19967) = ['2,73', 'euros']
# MONEY (19974-19976) = ['2,99', 'euros']
# MONEY (20029-20031) = ['20', 'cèntims']
# PERCENT (2294-2295) = ['45,7%']
# PERCENT (3964-3965) = ['100%']
# PERCENT (3978-3979) = ['34%']
# PERCENT (4218-4219) = ['0,5%']
# PERCENT (8461-8462) = ['26%']
# PERCENT (8467-8468) = ['23%']
# PERCENT (8500-8501) = ['76%']
# PERCENT (8503-8504) = ['73%']
# PERCENT (8522-8523) = ['5,01%']
# PERCENT (8526-8527) = ['7,53%']
# PERCENT (8773-8774) = ['39,28%']
# PERCENT (9834-9835) = ['0,4%']
# PERCENT (9873-9874) = ['1,5%']
# PERCENT (11264-11265) = ['5%']
# PERCENT (11282-11283) = ['9%']
# PERCENT (11812-11813) = ['18,7%']
# PERCENT (11867-11868) = ['20,9%']
# PERCENT (11875-11876) = ['2,6%']
# PERCENT (11920-11921) = ['4,5%']
# PERCENT (11926-11928) = ['-', '3%']
# PERCENT (11937-11938) = ['34,7%']
# PERCENT (12054-12055) = ['50%']
# PERCENT (13713-13714) = ['9,1%']
# PERCENT (13749-13750) = ['16%']
# PERCENT (13841-13842) = ['74,5%']
# PERCENT (13871-13872) = ['9,4%']
# PERCENT (13908-13909) = ['56%']
# PERCENT (13917-13918) = ['9,3%']
# PERCENT (13949-13950) = ['1,6%']
# PERCENT (13976-13977) = ['34%']
# PERCENT (14001-14002) = ['2,8%']
# PERCENT (14454-14455) = ['16,6%']
# PERCENT (14478-14479) = ['7%']
# PERCENT (15416-15417) = ['125%']
# PERCENT (15434-15435) = ['13%']
# PERCENT (17663-17666) = ['85', 'per', 'cent']
# PERCENT (17795-17798) = ['85', 'per', 'cent']
# PERCENT (17803-17806) = ['15', 'per', 'cent']
# PERCENT (17913-17914) = ['12,5%']
# PERCENT (19112-19113) = ['25,2%']
# PERCENT (19174-19175) = ['18,7%']
# PERCENT (19330-19331) = ['3,5%']
# PERCENT (19561-19562) = ['3,64%']
# PERCENT (19602-19603) = ['85%']
# PERCENT (19687-19688) = ['45,3%']
# PERCENT (19703-19704) = ['9,5%']
# PERCENT (19721-19722) = ['7%']
# PERCENT (19745-19746) = ['7,6%']
# PERCENT (19753-19754) = ['1,9%']
# PERCENT (19779-19780) = ['6,1%']
# PERCENT (19789-19790) = ['5%']
# PERCENT (19795-19796) = ['3,6%']
# PERCENT (19803-19804) = ['3,5%']
# PERCENT (19830-19831) = ['5%']
# PERCENT (19860-19861) = ['3%']
# PERCENT (19987-19988) = ['9%']
# PERCENT (20054-20055) = ['66%']
# PERCENT (20057-20058) = ['11%']
# QUANTITY (2002-2004) = ['500', 'grams']
# QUANTITY (12764-12768) = ['200', 'metres', 'per', 'segon']
# QUANTITY (13302-13304) = ['10', 'minuts']
# QUANTITY (13670-13672) = ['12', 'hores']
# QUANTITY (16532-16534) = ['14', 'hectàrees']
# QUANTITY (16579-16581) = ['600', 'metres']
# QUANTITY (17608-17610) = ['200', 'hectàrees']
# QUANTITY (19452-19454) = ['3.000', 'megawatts']
# CARDINAL (917-919) = ['18', 'temes']
# CARDINAL (1833-1835) = ['19', 'anys']
# CARDINAL (1846-1848) = ['19', 'anys']
# CARDINAL (2121-2122) = ['70']
# CARDINAL (2234-2236) = ['63', 'vots']
# CARDINAL (2254-2256) = ['1.701', 'vots']
# CARDINAL (2271-2273) = ['7.302', 'arquitectes']
# CARDINAL (2307-2309) = ['1.052', 'arquitectes']
# CARDINAL (2676-2678) = ['67', 'adolescents']
# CARDINAL (2703-2705) = ['320', 'persones']
# CARDINAL (2720-2722) = ['35', 'morts']
# CARDINAL (2787-2789) = ['1.300.000', 'persones']
# CARDINAL (2858-2860) = ['400.000', 'persones']
# CARDINAL (2957-2959) = ['100.000', 'assistents']
# CARDINAL (11332-11333) = ['15']
# CARDINAL (2969-2971) = ['20.000', 'persones']
# CARDINAL (3019-3021) = ['3.000', 'persones']
# CARDINAL (3145-3147) = ['2.000', 'persones']
# CARDINAL (3248-3249) = ['400']
# CARDINAL (3659-3661) = ['224', 'veïns']
# CARDINAL (3664-3666) = ['165', 'ferits']
# CARDINAL (3687-3689) = ['80', 'edificis']
# CARDINAL (4028-4030) = ['25', 'millors']
# CARDINAL (5672-5674) = ['14', 'parlamentaris']
# CARDINAL (5730-5732) = ['300', 'convidats']
# CARDINAL (6334-6336) = ['8', 'anys']
# CARDINAL (7956-7958) = ['20', 'anys']
# CARDINAL (8354-8356) = ['89', 'anys']
# CARDINAL (8510-8512) = ['8,8', 'milions']
# CARDINAL (8515-8517) = ['1,19', 'bilions']
# CARDINAL (5948-5949) = ['100']
# CARDINAL (8707-8709) = ['3,5', 'milions']
# CARDINAL (8743-8745) = ['1,2', 'milions']
# CARDINAL (8750-8752) = ['1,7', 'milions']
# CARDINAL (8756-8758) = ['1,9', 'milions']
# CARDINAL (8759-8761) = ['2,8', 'milions']
# CARDINAL (8882-8884) = ['30.000', 'milions']
# CARDINAL (8887-8889) = ['46.000', 'milions']
# CARDINAL (8909-8911) = ['30', 'dies']
# CARDINAL (9152-9154) = ['1.400', 'socis']
# CARDINAL (9187-9189) = ['247', 'llocs']
# CARDINAL (9202-9204) = ['1.400', 'socis']
# CARDINAL (9454-9456) = ['75', 'anys']
# CARDINAL (9743-9745) = ['127', 'pacients']
# CARDINAL (10104-10106) = ['150', 'anys']
# CARDINAL (10220-10222) = ['28', 'persones']
# CARDINAL (10228-10230) = ['50', 'col·laboradors']
# CARDINAL (10473-10475) = ['28', 'persones']
# CARDINAL (10849-10851) = ['245', 'passatgers']
# CARDINAL (11249-11251) = ['184.065', 'vehicles']
# CARDINAL (11329-11330) = ['11']
# CARDINAL (11520-11521) = ['60']
# CARDINAL (11522-11524) = ['65', 'anys']
# CARDINAL (11695-11697) = ['31', 'persones']
# CARDINAL (11711-11713) = ['12', 'van']
# CARDINAL (12083-12084) = ['15']
# CARDINAL (12198-12199) = ['90']
# CARDINAL (12203-12205) = ['10', 'milions']
# CARDINAL (12210-12212) = ['23', 'empreses']
# CARDINAL (12294-12296) = ['4.500', 'milions']
# CARDINAL (12430-12432) = ['4.500', 'milions']
# CARDINAL (12440-12441) = ['187']
# CARDINAL (12527-12529) = ['2.836', 'milions']
# CARDINAL (12545-12548) = ['4.500', 'milions', '"']
# CARDINAL (1495-1496) = ['23']
# CARDINAL (11629-11630) = ['22']
# CARDINAL (13488-13490) = ['10', 'representants']
# CARDINAL (13492-13493) = ['34']
# CARDINAL (13501-13503) = ['10', 'correspondran']
# CARDINAL (13507-13509) = ['10', 'més']
# CARDINAL (13554-13556) = ['31', 'vots']
# CARDINAL (13791-13793) = ['115.000', 'milions']
# CARDINAL (13904-13906) = ['1.615', 'milions']
# CARDINAL (14577-14579) = ['60', 'voluntaris']
# CARDINAL (14583-14584) = ['23']
# CARDINAL (14588-14589) = ['28']
# CARDINAL (14680-14682) = ['60', 'voluntaris']
# CARDINAL (14725-14726) = ['20']
# CARDINAL (14727-14729) = ['30', 'anys']
# CARDINAL (15476-15478) = ['200', 'grups']
# CARDINAL (15699-15701) = ['4', 'anys']
# CARDINAL (16215-16217) = ['17', 'anys']
# CARDINAL (16230-16231) = ['92']
# CARDINAL (16993-16995) = ['90.000', 'formigues']
# CARDINAL (17382-17384) = ['89', 'milions']
# CARDINAL (17633-17634) = ['300']
# CARDINAL (17811-17813) = ['8.000', 'milions']
# CARDINAL (17841-17843) = ['23', 'hotels']
# CARDINAL (18068-18069) = ['12']
# CARDINAL (17991-17993) = ['181', 'originals']
# CARDINAL (18033-18035) = ['39', 'originals']
# CARDINAL (18057-18059) = ['42', 'obres']
# CARDINAL (18088-18089) = ['31']
# CARDINAL (18102-18103) = ['27']
# CARDINAL (18399-18400) = ['20h']
# CARDINAL (18431-18432) = ['20h']
# CARDINAL (18616-18618) = ['31', 'anys']
# CARDINAL (18665-18667) = ['10', 'mesos']
# CARDINAL (18933-18935) = ['19', 'anys']
# CARDINAL (19005-19007) = ['1.500', 'places']
# CARDINAL (19090-19092) = ['250', 'places']
# CARDINAL (19098-19100) = ['16.828', 'milions']
# CARDINAL (19166-19168) = ['283.297', 'milions']
# CARDINAL (19180-19182) = ['97.455', 'milions']
# CARDINAL (19295-19297) = ['83.600', 'milions']
# CARDINAL (19310-19312) = ['300.000', 'milions']
# CARDINAL (19380-19382) = ['300.000', 'milions']
# CARDINAL (19566-19568) = ['82.000', 'milions']
# CARDINAL (19883-19884) = ['00']
# CARDINAL (19886-19887) = ['95']
# CARDINAL (19889-19890) = ['99']
# CARDINAL (19934-19935) = ['2,99']
# CARDINAL (19936-19937) = ['8,95']

# %%
# Convertim totes les EN trobades per Spacy al nostre format.
entitats_spacy = [EntitatNomenada(e.label_, e.start, e.end - e.start, tokens[e.start:e.end]) for e in doc_spacy.ents]

# %%
DESCARTAR_REGEX = True

# Bucle en què iterem per totes les combinacions d'etiquetes nostres i de spacy
for i, en_spacy in enumerate(entitats_spacy):
    for j, en_regex in enumerate(entitats_nomenades):
        
        # Condicional per assignar la categoria ERROR si etiquetes se solapen
        if comprova_si_solapa(en_spacy, en_regex):
            
            if DESCARTAR_REGEX:

                en_regex.etiqueta += '-ERROR'

            else:

                en_spacy.etiqueta += '-ERROR'

# L'afegim a la llista general d'EN.
for i, en_spacy in enumerate(entitats_spacy):
    entitats_nomenades.append(en_spacy)

# %%
# Iterem per les entitats en sentit contrari per eliminar els errors.
# Ho fem en sentit contrari per evitar errors pel desplaçament dels indexs.
for i in reversed(range(len(entitats_nomenades))):
    
    # Elimina els que han estat marcats com errors.
    if '-ERROR' in entitats_nomenades[i].etiqueta:
        del entitats_nomenades[i]

# %%
# Eliminem totes les EN perquè les hem inclòs a la nostra llista.
doc_spacy.ents = []

# Afegim totes les EN que hem trobat i/o no hem descartat.
for entitat in entitats_nomenades:
    afegir_entitat_nomenada(doc_spacy, entitat)

# %%
# Guardem la variable en un arxiu Pickle.
with open('entitats_nomenades.corpus_raw.pickle', 'wb') as file:
    pickle.dump(entitats_nomenades, file)

# Guardem la variable en un arxiu Pickle.
with open('tokens.corpus_raw.pickle', 'wb') as file:
    pickle.dump(tokens, file)

# %%
html = displacy.render(doc_spacy, style="ent", jupyter=not SAVE_IMAGES)

if SAVE_IMAGES:
    output_path = Path("C:\\Users\\alber\\OneDrive\\Documents\\Cosetes\\prova_imatge1.html")
    output_path.open("w", encoding="utf-8").write(html)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ni l'alliberament de les persones detingudes per la policia ni cap altra cosa. Ha estat una victòria &quot;, va indicar el vicegovernador de la província de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kerman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mohammad Ali Karimi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Alliberament incondicional. El responsable polític de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kerman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , on es va produir el segrest, va reiterar que els agents del servei secret iranià van aconseguir,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     després
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  de llargues converses, l'alliberament incondicional dels captius. El segrest, segons mitjans iranians, va ser obra d'un grup de narcotraficants de la tribu balutxistanesa
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shah Bajsh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , que exigia l'alliberament de dos dels seus membres, capturats en un enfrontament amb la policia. En un comunicat que es va fer públic
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ahir
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     un dia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     després
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  del desenllaç del segrest, el
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ministeri d'Informació
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  iranià va reafirmar la voluntat del
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Govern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  de &quot;lluitar sense quarter contra els contrarevolucionaris i bandits&quot;. La nota qualificava el segrest de &quot;perfecte exemple de xantatge i d'atemptat contra la seguretat del país&quot;, informa
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France Presse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . La denúncia del ministre va coincidir amb el discurs que, davant milers de militars, va pronunciar el guia espiritual de l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ali Khamenei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , que va defensar &quot;la llei del talió&quot; i la pena de mort, en resposta a les demandes del
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  moderat iranià
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nechat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , que ha proposat que totes dues formes de càstig siguin abolides. De forma, suau; de fons, dur; i els trets, apuntant cap a l'economia. Acabat el seu
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     primer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  mes de treball com a líder de l'oposició, aquest pot ser el resum de l'efecte que ha causat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     José Luis Rodríguez Zapatero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  en la política madrilenya. I no és que sigui nou, corria per les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  des de
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     l'any 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , el que passava és que fins
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , quan passava per davant d'un grup de periodistes als passadissos, no es girava ni un sol cap per mirar-lo, i
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: midd
